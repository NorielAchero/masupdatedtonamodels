# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the accompanying [Blog Post](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset/).
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Jan 16 18:00:15 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   38C    P8              12W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 30.8/235.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 341MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 76.7MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 62.6ms
# Speed: 14.8ms preprocess, 62.6ms inference, 805.3ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 68.3ms
# Speed: 4.6ms preprocess, 68.3ms inference, 602.6ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.0000,  314.4659,  625.1384, 1278.2329],
#         [  55.3155,  250.0996,  648.0573, 1266.2471],
#         [ 633.2308,  719.5389,  701.0688,  786.0390]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.7272, 0.2903, 0.2839], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a [supported format](https://roboflow.com/formats), the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v8` dataset format. (Formerly, we used to use `Yolov5`, as the gif shows)
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# 🟢 Tip: The examples below work even if you use our non-custom model. However, you won't be able to deploy it to Roboflow. To do that, create a custom dataset as described below or fork (copy) one into your workspace from Universe.

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow==1.1.48 --quiet

import roboflow

roboflow.login()

rf = roboflow.Roboflow()

project = rf.workspace("final-ai-solution-p79og").project("driver-fatigue")
dataset = project.version(2).download("yolov8")
# Out:
# /content/datasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# Downloading Dataset Version Zip in Driver-Fatigue-2 to yolov8:: 100%|██████████| 293612/293612 [00:17<00:00, 16641.92it/s]
# Extracting Dataset Version Zip to Driver-Fatigue-2 in yolov8:: 100%|██████████| 14338/14338 [00:01<00:00, 7773.48it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 452MB/s]
# New https://pypi.org/project/ultralytics/8.3.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/Driver-Fatigue-2/data.yaml, epochs=25, time=None, patience=100, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 133MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# Model summary: 225 layers, 11,136,374 parameters, 11,136,358 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/datasets/Driver-Fatigue-2/train/labels... 6240 images, 33 backgrounds, 0 corrupt: 100% 6240/6240 [00:04<00:00, 1506.03it/s]
# train: New cache created: /content/datasets/Driver-Fatigue-2/train/labels.cache
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.0 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Driver-Fatigue-2/valid/labels... 617 images, 0 backgrounds, 0 corrupt: 100% 617/617 [00:00<00:00, 1235.39it/s]
# val: New cache created: /content/datasets/Driver-Fatigue-2/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      5.74G      1.355      1.641       1.52         41        800: 100% 390/390 [01:41<00:00,  3.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.26it/s]
#                    all        617        617      0.739      0.704      0.776      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      5.54G      1.304      1.068      1.426         33        800: 100% 390/390 [01:38<00:00,  3.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.29it/s]
#                    all        617        617      0.816      0.798      0.862      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      5.76G       1.25     0.9741      1.378         29        800: 100% 390/390 [01:37<00:00,  3.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.14it/s]
#                    all        617        617      0.789      0.786      0.842      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      5.52G      1.187     0.8847      1.335         33        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.30it/s]
#                    all        617        617      0.929      0.911       0.97      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      5.53G      1.101     0.8034       1.29         36        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.37it/s]
#                    all        617        617      0.948      0.947      0.982      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      5.54G      1.061     0.7381      1.258         31        800: 100% 390/390 [01:37<00:00,  3.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.29it/s]
#                    all        617        617      0.906      0.952      0.975      0.804
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      5.53G      1.013     0.7034      1.237         29        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.25it/s]
#                    all        617        617      0.964      0.971       0.99       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      5.54G     0.9843     0.6816      1.221         29        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.33it/s]
#                    all        617        617       0.96      0.959      0.984      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      5.53G     0.9657     0.6577      1.204         30        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.34it/s]
#                    all        617        617      0.943      0.976      0.985      0.837
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      5.53G     0.9231     0.6232      1.178         23        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.31it/s]
#                    all        617        617      0.959      0.981      0.988       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      5.53G     0.8962     0.5945      1.165         32        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.36it/s]
#                    all        617        617      0.961      0.957      0.985       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      5.53G     0.8899     0.5847      1.166         26        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.36it/s]
#                    all        617        617      0.973       0.98      0.988      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      5.54G     0.8715     0.5626      1.159         23        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.35it/s]
#                    all        617        617      0.976      0.982      0.991      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      5.54G     0.8525     0.5636      1.141         37        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.29it/s]
#                    all        617        617      0.964       0.98       0.99      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      5.53G     0.8214     0.5413      1.129         28        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.24it/s]
#                    all        617        617      0.975      0.981       0.99      0.872
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      5.53G     0.7498     0.3803      1.158         15        800: 100% 390/390 [01:38<00:00,  3.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.29it/s]
#                    all        617        617      0.984      0.987      0.989      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      5.54G     0.7142     0.3666      1.128         16        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.35it/s]
#                    all        617        617      0.969      0.968      0.988       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      5.53G     0.6826     0.3448      1.106         16        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.30it/s]
#                    all        617        617      0.977      0.979      0.987      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      5.54G     0.6628     0.3285      1.092         16        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.34it/s]
#                    all        617        617      0.968      0.982      0.989      0.893
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      5.53G     0.6509     0.3173       1.09         15        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.34it/s]
#                    all        617        617      0.981      0.985       0.99      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      5.53G     0.6305     0.3028      1.065         15        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.14it/s]
#                    all        617        617      0.972      0.984      0.988      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      5.53G     0.6013     0.2908      1.052         16        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.30it/s]
#                    all        617        617      0.981      0.979       0.99      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      5.54G     0.5909     0.2796      1.044         16        800: 100% 390/390 [01:37<00:00,  4.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.29it/s]
#                    all        617        617      0.973      0.983      0.987      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      5.54G     0.5666     0.2705      1.029         16        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.35it/s]
#                    all        617        617      0.977      0.983      0.989       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      5.53G     0.5541     0.2612      1.017         16        800: 100% 390/390 [01:37<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.33it/s]
#                    all        617        617      0.977      0.985      0.989      0.911
#
# 25 epochs completed in 0.719 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.86it/s]
#                    all        617        617      0.977      0.985      0.989      0.912
#                  Awake        327        327      0.978      0.991      0.991      0.916
#                 Drowsy        290        290      0.976      0.979      0.987      0.907
# Speed: 0.3ms preprocess, 4.0ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Driver-Fatigue-2/valid/labels.cache... 617 images, 0 backgrounds, 0 corrupt: 100% 617/617 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 39/39 [00:07<00:00,  5.02it/s]
#                    all        617        617      0.977      0.985      0.989      0.912
#                  Awake        327        327      0.978      0.991      0.991      0.916
#                 Drowsy        290        290      0.976      0.979      0.987      0.908
# Speed: 0.8ms preprocess, 6.8ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/306 /content/datasets/Driver-Fatigue-2/test/images/1007_jpg.rf.087411387508aa1d602475c840be86aa.jpg: 800x800 1 Awake, 7.7ms
# image 2/306 /content/datasets/Driver-Fatigue-2/test/images/1032_jpg.rf.6d18dee633e3fd077437adcda8aa44f1.jpg: 800x800 1 Awake, 7.6ms
# image 3/306 /content/datasets/Driver-Fatigue-2/test/images/1114_jpg.rf.3dda05bd88768438a0ec2e87aa5ff99b.jpg: 800x800 1 Awake, 7.2ms
# image 4/306 /content/datasets/Driver-Fatigue-2/test/images/1130_jpg.rf.9b30d23462516e7a9ec56b7c2074b5d0.jpg: 800x800 1 Awake, 7.1ms
# image 5/306 /content/datasets/Driver-Fatigue-2/test/images/1178_jpg.rf.6329e43cc2c2d5336e8984d72b9788c7.jpg: 800x800 1 Awake, 7.1ms
# image 6/306 /content/datasets/Driver-Fatigue-2/test/images/117_jpg.rf.459eeb5393a0a4fabf074dbd3103720c.jpg: 800x800 1 Drowsy, 7.2ms
# image 7/306 /content/datasets/Driver-Fatigue-2/test/images/1247_jpg.rf.560f80b98911f845aebc5a627d7a6039.jpg: 800x800 1 Awake, 7.2ms
# image 8/306 /content/datasets/Driver-Fatigue-2/test/images/127_jpg.rf.92366ee8fac48b782d20e0987a5bdb2f.jpg: 800x800 1 Drowsy, 7.0ms
# image 9/306 /content/datasets/Driver-Fatigue-2/test/images/130_jpg.rf.6fec9f7b9accbbc3903967520b5f8a9d.jpg: 800x800 1 Drowsy, 6.9ms
# image 10/306 /content/datasets/Driver-Fatigue-2/test/images/1369_jpg.rf.51b75a5135a3a5f4713397c8b6b4e75f.jpg: 800x800 1 Awake, 6.8ms
# image 11/306 /content/datasets/Driver-Fatigue-2/test/images/142_jpg.rf.074b52261a90a85e18fbfa6606469f4f.jpg: 800x800 1 Awake, 6.9ms
# image 12/306 /content/datasets/Driver-Fatigue-2/test/images/1462_jpg.rf.e91e208fbc41d6b82f02f3fcf96ea03d.jpg: 800x800 1 Awake, 6.8ms
# image 13/306 /content/datasets/Driver-Fatigue-2/test/images/149_jpg.rf.6b229426efc3f8c7991cf370c05392fd.jpg: 800x800 1 Awake, 6.7ms
# image 14/306 /content/datasets/Driver-Fatigue-2/test/images/1629_jpg.rf.3dd6f293591125d273605d3ba99a9924.jpg: 800x800 1 Awake, 6.9ms
# image 15/306 /content/datasets/Driver-Fatigue-2/test/images/1642_jpg.rf.50ea5a72c5a9eea5ca21751db1bb0ba2.jpg: 800x800 1 Awake, 6.8ms
# image 16/306 /content/datasets/Driver-Fatigue-2/test/images/16_jpg.rf.1b2412778f9b01bb24272dde322ea9b9.jpg: 800x800 1 Drowsy, 7.7ms
# image 17/306 /content/datasets/Driver-Fatigue-2/test/images/1701_jpg.rf.656b8a41dceb7532307b151dc8fe8e2e.jpg: 800x800 1 Awake, 6.9ms
# image 18/306 /content/datasets/Driver-Fatigue-2/test/images/1738_jpg.rf.02dcfd237b0f5f4e19c7ecb9e59c9597.jpg: 800x800 1 Awake, 6.8ms
# image 19/306 /content/datasets/Driver-Fatigue-2/test/images/1768_jpg.rf.549e3509e0124ca57f2eb579859943d1.jpg: 800x800 1 Awake, 6.8ms
# image 20/306 /content/datasets/Driver-Fatigue-2/test/images/1871_jpg.rf.0c03c7e8782502aa9bede4b87081b3b0.jpg: 800x800 1 Awake, 6.9ms
# image 21/306 /content/datasets/Driver-Fatigue-2/test/images/1878_jpg.rf.9ffa49ea112125ed33c08d22beaf6f85.jpg: 800x800 1 Awake, 6.8ms
# image 22/306 /content/datasets/Driver-Fatigue-2/test/images/1900_jpg.rf.91d2553e6a741a7ed59d556547c425f4.jpg: 800x800 1 Awake, 8.4ms
# image 23/306 /content/datasets/Driver-Fatigue-2/test/images/1937_jpg.rf.08a5eefbe89c64178c19c452fbad6b9c.jpg: 800x800 1 Awake, 8.4ms
# image 24/306 /content/datasets/Driver-Fatigue-2/test/images/1967_jpg.rf.5a47077e577cfb1d8f00e92c0953584b.jpg: 800x800 1 Awake, 8.4ms
# image 25/306 /content/datasets/Driver-Fatigue-2/test/images/2087_jpg.rf.fe9e4c1e6aa3a546702c477127f8948d.jpg: 800x800 1 Awake, 8.3ms
# image 26/306 /content/datasets/Driver-Fatigue-2/test/images/2131_jpg.rf.55b6a8516fdf35f791bcbea80736e278.jpg: 800x800 1 Awake, 6.7ms
# image 27/306 /content/datasets/Driver-Fatigue-2/test/images/2136_jpg.rf.79cb25e79dfffecd2d250611b3d935f0.jpg: 800x800 1 Awake, 6.8ms
# image 28/306 /content/datasets/Driver-Fatigue-2/test/images/216_jpg.rf.ac67fb8f7097de5e93219aa072735e3c.jpg: 800x800 1 Drowsy, 6.7ms
# image 29/306 /content/datasets/Driver-Fatigue-2/test/images/221023-091309_jpg.rf.d7de18c170fbcee208cd8643fdb82e34.jpg: 800x800 1 Awake, 7.5ms
# image 30/306 /content/datasets/Driver-Fatigue-2/test/images/221023-091355_jpg.rf.0052af7ffaefd802070a3d3cdd1feefa.jpg: 800x800 1 Drowsy, 8.3ms
# image 31/306 /content/datasets/Driver-Fatigue-2/test/images/221023-091420_jpg.rf.5d3b5ef3f7b61ef5530993b374f570fd.jpg: 800x800 1 Drowsy, 8.5ms
# image 32/306 /content/datasets/Driver-Fatigue-2/test/images/221023-091422_jpg.rf.83981b52bf45554d13e3f3b9ea038ecf.jpg: 800x800 1 Drowsy, 8.3ms
# image 33/306 /content/datasets/Driver-Fatigue-2/test/images/221023-091429_jpg.rf.7f9100708fa9514787fdbc5ff728d258.jpg: 800x800 1 Drowsy, 8.2ms
# image 34/306 /content/datasets/Driver-Fatigue-2/test/images/221023-091722_jpg.rf.6aa568ee91a065a9c73790fe68ca6d96.jpg: 800x800 1 Awake, 8.4ms
# image 35/306 /content/datasets/Driver-Fatigue-2/test/images/221023-091723_jpg.rf.3a819e64bcc9dca1a68d0a119edc315b.jpg: 800x800 1 Awake, 8.2ms
# image 36/306 /content/datasets/Driver-Fatigue-2/test/images/221023-091831_jpg.rf.84a3a34610adb26acea967741293df69.jpg: 800x800 1 Drowsy, 8.3ms
# image 37/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092019_jpg.rf.6a9179384fb494b7b05d62657a097e3a.jpg: 800x800 1 Drowsy, 8.2ms
# image 38/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092030_jpg.rf.cf510a59f25ba214a3c1d85510769e35.jpg: 800x800 1 Drowsy, 7.4ms
# image 39/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092031_jpg.rf.6e964bd35c9447b805e248a09129ab60.jpg: 800x800 1 Drowsy, 6.7ms
# image 40/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092032_jpg.rf.d0dd9c21d9f6818a5a17c0b37d91cc8f.jpg: 800x800 1 Drowsy, 6.7ms
# image 41/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092037_jpg.rf.859d3e06277f30bdde03ffee52c071b8.jpg: 800x800 1 Drowsy, 7.6ms
# image 42/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092049_jpg.rf.7aade474371c835b748c7f6a410479f5.jpg: 800x800 1 Drowsy, 6.8ms
# image 43/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092114_jpg.rf.9832e0ea78ddb869e36cdefa50a18dbc.jpg: 800x800 1 Drowsy, 6.7ms
# image 44/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092115_jpg.rf.9e8fd60cb61448608cfe839c03772772.jpg: 800x800 1 Drowsy, 6.8ms
# image 45/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092116_jpg.rf.df661a7496bd3893b800f4a8944dd570.jpg: 800x800 1 Drowsy, 6.7ms
# image 46/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092124_jpg.rf.4419823fddd3a64d9cc9ef5becf7a098.jpg: 800x800 1 Drowsy, 6.6ms
# image 47/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092131_jpg.rf.7d76f95a9a463ba8f03803a7b3cf52ed.jpg: 800x800 1 Drowsy, 6.7ms
# image 48/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092142_jpg.rf.93b91972709b82f23a6794a9511d36ec.jpg: 800x800 1 Drowsy, 6.7ms
# image 49/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092155_jpg.rf.0c6f05db621a636ddaca6a284112ba69.jpg: 800x800 1 Drowsy, 6.7ms
# image 50/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092201_jpg.rf.a775b3e3341ffc99c9475fedda174c71.jpg: 800x800 1 Drowsy, 6.7ms
# image 51/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092203_jpg.rf.a9649a6b8de6bd746c4838365321b24a.jpg: 800x800 1 Drowsy, 6.6ms
# image 52/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092736_jpg.rf.c0d9d46e4c102db35a31714eb72c98a8.jpg: 800x800 1 Drowsy, 6.5ms
# image 53/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092737_jpg.rf.8874bda6e7c6c2b1a4c113bf05c05940.jpg: 800x800 1 Drowsy, 6.6ms
# image 54/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092753_jpg.rf.ac009fabe1f8e1e8dc92d8ec8c100fd3.jpg: 800x800 1 Drowsy, 6.5ms
# image 55/306 /content/datasets/Driver-Fatigue-2/test/images/221023-092923_jpg.rf.8854d190d9a881977696f5e21987541a.jpg: 800x800 1 Drowsy, 6.5ms
# image 56/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093123_jpg.rf.7a3fff11f10434899ac7203e861cd764.jpg: 800x800 1 Drowsy, 6.6ms
# image 57/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093135_jpg.rf.98bc1b82c66766a4c907237ec89c9796.jpg: 800x800 1 Drowsy, 6.5ms
# image 58/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093154_jpg.rf.3da991e8dbf15b84229b5154bd8f9fb7.jpg: 800x800 1 Drowsy, 6.5ms
# image 59/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093157_jpg.rf.cf5a4fbc0f6f8b5b819d1f7a4d76cc8a.jpg: 800x800 1 Drowsy, 6.5ms
# image 60/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093209_jpg.rf.f1749d437563d29b543ae82a609f8670.jpg: 800x800 1 Drowsy, 6.5ms
# image 61/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093221_jpg.rf.893de57520b4477701bb32b7fc352d2b.jpg: 800x800 1 Drowsy, 6.5ms
# image 62/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093407_jpg.rf.7eb9e5a16c7f131f7ff0beb8a0c390f9.jpg: 800x800 1 Drowsy, 6.5ms
# image 63/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093706_jpg.rf.19d8ef10ace2dbe57b60b39d476daced.jpg: 800x800 1 Drowsy, 6.6ms
# image 64/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093719_jpg.rf.a84307fc0fa0596b8659a658936bde45.jpg: 800x800 1 Drowsy, 6.5ms
# image 65/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093731_jpg.rf.de69024d094232af5168c58b7a013a49.jpg: 800x800 1 Drowsy, 6.5ms
# image 66/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093745_jpg.rf.3cdc8371df43e80b0577fdeef5f657fb.jpg: 800x800 1 Drowsy, 6.6ms
# image 67/306 /content/datasets/Driver-Fatigue-2/test/images/221023-093949_jpg.rf.1b70b666a08d76cbd516119c3464a486.jpg: 800x800 1 Drowsy, 6.6ms
# image 68/306 /content/datasets/Driver-Fatigue-2/test/images/221023-094006_jpg.rf.e5cc4b0a162be387ecc6e7c51eb64270.jpg: 800x800 1 Drowsy, 6.6ms
# image 69/306 /content/datasets/Driver-Fatigue-2/test/images/221023-094022_jpg.rf.91df108da89c359c6d329b3e5fadc4ed.jpg: 800x800 1 Awake, 6.6ms
# image 70/306 /content/datasets/Driver-Fatigue-2/test/images/221023-094041_jpg.rf.e0285444466fd8e3d53c8ea1ca784697.jpg: 800x800 1 Awake, 8.2ms
# image 71/306 /content/datasets/Driver-Fatigue-2/test/images/221023-094137_jpg.rf.be831487315251a6c31776d212a429cd.jpg: 800x800 1 Drowsy, 6.7ms
# image 72/306 /content/datasets/Driver-Fatigue-2/test/images/221023-094141_jpg.rf.b765e559a1745228d43509037c02f448.jpg: 800x800 1 Drowsy, 6.6ms
# image 73/306 /content/datasets/Driver-Fatigue-2/test/images/221023-094222_jpg.rf.364fd44e4a7abe353031184986ce4d7a.jpg: 800x800 1 Drowsy, 6.7ms
# image 74/306 /content/datasets/Driver-Fatigue-2/test/images/221023-140341_jpg.rf.d1c7a27e076d83115555ba223f594c07.jpg: 800x800 1 Drowsy, 6.7ms
# image 75/306 /content/datasets/Driver-Fatigue-2/test/images/221023-140356_jpg.rf.cb1b0e832412aacbf2913487d7a7da70.jpg: 800x800 1 Drowsy, 6.7ms
# image 76/306 /content/datasets/Driver-Fatigue-2/test/images/221023-140400_jpg.rf.67243d5bbfe34a9fed34a012fc5b7c01.jpg: 800x800 1 Drowsy, 6.7ms
# image 77/306 /content/datasets/Driver-Fatigue-2/test/images/221023-140405_jpg.rf.9075ba8ebd43144f2cdddb201a5bc849.jpg: 800x800 1 Drowsy, 6.7ms
# image 78/306 /content/datasets/Driver-Fatigue-2/test/images/221023-140446_jpg.rf.d002efffb6988548aa31f04c6b12eb0b.jpg: 800x800 1 Drowsy, 6.7ms
# image 79/306 /content/datasets/Driver-Fatigue-2/test/images/221023-140716_jpg.rf.6be01356cb2732c4dd23861e242b24b9.jpg: 800x800 1 Drowsy, 6.7ms
# image 80/306 /content/datasets/Driver-Fatigue-2/test/images/221023-140801_jpg.rf.8cf8c4db0901190ef060e4e332fe24e9.jpg: 800x800 1 Drowsy, 6.8ms
# image 81/306 /content/datasets/Driver-Fatigue-2/test/images/221023-140827_jpg.rf.a754f465f8844727f6bee179908fb594.jpg: 800x800 1 Drowsy, 8.6ms
# image 82/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141048_jpg.rf.818ec9c31d169057df7681404a55851c.jpg: 800x800 1 Drowsy, 7.1ms
# image 83/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141109_jpg.rf.90eb8902d4e026e0d85abe92a40e8f66.jpg: 800x800 1 Drowsy, 6.6ms
# image 84/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141224_jpg.rf.357d58721a8dd9f891181d4a5e92f0c7.jpg: 800x800 1 Drowsy, 6.7ms
# image 85/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141227_jpg.rf.e5cbfabc01db411303e69a69344ffed6.jpg: 800x800 1 Drowsy, 6.6ms
# image 86/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141237_jpg.rf.451030c4a8af45dbf5e98c3ef68d8863.jpg: 800x800 1 Drowsy, 6.7ms
# image 87/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141239_jpg.rf.1493ea19dd1304abca1aa163399983b8.jpg: 800x800 1 Drowsy, 6.5ms
# image 88/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141241_jpg.rf.a17b394294eaf17f16ffd0212554a480.jpg: 800x800 1 Drowsy, 6.6ms
# image 89/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141356_jpg.rf.ffa1435ca854a3d052a13e0e4018981e.jpg: 800x800 1 Awake, 6.5ms
# image 90/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141429_jpg.rf.bd89414452e58ae04cc3e2da6328e554.jpg: 800x800 1 Awake, 6.5ms
# image 91/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141455_jpg.rf.df68e8da0d58004e4a31d8423aec73c7.jpg: 800x800 1 Awake, 6.5ms
# image 92/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141533_jpg.rf.6d31784c389fdd24bd4512cef2737e02.jpg: 800x800 1 Drowsy, 6.5ms
# image 93/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141546_jpg.rf.66bb683376af39801c199ca4f9eb9865.jpg: 800x800 1 Drowsy, 6.6ms
# image 94/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141547_jpg.rf.cf000e0ff10b4220e63fad270639e3fc.jpg: 800x800 1 Drowsy, 7.7ms
# image 95/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141549_jpg.rf.bbe1adf00dbc4a081dc3ec46714879fa.jpg: 800x800 1 Drowsy, 6.6ms
# image 96/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141600_jpg.rf.5363118335710e7b63e0b8e5e11ba475.jpg: 800x800 1 Drowsy, 6.7ms
# image 97/306 /content/datasets/Driver-Fatigue-2/test/images/221023-141601_jpg.rf.92cfadb712d8c98103cf922db860b1ef.jpg: 800x800 1 Drowsy, 6.6ms
# image 98/306 /content/datasets/Driver-Fatigue-2/test/images/221023-142034_jpg.rf.caceaa4096b839051ff3e0441eff99dc.jpg: 800x800 1 Drowsy, 6.5ms
# image 99/306 /content/datasets/Driver-Fatigue-2/test/images/221023-142125_jpg.rf.9da60bc7be27444efda09f4ef1b445c2.jpg: 800x800 1 Drowsy, 6.8ms
# image 100/306 /content/datasets/Driver-Fatigue-2/test/images/221023-142312_jpg.rf.01d35e2b24cbc4b596ebc1a56b9a77a8.jpg: 800x800 1 Drowsy, 6.8ms
# image 101/306 /content/datasets/Driver-Fatigue-2/test/images/221023-142348_jpg.rf.6e7d3deacebe00982ad59746a7453eea.jpg: 800x800 1 Drowsy, 6.7ms
# image 102/306 /content/datasets/Driver-Fatigue-2/test/images/221023-142747_jpg.rf.37f9aa7008c234a5188e69aeaa34bc76.jpg: 800x800 1 Awake, 6.6ms
# image 103/306 /content/datasets/Driver-Fatigue-2/test/images/221023-143326_jpg.rf.8c11d214cb9e6015cc1f30a2b2e9d559.jpg: 800x800 1 Drowsy, 6.6ms
# image 104/306 /content/datasets/Driver-Fatigue-2/test/images/221023-143340_jpg.rf.7f32602e46686de6247007e7755ea821.jpg: 800x800 1 Drowsy, 6.5ms
# image 105/306 /content/datasets/Driver-Fatigue-2/test/images/221023-143809_jpg.rf.ff500bd1d3a321773e232a27f45dc129.jpg: 800x800 1 Drowsy, 6.6ms
# image 106/306 /content/datasets/Driver-Fatigue-2/test/images/221023-143841_jpg.rf.beb9690c1049bfe7b9dcdfdf5a60c02f.jpg: 800x800 1 Drowsy, 6.6ms
# image 107/306 /content/datasets/Driver-Fatigue-2/test/images/221023-144001_jpg.rf.5b46658567e22b05196560eee4b8a9c3.jpg: 800x800 1 Awake, 6.5ms
# image 108/306 /content/datasets/Driver-Fatigue-2/test/images/221023-144004_jpg.rf.a6615de903564c7e0724289b8d7183a5.jpg: 800x800 1 Awake, 6.5ms
# image 109/306 /content/datasets/Driver-Fatigue-2/test/images/221023-144103_jpg.rf.28072a4d0cd051a19f0e6c6e21eab281.jpg: 800x800 1 Drowsy, 6.5ms
# image 110/306 /content/datasets/Driver-Fatigue-2/test/images/221023-144214_jpg.rf.0bbb2c9527c3d1e4e9fae632232f1efe.jpg: 800x800 1 Awake, 6.6ms
# image 111/306 /content/datasets/Driver-Fatigue-2/test/images/221023-144221_jpg.rf.bc9bca10c5c5a3cdc55df0e8623149ea.jpg: 800x800 1 Awake, 7.3ms
# image 112/306 /content/datasets/Driver-Fatigue-2/test/images/221023-144300_jpg.rf.6cd6e34c013677f167ae838651f3867c.jpg: 800x800 1 Drowsy, 6.7ms
# image 113/306 /content/datasets/Driver-Fatigue-2/test/images/221023-144921_jpg.rf.4ef72cf801244e9eb1fc844a995cbf8e.jpg: 800x800 1 Drowsy, 6.7ms
# image 114/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145053_jpg.rf.d4919206587ea8ff600106f49f3f5791.jpg: 800x800 1 Drowsy, 6.8ms
# image 115/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145117_jpg.rf.0007562011b53da01d6d67169ff3f725.jpg: 800x800 1 Drowsy, 6.9ms
# image 116/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145136_jpg.rf.4e6558b15b901d697a1c6e54196b3c06.jpg: 800x800 1 Drowsy, 6.9ms
# image 117/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145155_jpg.rf.2bdb2206d1c937d688fdcb7c2332b1ff.jpg: 800x800 1 Drowsy, 6.8ms
# image 118/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145325_jpg.rf.7a5e75e22c2dfc060633e49e31c51f98.jpg: 800x800 1 Awake, 6.8ms
# image 119/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145327_jpg.rf.1336a3a6daa4bebeba475cdc2eb0ecf9.jpg: 800x800 1 Awake, 6.8ms
# image 120/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145356_jpg.rf.2a9e88fff502269459c26a20e63980d7.jpg: 800x800 1 Awake, 6.8ms
# image 121/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145357_jpg.rf.1ee6b5f1369e88fe459d26b6ab338391.jpg: 800x800 1 Awake, 6.8ms
# image 122/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145359_jpg.rf.f353aaa0c2c32dd4e2dc678386c7498a.jpg: 800x800 1 Awake, 6.7ms
# image 123/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145401_jpg.rf.c74057bef8c20b330392cf8bc3071dde.jpg: 800x800 1 Awake, 6.8ms
# image 124/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145432_jpg.rf.c372efb21aaaa7cc9da57b658a3d2b48.jpg: 800x800 1 Drowsy, 6.8ms
# image 125/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145623_jpg.rf.9304ef6309e83906d2ef96561629ac1d.jpg: 800x800 1 Awake, 6.7ms
# image 126/306 /content/datasets/Driver-Fatigue-2/test/images/221023-145639_jpg.rf.9b417f9c38fea2329c36b4ae941cca79.jpg: 800x800 1 Awake, 6.9ms
# image 127/306 /content/datasets/Driver-Fatigue-2/test/images/221024-093228_jpg.rf.cd9053504ee6c3db134021f35eac9232.jpg: 800x800 1 Drowsy, 6.8ms
# image 128/306 /content/datasets/Driver-Fatigue-2/test/images/221024-093529_jpg.rf.6863c697fed8c38ac7a9f15bfc2e1113.jpg: 800x800 1 Awake, 6.6ms
# image 129/306 /content/datasets/Driver-Fatigue-2/test/images/221024-094403_jpg.rf.5be4cc28bc1bb99bb70f56fe92c8f0f1.jpg: 800x800 1 Awake, 7.1ms
# image 130/306 /content/datasets/Driver-Fatigue-2/test/images/221024-094716_jpg.rf.6928182f66db7d33c316e65b49c92627.jpg: 800x800 1 Drowsy, 6.8ms
# image 131/306 /content/datasets/Driver-Fatigue-2/test/images/221024-095157_jpg.rf.c7653e25f0f885cb917b557963976e5c.jpg: 800x800 1 Drowsy, 6.6ms
# image 132/306 /content/datasets/Driver-Fatigue-2/test/images/221024-095201_jpg.rf.4eddd2f9394951d93f57e8ce107e1442.jpg: 800x800 1 Drowsy, 6.6ms
# image 133/306 /content/datasets/Driver-Fatigue-2/test/images/221024-095248_jpg.rf.e74383267db0ef144cfbceb752410c6c.jpg: 800x800 1 Awake, 6.8ms
# image 134/306 /content/datasets/Driver-Fatigue-2/test/images/221024-095252_jpg.rf.72bff5413b476127f1e8774c0ff674af.jpg: 800x800 1 Awake, 6.9ms
# image 135/306 /content/datasets/Driver-Fatigue-2/test/images/221024-095347_jpg.rf.a282cb639f576e5232315cbfafdfa8bc.jpg: 800x800 1 Awake, 6.7ms
# image 136/306 /content/datasets/Driver-Fatigue-2/test/images/221024-095353_jpg.rf.9fdfd518b06e5717bd836122ce7bfc85.jpg: 800x800 1 Awake, 6.8ms
# image 137/306 /content/datasets/Driver-Fatigue-2/test/images/2259_jpg.rf.566876736a198582ce1fa267633eeeb3.jpg: 800x800 1 Awake, 6.7ms
# image 138/306 /content/datasets/Driver-Fatigue-2/test/images/225_jpg.rf.5bc6a9d146035b957f910ccb81d1be1d.jpg: 800x800 1 Awake, 6.7ms
# image 139/306 /content/datasets/Driver-Fatigue-2/test/images/226_jpg.rf.2190117ac123ecc4e3456716911adba0.jpg: 800x800 1 Awake, 7.0ms
# image 140/306 /content/datasets/Driver-Fatigue-2/test/images/230_jpg.rf.b5083ed8822c048ae8e98815ca86fe5c.jpg: 800x800 1 Drowsy, 6.8ms
# image 141/306 /content/datasets/Driver-Fatigue-2/test/images/2346_jpg.rf.088b7d3aa4857e2a30aba8688f1232b2.jpg: 800x800 1 Awake, 7.0ms
# image 142/306 /content/datasets/Driver-Fatigue-2/test/images/2371_jpg.rf.f5d449c460f8f64b058ba126dd7f7882.jpg: 800x800 1 Awake, 7.1ms
# image 143/306 /content/datasets/Driver-Fatigue-2/test/images/2399_jpg.rf.e74ad92c178da3cce7d0c3e81f671a06.jpg: 800x800 1 Awake, 6.7ms
# image 144/306 /content/datasets/Driver-Fatigue-2/test/images/23_jpg.rf.263f0d96eb02335177736f4f803c73ac.jpg: 800x800 1 Drowsy, 6.9ms
# image 145/306 /content/datasets/Driver-Fatigue-2/test/images/2403_jpg.rf.812046334dd2a64220cdaff0561e9d07.jpg: 800x800 1 Awake, 6.7ms
# image 146/306 /content/datasets/Driver-Fatigue-2/test/images/2409_jpg.rf.1c8389e92c656316f626d6d5e435082f.jpg: 800x800 1 Awake, 6.7ms
# image 147/306 /content/datasets/Driver-Fatigue-2/test/images/2429_jpg.rf.d6dbd0b2beaf7135514cd09164f694e4.jpg: 800x800 1 Awake, 6.7ms
# image 148/306 /content/datasets/Driver-Fatigue-2/test/images/249_jpg.rf.c3a9e446d9831022a2f073f619ec13bc.jpg: 800x800 1 Drowsy, 6.7ms
# image 149/306 /content/datasets/Driver-Fatigue-2/test/images/2518_jpg.rf.2b62e3e3e367f62b50f336a7dcf29178.jpg: 800x800 1 Awake, 6.7ms
# image 150/306 /content/datasets/Driver-Fatigue-2/test/images/256_jpg.rf.c105296f7a70c391f077bca84c71774a.jpg: 800x800 1 Awake, 6.9ms
# image 151/306 /content/datasets/Driver-Fatigue-2/test/images/2571_jpg.rf.070d0b718c73977a50be2020d7245cb3.jpg: 800x800 1 Awake, 6.7ms
# image 152/306 /content/datasets/Driver-Fatigue-2/test/images/2584_jpg.rf.ce93e577c90adeacc873726315391dd5.jpg: 800x800 1 Awake, 6.7ms
# image 153/306 /content/datasets/Driver-Fatigue-2/test/images/2610_jpg.rf.8246519ef11172272fc35b4b567b0660.jpg: 800x800 1 Awake, 7.7ms
# image 154/306 /content/datasets/Driver-Fatigue-2/test/images/264_jpg.rf.ff6795331d97fc8dad63b6606bcc7749.jpg: 800x800 1 Drowsy, 7.1ms
# image 155/306 /content/datasets/Driver-Fatigue-2/test/images/265_jpg.rf.2a7221ecc07c8339c0bfb6350b52f1c0.jpg: 800x800 1 Drowsy, 6.7ms
# image 156/306 /content/datasets/Driver-Fatigue-2/test/images/278_jpg.rf.1bb35d170df1d3868db137a8f7a74ab5.jpg: 800x800 1 Drowsy, 6.7ms
# image 157/306 /content/datasets/Driver-Fatigue-2/test/images/280_jpg.rf.8dd48f6596c7348e8418cfc2702e57df.jpg: 800x800 1 Drowsy, 6.7ms
# image 158/306 /content/datasets/Driver-Fatigue-2/test/images/315_jpg.rf.e22a5f0ce85040ea94c6dec1a99a9774.jpg: 800x800 1 Awake, 7.3ms
# image 159/306 /content/datasets/Driver-Fatigue-2/test/images/32_jpg.rf.f947a03ab6ae6e1767c1a4260e7948fd.jpg: 800x800 1 Drowsy, 6.9ms
# image 160/306 /content/datasets/Driver-Fatigue-2/test/images/332_jpg.rf.c51d0dc05a2a9208de4b65033c4d29e4.jpg: 800x800 1 Awake, 6.6ms
# image 161/306 /content/datasets/Driver-Fatigue-2/test/images/338_jpg.rf.7adc1194a1ae08af9991c07605b886de.jpg: 800x800 1 Drowsy, 6.6ms
# image 162/306 /content/datasets/Driver-Fatigue-2/test/images/345_jpg.rf.71f942333fb93cc2e6b706cbda2bd3bb.jpg: 800x800 1 Drowsy, 6.6ms
# image 163/306 /content/datasets/Driver-Fatigue-2/test/images/356_jpg.rf.9e20fb5dbeda5524c397d694bcaab84e.jpg: 800x800 1 Drowsy, 6.6ms
# image 164/306 /content/datasets/Driver-Fatigue-2/test/images/369_jpg.rf.784b796cdc8b08a25312f8b9f9261556.jpg: 800x800 1 Drowsy, 6.5ms
# image 165/306 /content/datasets/Driver-Fatigue-2/test/images/36_jpg.rf.81ca607f63f2118bf360fac4128202eb.jpg: 800x800 1 Drowsy, 6.6ms
# image 166/306 /content/datasets/Driver-Fatigue-2/test/images/374_jpg.rf.64c7b5f4c3fccac01f988cfd23a7bd5e.jpg: 800x800 1 Drowsy, 6.6ms
# image 167/306 /content/datasets/Driver-Fatigue-2/test/images/393_jpg.rf.06b05688343887f60d1bee04294ca885.jpg: 800x800 1 Drowsy, 6.6ms
# image 168/306 /content/datasets/Driver-Fatigue-2/test/images/400_jpg.rf.397f4df6cdc04dfc9e9745d7bbd421b3.jpg: 800x800 1 Drowsy, 6.8ms
# image 169/306 /content/datasets/Driver-Fatigue-2/test/images/412054364_1157921618504990_6015814173518158205_n_jpg.rf.f7150244de72cc3d014b0d20f9df23b8.jpg: 800x800 1 Awake, 6.7ms
# image 170/306 /content/datasets/Driver-Fatigue-2/test/images/42_jpg.rf.0ac83d6a498ec5f00c534f91f65eb417.jpg: 800x800 1 Drowsy, 6.7ms
# image 171/306 /content/datasets/Driver-Fatigue-2/test/images/458_jpg.rf.44b6f9b17c98d87b478873182e23ef05.jpg: 800x800 1 Drowsy, 6.7ms
# image 172/306 /content/datasets/Driver-Fatigue-2/test/images/486_jpg.rf.3ecf930ddb532612a209e9e41edb6e12.jpg: 800x800 1 Drowsy, 6.7ms
# image 173/306 /content/datasets/Driver-Fatigue-2/test/images/497_jpg.rf.08054b5c1a441489efa198e762761ae4.jpg: 800x800 1 Drowsy, 6.6ms
# image 174/306 /content/datasets/Driver-Fatigue-2/test/images/522_jpg.rf.d04c20c7497ce4b0e344ba36e7909d29.jpg: 800x800 1 Drowsy, 6.7ms
# image 175/306 /content/datasets/Driver-Fatigue-2/test/images/572_jpg.rf.59851c3071de4337916d1097f17f8947.jpg: 800x800 1 Awake, 6.6ms
# image 176/306 /content/datasets/Driver-Fatigue-2/test/images/610_jpg.rf.275c5632b9344252e2cc1b1216696906.jpg: 800x800 1 Awake, 6.5ms
# image 177/306 /content/datasets/Driver-Fatigue-2/test/images/623_jpg.rf.fa57c9482d0a9b965a93e911f627c633.jpg: 800x800 1 Awake, 6.7ms
# image 178/306 /content/datasets/Driver-Fatigue-2/test/images/658_jpg.rf.a8be11315081288a2a8a0a52823a5d6b.jpg: 800x800 1 Awake, 6.5ms
# image 179/306 /content/datasets/Driver-Fatigue-2/test/images/791_jpg.rf.b3fe71079d4fb0cf82bc0838b14b0785.jpg: 800x800 1 Awake, 6.6ms
# image 180/306 /content/datasets/Driver-Fatigue-2/test/images/793_jpg.rf.5635de73ac05dd4f10f136a76244f6b9.jpg: 800x800 1 Awake, 6.7ms
# image 181/306 /content/datasets/Driver-Fatigue-2/test/images/866_jpg.rf.9999f7ca00ac35d42b47b96eac319064.jpg: 800x800 1 Awake, 6.7ms
# image 182/306 /content/datasets/Driver-Fatigue-2/test/images/867_jpg.rf.72f26a1871d520094d64b77be14c3be9.jpg: 800x800 1 Awake, 6.8ms
# image 183/306 /content/datasets/Driver-Fatigue-2/test/images/900_jpg.rf.7b5ee48c0241a689df95434b67a6d922.jpg: 800x800 1 Awake, 6.8ms
# image 184/306 /content/datasets/Driver-Fatigue-2/test/images/919_jpg.rf.b0f47a052c9c8d9c1105d2c633da123c.jpg: 800x800 1 Awake, 6.8ms
# image 185/306 /content/datasets/Driver-Fatigue-2/test/images/997_jpg.rf.3c59a5c74e387b70f758a4de917254b1.jpg: 800x800 1 Awake, 6.8ms
# image 186/306 /content/datasets/Driver-Fatigue-2/test/images/998_jpg.rf.ebb476cb7dfc82de3a582227bbe37526.jpg: 800x800 1 Awake, 6.9ms
# image 187/306 /content/datasets/Driver-Fatigue-2/test/images/Bao0_jpg.rf.5445e1743433dd151010effdb8023183.jpg: 800x800 1 Drowsy, 6.9ms
# image 188/306 /content/datasets/Driver-Fatigue-2/test/images/Bao14_jpg.rf.5e2749319a8a3e8b3f5404554d64d252.jpg: 800x800 1 Drowsy, 6.8ms
# image 189/306 /content/datasets/Driver-Fatigue-2/test/images/Bao15_jpg.rf.a88cf930f262f36989f1c780b0ed6754.jpg: 800x800 1 Drowsy, 6.8ms
# image 190/306 /content/datasets/Driver-Fatigue-2/test/images/Bao44_jpg.rf.a673e4d8d0b8270c93aadab41d081f18.jpg: 800x800 1 Awake, 6.8ms
# image 191/306 /content/datasets/Driver-Fatigue-2/test/images/Bao4_jpg.rf.203cf21306d7b97e92462894a13676f0.jpg: 800x800 1 Drowsy, 6.7ms
# image 192/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105210649_jpg.rf.cd61de2ef2359962dd8f667f02312a70.jpg: 800x800 1 Awake, 6.8ms
# image 193/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105210659_jpg.rf.f2d60c8a752017153a9b22f15fd7fdba.jpg: 800x800 1 Awake, 6.6ms
# image 194/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105210931_jpg.rf.91fb9693767019e95069dc285da317c1.jpg: 800x800 1 Drowsy, 6.7ms
# image 195/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105210950_jpg.rf.6205fbaa4e45b9e470de7f24bc352204.jpg: 800x800 1 Drowsy, 6.6ms
# image 196/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105210952_jpg.rf.6d35722de4b78303b122826e924e3496.jpg: 800x800 1 Drowsy, 6.6ms
# image 197/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211033_jpg.rf.4f08a3adf125cede50f0c596669343ec.jpg: 800x800 1 Drowsy, 6.6ms
# image 198/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211259_jpg.rf.bbf69a06d74d29a72163d69b4ab97b77.jpg: 800x800 1 Awake, 6.7ms
# image 199/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211502_jpg.rf.c9064f1c26d8b364dd2d3bc0fb829602.jpg: 800x800 1 Awake, 6.6ms
# image 200/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211508_jpg.rf.c49b4c02ddfe775e4cd150e81abf49aa.jpg: 800x800 1 Awake, 6.6ms
# image 201/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211531_jpg.rf.2e32b7db29ef69f318499e77459b28e8.jpg: 800x800 1 Awake, 7.2ms
# image 202/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211534_jpg.rf.f55fddae5d3111065bec2270479589d8.jpg: 800x800 1 Awake, 7.0ms
# image 203/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211632_jpg.rf.8ed2af81ccbc7d0487c4adb2a5a5347e.jpg: 800x800 1 Drowsy, 6.8ms
# image 204/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211704_jpg.rf.61ee270cd3a127ec8941aa1541ea7703.jpg: 800x800 1 Drowsy, 6.9ms
# image 205/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211713_jpg.rf.e3077ddc60984c05a23b537b84a58a22.jpg: 800x800 1 Drowsy, 6.9ms
# image 206/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211722_jpg.rf.ff21f4b7d1fad7477b371dddcff51da6.jpg: 800x800 1 Drowsy, 6.8ms
# image 207/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211726_jpg.rf.0a09fbb097089c0784d6e0a137aacf39.jpg: 800x800 1 Drowsy, 6.7ms
# image 208/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211736_jpg.rf.16baba9a217ae550cfbb83b8fb6557bb.jpg: 800x800 1 Drowsy, 6.6ms
# image 209/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211745_jpg.rf.47176d03985ff35d3c2fda93f1925b63.jpg: 800x800 1 Drowsy, 6.6ms
# image 210/306 /content/datasets/Driver-Fatigue-2/test/images/IMG20240105211830_jpg.rf.1ef65f9953c540d87ead39163c2ee623.jpg: 800x800 1 Drowsy, 6.8ms
# image 211/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4052_jpg.rf.da2d15fae36a3ad388f00353d5ed338c.jpg: 800x800 1 Awake, 6.6ms
# image 212/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4055_jpg.rf.c72bf1784c74a25ffca652a425c8ed72.jpg: 800x800 1 Awake, 6.6ms
# image 213/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4067_jpg.rf.28014c3ca4a68845fdfbf380257db800.jpg: 800x800 1 Awake, 7.4ms
# image 214/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4070_jpg.rf.c3e85e10dcf8b19604084b86aa2a8351.jpg: 800x800 1 Awake, 6.7ms
# image 215/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4071_jpg.rf.500fa090c23d21cecba345053e3e0312.jpg: 800x800 1 Awake, 6.8ms
# image 216/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4080_jpg.rf.9e97d352275ff89139c1deec63d943d0.jpg: 800x800 1 Awake, 6.8ms
# image 217/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4100_jpg.rf.152328b16311d2c01251921973adc3bb.jpg: 800x800 1 Awake, 6.8ms
# image 218/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4107_jpg.rf.cfaca3e420313286b3e28c596600c97d.jpg: 800x800 1 Awake, 6.8ms
# image 219/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4116_jpg.rf.46f15e84bc08520388734609efd23e49.jpg: 800x800 1 Awake, 6.7ms
# image 220/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4125_jpg.rf.6f775199d4c0fc59ef678b4def44ee5f.jpg: 800x800 1 Awake, 6.7ms
# image 221/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4129_jpg.rf.203018ffe61fda20e4e73abc58f9855f.jpg: 800x800 1 Awake, 6.7ms
# image 222/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4138_jpg.rf.d0d7de9ade0eca5c47fe519ae6b2ef24.jpg: 800x800 1 Drowsy, 6.8ms
# image 223/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4143_jpg.rf.a444cd3900bc86848cd07f094f35ddfa.jpg: 800x800 1 Drowsy, 6.6ms
# image 224/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4147_jpg.rf.bba7e9660775ce945f76328a2ccc9aac.jpg: 800x800 1 Drowsy, 6.7ms
# image 225/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_4151_jpg.rf.f2a4330803561952f15108d609bd1080.jpg: 800x800 1 Drowsy, 7.1ms
# image 226/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6942_JPG.rf.da5c3092038ec8c9b9511941fc02825b.jpg: 800x800 1 Drowsy, 6.6ms
# image 227/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6951_JPG.rf.abec41f19844b4e4e6b4a7f0f88d37b2.jpg: 800x800 1 Awake, 6.8ms
# image 228/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6956_JPG.rf.4429e02ccbb60eab47952ad50fb6bc81.jpg: 800x800 1 Drowsy, 6.7ms
# image 229/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6970_JPG.rf.4f01635518f3f0aa1e6a57b723e65bc0.jpg: 800x800 1 Drowsy, 6.5ms
# image 230/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6978_JPG.rf.74a154aee2a59e26f3d3543d0ec8eb16.jpg: 800x800 1 Awake, 6.5ms
# image 231/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6981_JPG.rf.be53f859fc8e449a245ec711ed603312.jpg: 800x800 1 Awake, 6.4ms
# image 232/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6984_JPG.rf.dee52bf1c984dd72626910c5e6d98c80.jpg: 800x800 1 Awake, 1 Drowsy, 6.4ms
# image 233/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6987_JPG.rf.77e8232c2cce51105591183113bb3939.jpg: 800x800 1 Awake, 6.8ms
# image 234/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6991_JPG.rf.b6697a64bdf1ea506827a1c217879c3c.jpg: 800x800 1 Awake, 6.4ms
# image 235/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6993_JPG.rf.5ab7fec45ef6a14a017213e539bfb6e0.jpg: 800x800 1 Awake, 6.4ms
# image 236/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_6996_JPG.rf.42c4276cb9e481716793b74bbe041ef4.jpg: 800x800 1 Awake, 6.4ms
# image 237/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_7006_JPG.rf.63c6304384ee02bc19797e367febd550.jpg: 800x800 1 Drowsy, 6.4ms
# image 238/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_7019_JPG.rf.f4215007bf0dce7b942a4c25c566487c.jpg: 800x800 1 Awake, 7.0ms
# image 239/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_7021_JPG.rf.10e9a52de700c20505c3ee1ccf4b3e9b.jpg: 800x800 1 Awake, 6.7ms
# image 240/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_7034_JPG.rf.55795cf0bb5a450cbf685600f9f36ed8.jpg: 800x800 1 Awake, 1 Drowsy, 6.7ms
# image 241/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_7053_JPG.rf.18c305441b1299949a5999528cff1725.jpg: 800x800 1 Awake, 6.8ms
# image 242/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_7108_JPG.rf.9e361868b410635089ee68d52f7faa59.jpg: 800x800 1 Drowsy, 6.6ms
# image 243/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_7123_JPG.rf.1a2d1849a9a8eddef014fb9d64d43924.jpg: 800x800 1 Drowsy, 6.6ms
# image 244/306 /content/datasets/Driver-Fatigue-2/test/images/IMG_7145_JPG.rf.014e6af5c761a2753b7fefa4fd903874.jpg: 800x800 1 Drowsy, 6.6ms
# image 245/306 /content/datasets/Driver-Fatigue-2/test/images/Long9_jpg.rf.693918532e5e132cd6f8daec7f7ef921.jpg: 800x800 1 Drowsy, 6.5ms
# image 246/306 /content/datasets/Driver-Fatigue-2/test/images/Nam12_jpg.rf.43012450dc99314fbb78c296f8b6c9fa.jpg: 800x800 1 Drowsy, 6.5ms
# image 247/306 /content/datasets/Driver-Fatigue-2/test/images/Nam14_jpg.rf.3cb187e126e4aacc7213a189518ed85c.jpg: 800x800 1 Drowsy, 6.5ms
# image 248/306 /content/datasets/Driver-Fatigue-2/test/images/Nam37_jpg.rf.88bb993c5bd2854a43968b308c18132b.jpg: 800x800 1 Drowsy, 6.4ms
# image 249/306 /content/datasets/Driver-Fatigue-2/test/images/Nam47_jpg.rf.f5a2f64094db40ef08dc07dd7cc03f0d.jpg: 800x800 1 Drowsy, 6.7ms
# image 250/306 /content/datasets/Driver-Fatigue-2/test/images/Nam49_jpg.rf.d71e18f40716ca7f53272a9785cb14f0.jpg: 800x800 1 Drowsy, 7.3ms
# image 251/306 /content/datasets/Driver-Fatigue-2/test/images/Nguyen0_jpg.rf.5a1b0c85795b9d251136c519735141ef.jpg: 800x800 1 Drowsy, 6.7ms
# image 252/306 /content/datasets/Driver-Fatigue-2/test/images/Nguyen28_jpg.rf.6157591bb416b38d3f220a35505d17bb.jpg: 800x800 1 Drowsy, 6.7ms
# image 253/306 /content/datasets/Driver-Fatigue-2/test/images/Phong12_jpg.rf.4d4f1e1d2d5670b723ada992fb6d42be.jpg: 800x800 1 Drowsy, 6.8ms
# image 254/306 /content/datasets/Driver-Fatigue-2/test/images/Phong2_jpg.rf.c265245356142d2a4820b41664674113.jpg: 800x800 1 Drowsy, 6.7ms
# image 255/306 /content/datasets/Driver-Fatigue-2/test/images/Phong36_jpg.rf.0fd4c519bba047d6333ffb46f716600b.jpg: 800x800 1 Drowsy, 6.7ms
# image 256/306 /content/datasets/Driver-Fatigue-2/test/images/Phong49_jpg.rf.1952e7306db2eddf6c61ee095abda3ba.jpg: 800x800 1 Drowsy, 6.7ms
# image 257/306 /content/datasets/Driver-Fatigue-2/test/images/Phong7_jpg.rf.8f0261b6391514e14f2a80e3f5f9328e.jpg: 800x800 1 Drowsy, 6.6ms
# image 258/306 /content/datasets/Driver-Fatigue-2/test/images/Si7_jpg.rf.7dc9e354d8c46242bc33cb9dcff1aef7.jpg: 800x800 1 Drowsy, 6.6ms
# image 259/306 /content/datasets/Driver-Fatigue-2/test/images/Tam10_jpg.rf.3985b8a78364281a88092a9fdb8b7b6d.jpg: 800x800 1 Drowsy, 6.7ms
# image 260/306 /content/datasets/Driver-Fatigue-2/test/images/Tam32_jpg.rf.010c61b496052361ce1bf72a6bef0ab7.jpg: 800x800 1 Drowsy, 6.7ms
# image 261/306 /content/datasets/Driver-Fatigue-2/test/images/Tam36_jpg.rf.90e947dade9bd1174f8716da4d07ff78.jpg: 800x800 1 Drowsy, 6.6ms
# image 262/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao11_jpg.rf.82d758291a8133dfff5abb6af89daa59.jpg: 800x800 1 Awake, 1 Drowsy, 6.7ms
# image 263/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao15_jpg.rf.873d0b7af2559918817e7337de1d66fe.jpg: 800x800 1 Awake, 6.7ms
# image 264/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao22_jpg.rf.237b6b61bd259ea31de9f1edd3ca406b.jpg: 800x800 1 Awake, 6.8ms
# image 265/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao23_jpg.rf.4c12fafdd190d9bfa8190a720eee3ebb.jpg: 800x800 1 Drowsy, 6.7ms
# image 266/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao28_jpg.rf.02a083953bc0de89cbaee2ae8bf70bff.jpg: 800x800 1 Awake, 6.5ms
# image 267/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao31_jpg.rf.3929c29b533da9da92a72c0872905caa.jpg: 800x800 1 Awake, 6.4ms
# image 268/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao43_jpg.rf.21644796782dd58d6d3ab26725742b20.jpg: 800x800 1 Awake, 6.5ms
# image 269/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao45_jpg.rf.f04b5e98668394190af0c2cbc3cca5c4.jpg: 800x800 1 Awake, 6.4ms
# image 270/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Bao47_jpg.rf.6175eeea3f53a6098c7eb39ef289b316.jpg: 800x800 1 Awake, 6.4ms
# image 271/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Long14_jpg.rf.e82baea0818ad8092336e335cf7338b6.jpg: 800x800 1 Awake, 6.4ms
# image 272/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Long21_jpg.rf.52f35f98b692578476b3c7073f6964e4.jpg: 800x800 1 Awake, 6.4ms
# image 273/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Long24_jpg.rf.df187997bc30f99b699137eac7c2f399.jpg: 800x800 1 Awake, 6.4ms
# image 274/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Long8_jpg.rf.5cc8c99776e194b7ca4f15d0b186bc0d.jpg: 800x800 1 Drowsy, 7.1ms
# image 275/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nam16_jpg.rf.ad3196da7c49d0412d73cac9d7403f52.jpg: 800x800 1 Awake, 6.5ms
# image 276/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nam24_jpg.rf.890ed86d8e9fdcc97f6fb07d0156547f.jpg: 800x800 1 Awake, 6.5ms
# image 277/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nam26_jpg.rf.aa5d80d880c79baa9aae9a703c40e0a6.jpg: 800x800 1 Awake, 6.6ms
# image 278/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nam30_jpg.rf.64c1e08f62a9c725b47b70d5a3527223.jpg: 800x800 1 Awake, 6.7ms
# image 279/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nam39_jpg.rf.045e5842db7cd593c767f5fab3c74122.jpg: 800x800 1 Awake, 6.7ms
# image 280/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nam46_jpg.rf.50f9edaf66ffb3d5ff149de541256725.jpg: 800x800 1 Awake, 6.5ms
# image 281/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nam8_jpg.rf.69b32ff1e6d660e82c98efaf57b4883a.jpg: 800x800 1 Awake, 6.6ms
# image 282/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nguyen19_jpg.rf.ca1fe0f72484d6b4670742c7930f56c4.jpg: 800x800 1 Awake, 6.6ms
# image 283/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nguyen21_jpg.rf.272da62359a43eeba6bb3ad0e9497fa4.jpg: 800x800 1 Awake, 6.6ms
# image 284/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nguyen44_jpg.rf.b50c992b430a71746cb0a19252d310a4.jpg: 800x800 1 Awake, 6.7ms
# image 285/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Nguyen8_jpg.rf.307b9f024fc5eb7ab251558817858874.jpg: 800x800 1 Awake, 6.7ms
# image 286/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Phong25_jpg.rf.b52fa88faf2cdfe2942eda7b07829967.jpg: 800x800 1 Awake, 7.2ms
# image 287/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Phong29_jpg.rf.960412e6d6323e014608aca7c9eaac7d.jpg: 800x800 1 Awake, 6.6ms
# image 288/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Phong35_jpg.rf.3b16944be4f0e43f186e9a5819783db1.jpg: 800x800 1 Awake, 6.6ms
# image 289/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Phong5_jpg.rf.e3a614b9b548ee3374388ac3273ea0f3.jpg: 800x800 1 Awake, 6.6ms
# image 290/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si14_jpg.rf.3ecff54f25e88f61d693e286d96d3572.jpg: 800x800 1 Awake, 6.6ms
# image 291/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si25_jpg.rf.d1594b690816d6d53a0dc091626d98b8.jpg: 800x800 1 Awake, 6.8ms
# image 292/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si27_jpg.rf.f6b98f1758f29c30f55c16175c352158.jpg: 800x800 1 Awake, 6.6ms
# image 293/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si29_jpg.rf.a1f18898fa5c87eafcf5af37111d7d1b.jpg: 800x800 1 Awake, 6.6ms
# image 294/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si3_jpg.rf.5d2dcb85f35571b4934bf83b2efbceb4.jpg: 800x800 1 Awake, 6.9ms
# image 295/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si73_jpg.rf.cf408f300d34ceec4aff64eeec1a2e61.jpg: 800x800 1 Awake, 6.9ms
# image 296/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si91_jpg.rf.40ffd5f19f6b42dea4b74aefb40236d4.jpg: 800x800 1 Awake, 7.0ms
# image 297/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si92_jpg.rf.587371f9e22ee06304124edc4fc226f3.jpg: 800x800 1 Awake, 6.9ms
# image 298/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si93_jpg.rf.60c104e3bbefb110a9565845ce101287.jpg: 800x800 1 Awake, 7.8ms
# image 299/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Si97_jpg.rf.1a8862d14866e7787e82b5e23dbee17b.jpg: 800x800 1 Awake, 6.8ms
# image 300/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Tam29_jpg.rf.c98069f3145158e97ebe042bb0da9992.jpg: 800x800 1 Awake, 6.9ms
# image 301/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Tam32_jpg.rf.42f160b441994163304153c9b48edcd9.jpg: 800x800 1 Awake, 6.9ms
# image 302/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Tam41_jpg.rf.1e5b2df29f56693c66f1fd3505bb00da.jpg: 800x800 1 Awake, 6.9ms
# image 303/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Tam46_jpg.rf.e7a1ade84d6c3ef96b16c73261952c01.jpg: 800x800 1 Awake, 6.7ms
# image 304/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Tam49_jpg.rf.553fec988ca789ecf7c5047c36ce9a6b.jpg: 800x800 1 Awake, 6.7ms
# image 305/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Tam7_jpg.rf.73290169849570e05671a74484f1e399.jpg: 800x800 1 Awake, 6.8ms
# image 306/306 /content/datasets/Driver-Fatigue-2/test/images/tinh_Tam9_jpg.rf.3394c5aa73403a96301068c72885eb87.jpg: 800x800 1 Awake, 7.1ms
# Speed: 3.9ms preprocess, 6.8ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.103, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/final-ai-solution-p79og/driver-fatigue/2
# Share your model with the world at: https://universe.roboflow.com/final-ai-solution-p79og/driver-fatigue/model/2

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-afd7f5f31b70> in <cell line: 0>()
#       3 # Load model
#       4 model = project.version(dataset.version).model
# ----> 5 assert model, "Model deployment is still loading"
#       6
#       7 # Choose a random test image
#
# AssertionError: Model deployment is still loading

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/runs
# Out:
# /content/runs

# %%
# !zip -r drowsy.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/dog.jpeg (deflated 6%)
#   adding: content/runs/detect/predict2/ (stored 0%)
#   adding: content/runs/detect/predict2/IMG_4125_jpg.rf.6f775199d4c0fc59ef678b4def44ee5f.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/IMG_6993_JPG.rf.5ab7fec45ef6a14a017213e539bfb6e0.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105210952_jpg.rf.6d35722de4b78303b122826e924e3496.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Bao11_jpg.rf.82d758291a8133dfff5abb6af89daa59.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-141239_jpg.rf.1493ea19dd1304abca1aa163399983b8.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-091420_jpg.rf.5d3b5ef3f7b61ef5530993b374f570fd.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-145327_jpg.rf.1336a3a6daa4bebeba475cdc2eb0ecf9.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_7053_JPG.rf.18c305441b1299949a5999528cff1725.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221024-094716_jpg.rf.6928182f66db7d33c316e65b49c92627.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/497_jpg.rf.08054b5c1a441489efa198e762761ae4.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Bao15_jpg.rf.873d0b7af2559918817e7337de1d66fe.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221024-095347_jpg.rf.a282cb639f576e5232315cbfafdfa8bc.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/IMG_4080_jpg.rf.9e97d352275ff89139c1deec63d943d0.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/Nam49_jpg.rf.d71e18f40716ca7f53272a9785cb14f0.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/264_jpg.rf.ff6795331d97fc8dad63b6606bcc7749.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/2429_jpg.rf.d6dbd0b2beaf7135514cd09164f694e4.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221024-093529_jpg.rf.6863c697fed8c38ac7a9f15bfc2e1113.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-141356_jpg.rf.ffa1435ca854a3d052a13e0e4018981e.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-141549_jpg.rf.bbe1adf00dbc4a081dc3ec46714879fa.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105211534_jpg.rf.f55fddae5d3111065bec2270479589d8.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/IMG_7123_JPG.rf.1a2d1849a9a8eddef014fb9d64d43924.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/658_jpg.rf.a8be11315081288a2a8a0a52823a5d6b.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/1768_jpg.rf.549e3509e0124ca57f2eb579859943d1.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105211830_jpg.rf.1ef65f9953c540d87ead39163c2ee623.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/1878_jpg.rf.9ffa49ea112125ed33c08d22beaf6f85.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221024-095157_jpg.rf.c7653e25f0f885cb917b557963976e5c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092049_jpg.rf.7aade474371c835b748c7f6a410479f5.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1738_jpg.rf.02dcfd237b0f5f4e19c7ecb9e59c9597.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-092155_jpg.rf.0c6f05db621a636ddaca6a284112ba69.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Si3_jpg.rf.5d2dcb85f35571b4934bf83b2efbceb4.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/458_jpg.rf.44b6f9b17c98d87b478873182e23ef05.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG20240105211531_jpg.rf.2e32b7db29ef69f318499e77459b28e8.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/249_jpg.rf.c3a9e446d9831022a2f073f619ec13bc.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/610_jpg.rf.275c5632b9344252e2cc1b1216696906.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG20240105211704_jpg.rf.61ee270cd3a127ec8941aa1541ea7703.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/221024-095248_jpg.rf.e74383267db0ef144cfbceb752410c6c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-093123_jpg.rf.7a3fff11f10434899ac7203e861cd764.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Tam36_jpg.rf.90e947dade9bd1174f8716da4d07ff78.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/998_jpg.rf.ebb476cb7dfc82de3a582227bbe37526.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-141224_jpg.rf.357d58721a8dd9f891181d4a5e92f0c7.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/2087_jpg.rf.fe9e4c1e6aa3a546702c477127f8948d.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Tam7_jpg.rf.73290169849570e05671a74484f1e399.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-091831_jpg.rf.84a3a34610adb26acea967741293df69.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-093949_jpg.rf.1b70b666a08d76cbd516119c3464a486.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-091723_jpg.rf.3a819e64bcc9dca1a68d0a119edc315b.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Nam37_jpg.rf.88bb993c5bd2854a43968b308c18132b.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/36_jpg.rf.81ca607f63f2118bf360fac4128202eb.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-094137_jpg.rf.be831487315251a6c31776d212a429cd.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092031_jpg.rf.6e964bd35c9447b805e248a09129ab60.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-143340_jpg.rf.7f32602e46686de6247007e7755ea821.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Long24_jpg.rf.df187997bc30f99b699137eac7c2f399.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/1462_jpg.rf.e91e208fbc41d6b82f02f3fcf96ea03d.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Si92_jpg.rf.587371f9e22ee06304124edc4fc226f3.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-145432_jpg.rf.c372efb21aaaa7cc9da57b658a3d2b48.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_4100_jpg.rf.152328b16311d2c01251921973adc3bb.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/221023-145053_jpg.rf.d4919206587ea8ff600106f49f3f5791.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105211259_jpg.rf.bbf69a06d74d29a72163d69b4ab97b77.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/230_jpg.rf.b5083ed8822c048ae8e98815ca86fe5c.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/Nam12_jpg.rf.43012450dc99314fbb78c296f8b6c9fa.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/IMG_7006_JPG.rf.63c6304384ee02bc19797e367febd550.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Nguyen28_jpg.rf.6157591bb416b38d3f220a35505d17bb.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-092203_jpg.rf.a9649a6b8de6bd746c4838365321b24a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/42_jpg.rf.0ac83d6a498ec5f00c534f91f65eb417.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-141533_jpg.rf.6d31784c389fdd24bd4512cef2737e02.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-141237_jpg.rf.451030c4a8af45dbf5e98c3ef68d8863.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Nam30_jpg.rf.64c1e08f62a9c725b47b70d5a3527223.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-145359_jpg.rf.f353aaa0c2c32dd4e2dc678386c7498a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/338_jpg.rf.7adc1194a1ae08af9991c07605b886de.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Nguyen21_jpg.rf.272da62359a43eeba6bb3ad0e9497fa4.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221024-095201_jpg.rf.4eddd2f9394951d93f57e8ce107e1442.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/265_jpg.rf.2a7221ecc07c8339c0bfb6350b52f1c0.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Si27_jpg.rf.f6b98f1758f29c30f55c16175c352158.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-092115_jpg.rf.9e8fd60cb61448608cfe839c03772772.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1642_jpg.rf.50ea5a72c5a9eea5ca21751db1bb0ba2.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG_6956_JPG.rf.4429e02ccbb60eab47952ad50fb6bc81.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221024-095353_jpg.rf.9fdfd518b06e5717bd836122ce7bfc85.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/486_jpg.rf.3ecf930ddb532612a209e9e41edb6e12.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-142312_jpg.rf.01d35e2b24cbc4b596ebc1a56b9a77a8.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_7108_JPG.rf.9e361868b410635089ee68d52f7faa59.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/2371_jpg.rf.f5d449c460f8f64b058ba126dd7f7882.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-092019_jpg.rf.6a9179384fb494b7b05d62657a097e3a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092142_jpg.rf.93b91972709b82f23a6794a9511d36ec.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_6991_JPG.rf.b6697a64bdf1ea506827a1c217879c3c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Long21_jpg.rf.52f35f98b692578476b3c7073f6964e4.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/900_jpg.rf.7b5ee48c0241a689df95434b67a6d922.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-145136_jpg.rf.4e6558b15b901d697a1c6e54196b3c06.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-142125_jpg.rf.9da60bc7be27444efda09f4ef1b445c2.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092737_jpg.rf.8874bda6e7c6c2b1a4c113bf05c05940.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-094222_jpg.rf.364fd44e4a7abe353031184986ce4d7a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Bao44_jpg.rf.a673e4d8d0b8270c93aadab41d081f18.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221024-095252_jpg.rf.72bff5413b476127f1e8774c0ff674af.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Si7_jpg.rf.7dc9e354d8c46242bc33cb9dcff1aef7.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Tam9_jpg.rf.3394c5aa73403a96301068c72885eb87.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/867_jpg.rf.72f26a1871d520094d64b77be14c3be9.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/216_jpg.rf.ac67fb8f7097de5e93219aa072735e3c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_4070_jpg.rf.c3e85e10dcf8b19604084b86aa2a8351.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/16_jpg.rf.1b2412778f9b01bb24272dde322ea9b9.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-091309_jpg.rf.d7de18c170fbcee208cd8643fdb82e34.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105211726_jpg.rf.0a09fbb097089c0784d6e0a137aacf39.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-144001_jpg.rf.5b46658567e22b05196560eee4b8a9c3.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221024-094403_jpg.rf.5be4cc28bc1bb99bb70f56fe92c8f0f1.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-144300_jpg.rf.6cd6e34c013677f167ae838651f3867c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Tam46_jpg.rf.e7a1ade84d6c3ef96b16c73261952c01.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Tam29_jpg.rf.c98069f3145158e97ebe042bb0da9992.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-140341_jpg.rf.d1c7a27e076d83115555ba223f594c07.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-145356_jpg.rf.2a9e88fff502269459c26a20e63980d7.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_6942_JPG.rf.da5c3092038ec8c9b9511941fc02825b.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/315_jpg.rf.e22a5f0ce85040ea94c6dec1a99a9774.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG_4116_jpg.rf.46f15e84bc08520388734609efd23e49.jpg (deflated 9%)
#   adding: content/runs/detect/predict2/221023-141048_jpg.rf.818ec9c31d169057df7681404a55851c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_4147_jpg.rf.bba7e9660775ce945f76328a2ccc9aac.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/tinh_Phong5_jpg.rf.e3a614b9b548ee3374388ac3273ea0f3.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-145117_jpg.rf.0007562011b53da01d6d67169ff3f725.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092124_jpg.rf.4419823fddd3a64d9cc9ef5becf7a098.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/919_jpg.rf.b0f47a052c9c8d9c1105d2c633da123c.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-143326_jpg.rf.8c11d214cb9e6015cc1f30a2b2e9d559.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Phong2_jpg.rf.c265245356142d2a4820b41664674113.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Bao23_jpg.rf.4c12fafdd190d9bfa8190a720eee3ebb.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/149_jpg.rf.6b229426efc3f8c7991cf370c05392fd.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/221023-141547_jpg.rf.cf000e0ff10b4220e63fad270639e3fc.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-094022_jpg.rf.91df108da89c359c6d329b3e5fadc4ed.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092116_jpg.rf.df661a7496bd3893b800f4a8944dd570.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-143809_jpg.rf.ff500bd1d3a321773e232a27f45dc129.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-141455_jpg.rf.df68e8da0d58004e4a31d8423aec73c7.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_7021_JPG.rf.10e9a52de700c20505c3ee1ccf4b3e9b.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/2584_jpg.rf.ce93e577c90adeacc873726315391dd5.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/369_jpg.rf.784b796cdc8b08a25312f8b9f9261556.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-140716_jpg.rf.6be01356cb2732c4dd23861e242b24b9.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Bao0_jpg.rf.5445e1743433dd151010effdb8023183.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/IMG_4138_jpg.rf.d0d7de9ade0eca5c47fe519ae6b2ef24.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/793_jpg.rf.5635de73ac05dd4f10f136a76244f6b9.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-141601_jpg.rf.92cfadb712d8c98103cf922db860b1ef.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092114_jpg.rf.9832e0ea78ddb869e36cdefa50a18dbc.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1701_jpg.rf.656b8a41dceb7532307b151dc8fe8e2e.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/2518_jpg.rf.2b62e3e3e367f62b50f336a7dcf29178.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/Phong12_jpg.rf.4d4f1e1d2d5670b723ada992fb6d42be.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Si25_jpg.rf.d1594b690816d6d53a0dc091626d98b8.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-140400_jpg.rf.67243d5bbfe34a9fed34a012fc5b7c01.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-144221_jpg.rf.bc9bca10c5c5a3cdc55df0e8623149ea.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_7019_JPG.rf.f4215007bf0dce7b942a4c25c566487c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-144103_jpg.rf.28072a4d0cd051a19f0e6c6e21eab281.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092131_jpg.rf.7d76f95a9a463ba8f03803a7b3cf52ed.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_6984_JPG.rf.dee52bf1c984dd72626910c5e6d98c80.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Si73_jpg.rf.cf408f300d34ceec4aff64eeec1a2e61.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/2136_jpg.rf.79cb25e79dfffecd2d250611b3d935f0.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/791_jpg.rf.b3fe71079d4fb0cf82bc0838b14b0785.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1900_jpg.rf.91d2553e6a741a7ed59d556547c425f4.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Si97_jpg.rf.1a8862d14866e7787e82b5e23dbee17b.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Phong29_jpg.rf.960412e6d6323e014608aca7c9eaac7d.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-092030_jpg.rf.cf510a59f25ba214a3c1d85510769e35.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105210649_jpg.rf.cd61de2ef2359962dd8f667f02312a70.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG_7145_JPG.rf.014e6af5c761a2753b7fefa4fd903874.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-093706_jpg.rf.19d8ef10ace2dbe57b60b39d476daced.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1967_jpg.rf.5a47077e577cfb1d8f00e92c0953584b.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Nam16_jpg.rf.ad3196da7c49d0412d73cac9d7403f52.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-092032_jpg.rf.d0dd9c21d9f6818a5a17c0b37d91cc8f.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-141241_jpg.rf.a17b394294eaf17f16ffd0212554a480.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Nam47_jpg.rf.f5a2f64094db40ef08dc07dd7cc03f0d.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/2610_jpg.rf.8246519ef11172272fc35b4b567b0660.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Bao15_jpg.rf.a88cf930f262f36989f1c780b0ed6754.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Bao31_jpg.rf.3929c29b533da9da92a72c0872905caa.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Bao47_jpg.rf.6175eeea3f53a6098c7eb39ef289b316.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Nam46_jpg.rf.50f9edaf66ffb3d5ff149de541256725.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/32_jpg.rf.f947a03ab6ae6e1767c1a4260e7948fd.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-093719_jpg.rf.a84307fc0fa0596b8659a658936bde45.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Phong7_jpg.rf.8f0261b6391514e14f2a80e3f5f9328e.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/1629_jpg.rf.3dd6f293591125d273605d3ba99a9924.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-142747_jpg.rf.37f9aa7008c234a5188e69aeaa34bc76.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1007_jpg.rf.087411387508aa1d602475c840be86aa.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/Nguyen0_jpg.rf.5a1b0c85795b9d251136c519735141ef.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-140405_jpg.rf.9075ba8ebd43144f2cdddb201a5bc849.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-093221_jpg.rf.893de57520b4477701bb32b7fc352d2b.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1871_jpg.rf.0c03c7e8782502aa9bede4b87081b3b0.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Bao28_jpg.rf.02a083953bc0de89cbaee2ae8bf70bff.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Nguyen8_jpg.rf.307b9f024fc5eb7ab251558817858874.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Nguyen44_jpg.rf.b50c992b430a71746cb0a19252d310a4.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/280_jpg.rf.8dd48f6596c7348e8418cfc2702e57df.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/2131_jpg.rf.55b6a8516fdf35f791bcbea80736e278.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/226_jpg.rf.2190117ac123ecc4e3456716911adba0.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/997_jpg.rf.3c59a5c74e387b70f758a4de917254b1.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-092923_jpg.rf.8854d190d9a881977696f5e21987541a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_7034_JPG.rf.55795cf0bb5a450cbf685600f9f36ed8.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Si14_jpg.rf.3ecff54f25e88f61d693e286d96d3572.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/IMG20240105211502_jpg.rf.c9064f1c26d8b364dd2d3bc0fb829602.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/221023-093731_jpg.rf.de69024d094232af5168c58b7a013a49.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Tam32_jpg.rf.42f160b441994163304153c9b48edcd9.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/IMG_4129_jpg.rf.203018ffe61fda20e4e73abc58f9855f.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/Long9_jpg.rf.693918532e5e132cd6f8daec7f7ef921.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-141429_jpg.rf.bd89414452e58ae04cc3e2da6328e554.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092037_jpg.rf.859d3e06277f30bdde03ffee52c071b8.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Long8_jpg.rf.5cc8c99776e194b7ca4f15d0b186bc0d.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-094041_jpg.rf.e0285444466fd8e3d53c8ea1ca784697.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-145639_jpg.rf.9b417f9c38fea2329c36b4ae941cca79.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_6987_JPG.rf.77e8232c2cce51105591183113bb3939.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-093209_jpg.rf.f1749d437563d29b543ae82a609f8670.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Nam24_jpg.rf.890ed86d8e9fdcc97f6fb07d0156547f.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-145155_jpg.rf.2bdb2206d1c937d688fdcb7c2332b1ff.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-091722_jpg.rf.6aa568ee91a065a9c73790fe68ca6d96.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105211745_jpg.rf.47176d03985ff35d3c2fda93f1925b63.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/345_jpg.rf.71f942333fb93cc2e6b706cbda2bd3bb.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Bao14_jpg.rf.5e2749319a8a3e8b3f5404554d64d252.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-141109_jpg.rf.90eb8902d4e026e0d85abe92a40e8f66.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Nam8_jpg.rf.69b32ff1e6d660e82c98efaf57b4883a.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/1032_jpg.rf.6d18dee633e3fd077437adcda8aa44f1.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Si29_jpg.rf.a1f18898fa5c87eafcf5af37111d7d1b.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Nam39_jpg.rf.045e5842db7cd593c767f5fab3c74122.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/2409_jpg.rf.1c8389e92c656316f626d6d5e435082f.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG_4052_jpg.rf.da2d15fae36a3ad388f00353d5ed338c.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/374_jpg.rf.64c7b5f4c3fccac01f988cfd23a7bd5e.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Phong25_jpg.rf.b52fa88faf2cdfe2942eda7b07829967.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-145401_jpg.rf.c74057bef8c20b330392cf8bc3071dde.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1369_jpg.rf.51b75a5135a3a5f4713397c8b6b4e75f.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/1937_jpg.rf.08a5eefbe89c64178c19c452fbad6b9c.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG20240105211736_jpg.rf.16baba9a217ae550cfbb83b8fb6557bb.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/221023-093157_jpg.rf.cf5a4fbc0f6f8b5b819d1f7a4d76cc8a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-145325_jpg.rf.7a5e75e22c2dfc060633e49e31c51f98.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-144004_jpg.rf.a6615de903564c7e0724289b8d7183a5.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-091422_jpg.rf.83981b52bf45554d13e3f3b9ea038ecf.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_4067_jpg.rf.28014c3ca4a68845fdfbf380257db800.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/221023-140446_jpg.rf.d002efffb6988548aa31f04c6b12eb0b.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_4071_jpg.rf.500fa090c23d21cecba345053e3e0312.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/tinh_Bao45_jpg.rf.f04b5e98668394190af0c2cbc3cca5c4.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221024-093228_jpg.rf.cd9053504ee6c3db134021f35eac9232.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-093745_jpg.rf.3cdc8371df43e80b0577fdeef5f657fb.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/572_jpg.rf.59851c3071de4337916d1097f17f8947.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/Bao4_jpg.rf.203cf21306d7b97e92462894a13676f0.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/tinh_Tam41_jpg.rf.1e5b2df29f56693c66f1fd3505bb00da.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/356_jpg.rf.9e20fb5dbeda5524c397d694bcaab84e.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-092201_jpg.rf.a775b3e3341ffc99c9475fedda174c71.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_6951_JPG.rf.abec41f19844b4e4e6b4a7f0f88d37b2.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Tam49_jpg.rf.553fec988ca789ecf7c5047c36ce9a6b.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-144921_jpg.rf.4ef72cf801244e9eb1fc844a995cbf8e.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-145623_jpg.rf.9304ef6309e83906d2ef96561629ac1d.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/393_jpg.rf.06b05688343887f60d1bee04294ca885.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/2403_jpg.rf.812046334dd2a64220cdaff0561e9d07.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/332_jpg.rf.c51d0dc05a2a9208de4b65033c4d29e4.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/225_jpg.rf.5bc6a9d146035b957f910ccb81d1be1d.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Si93_jpg.rf.60c104e3bbefb110a9565845ce101287.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-142034_jpg.rf.caceaa4096b839051ff3e0441eff99dc.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105210950_jpg.rf.6205fbaa4e45b9e470de7f24bc352204.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-091429_jpg.rf.7f9100708fa9514787fdbc5ff728d258.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_4055_jpg.rf.c72bf1784c74a25ffca652a425c8ed72.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/400_jpg.rf.397f4df6cdc04dfc9e9745d7bbd421b3.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG_6970_JPG.rf.4f01635518f3f0aa1e6a57b723e65bc0.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/2399_jpg.rf.e74ad92c178da3cce7d0c3e81f671a06.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG20240105211722_jpg.rf.ff21f4b7d1fad7477b371dddcff51da6.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/Phong36_jpg.rf.0fd4c519bba047d6333ffb46f716600b.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/278_jpg.rf.1bb35d170df1d3868db137a8f7a74ab5.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-141546_jpg.rf.66bb683376af39801c199ca4f9eb9865.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_4107_jpg.rf.cfaca3e420313286b3e28c596600c97d.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/130_jpg.rf.6fec9f7b9accbbc3903967520b5f8a9d.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105210931_jpg.rf.91fb9693767019e95069dc285da317c1.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Nam26_jpg.rf.aa5d80d880c79baa9aae9a703c40e0a6.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/256_jpg.rf.c105296f7a70c391f077bca84c71774a.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/Phong49_jpg.rf.1952e7306db2eddf6c61ee095abda3ba.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/Nam14_jpg.rf.3cb187e126e4aacc7213a189518ed85c.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/623_jpg.rf.fa57c9482d0a9b965a93e911f627c633.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/tinh_Si91_jpg.rf.40ffd5f19f6b42dea4b74aefb40236d4.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/2259_jpg.rf.566876736a198582ce1fa267633eeeb3.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG20240105210659_jpg.rf.f2d60c8a752017153a9b22f15fd7fdba.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-094141_jpg.rf.b765e559a1745228d43509037c02f448.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Bao22_jpg.rf.237b6b61bd259ea31de9f1edd3ca406b.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/IMG_4151_jpg.rf.f2a4330803561952f15108d609bd1080.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/522_jpg.rf.d04c20c7497ce4b0e344ba36e7909d29.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-140827_jpg.rf.a754f465f8844727f6bee179908fb594.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/127_jpg.rf.92366ee8fac48b782d20e0987a5bdb2f.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Nguyen19_jpg.rf.ca1fe0f72484d6b4670742c7930f56c4.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/23_jpg.rf.263f0d96eb02335177736f4f803c73ac.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-092736_jpg.rf.c0d9d46e4c102db35a31714eb72c98a8.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/tinh_Bao43_jpg.rf.21644796782dd58d6d3ab26725742b20.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-140801_jpg.rf.8cf8c4db0901190ef060e4e332fe24e9.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-091355_jpg.rf.0052af7ffaefd802070a3d3cdd1feefa.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/2346_jpg.rf.088b7d3aa4857e2a30aba8688f1232b2.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-143841_jpg.rf.beb9690c1049bfe7b9dcdfdf5a60c02f.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-093135_jpg.rf.98bc1b82c66766a4c907237ec89c9796.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1130_jpg.rf.9b30d23462516e7a9ec56b7c2074b5d0.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/1114_jpg.rf.3dda05bd88768438a0ec2e87aa5ff99b.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/tinh_Phong35_jpg.rf.3b16944be4f0e43f186e9a5819783db1.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/117_jpg.rf.459eeb5393a0a4fabf074dbd3103720c.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/1178_jpg.rf.6329e43cc2c2d5336e8984d72b9788c7.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-093407_jpg.rf.7eb9e5a16c7f131f7ff0beb8a0c390f9.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_6978_JPG.rf.74a154aee2a59e26f3d3543d0ec8eb16.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_4143_jpg.rf.a444cd3900bc86848cd07f094f35ddfa.jpg (deflated 10%)
#   adding: content/runs/detect/predict2/2571_jpg.rf.070d0b718c73977a50be2020d7245cb3.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-093154_jpg.rf.3da991e8dbf15b84229b5154bd8f9fb7.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105211033_jpg.rf.4f08a3adf125cede50f0c596669343ec.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-141227_jpg.rf.e5cbfabc01db411303e69a69344ffed6.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-140356_jpg.rf.cb1b0e832412aacbf2913487d7a7da70.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-141600_jpg.rf.5363118335710e7b63e0b8e5e11ba475.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/142_jpg.rf.074b52261a90a85e18fbfa6606469f4f.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/tinh_Long14_jpg.rf.e82baea0818ad8092336e335cf7338b6.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/Tam10_jpg.rf.3985b8a78364281a88092a9fdb8b7b6d.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/IMG_6981_JPG.rf.be53f859fc8e449a245ec711ed603312.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105211632_jpg.rf.8ed2af81ccbc7d0487c4adb2a5a5347e.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/412054364_1157921618504990_6015814173518158205_n_jpg.rf.f7150244de72cc3d014b0d20f9df23b8.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/866_jpg.rf.9999f7ca00ac35d42b47b96eac319064.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-094006_jpg.rf.e5cc4b0a162be387ecc6e7c51eb64270.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1247_jpg.rf.560f80b98911f845aebc5a627d7a6039.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/221023-092753_jpg.rf.ac009fabe1f8e1e8dc92d8ec8c100fd3.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG_6996_JPG.rf.42c4276cb9e481716793b74bbe041ef4.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Tam32_jpg.rf.010c61b496052361ce1bf72a6bef0ab7.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/221023-144214_jpg.rf.0bbb2c9527c3d1e4e9fae632232f1efe.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-142348_jpg.rf.6e7d3deacebe00982ad59746a7453eea.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/221023-145357_jpg.rf.1ee6b5f1369e88fe459d26b6ab338391.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG20240105211508_jpg.rf.c49b4c02ddfe775e4cd150e81abf49aa.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/IMG20240105211713_jpg.rf.e3077ddc60984c05a23b537b84a58a22.jpg (deflated 5%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch5851.jpg (deflated 8%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 33%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train/roboflow_deploy.zip (stored 0%)
#   adding: content/runs/detect/train/R_curve.png (deflated 16%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 3%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 36%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 2%)
#   adding: content/runs/detect/train/results.png (deflated 8%)
#   adding: content/runs/detect/train/P_curve.png (deflated 22%)
#   adding: content/runs/detect/train/labels.jpg (deflated 36%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 16%)
#   adding: content/runs/detect/train/train_batch5852.jpg (deflated 6%)
#   adding: content/runs/detect/train/model_artifacts.json (deflated 64%)
#   adding: content/runs/detect/train/train_batch5850.jpg (deflated 9%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 2%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 35%)
#   adding: content/runs/detect/train/results.csv (deflated 84%)
#   adding: content/runs/detect/train/events.out.tfevents.1737050570.2ccdfd97df25.1254.0 (deflated 91%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/state_dict.pt (deflated 8%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 26%)
#   adding: content/runs/detect/val/ (stored 0%)
#   adding: content/runs/detect/val/val_batch0_labels.jpg (deflated 7%)
#   adding: content/runs/detect/val/confusion_matrix_normalized.png (deflated 33%)
#   adding: content/runs/detect/val/val_batch2_labels.jpg (deflated 8%)
#   adding: content/runs/detect/val/val_batch2_pred.jpg (deflated 7%)
#   adding: content/runs/detect/val/val_batch1_labels.jpg (deflated 7%)
#   adding: content/runs/detect/val/R_curve.png (deflated 16%)
#   adding: content/runs/detect/val/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/val/P_curve.png (deflated 22%)
#   adding: content/runs/detect/val/F1_curve.png (deflated 16%)
#   adding: content/runs/detect/val/confusion_matrix.png (deflated 34%)
#   adding: content/runs/detect/val/val_batch0_pred.jpg (deflated 7%)
#   adding: content/runs/detect/val/PR_curve.png (deflated 26%)

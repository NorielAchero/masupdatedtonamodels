# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the accompanying [Blog Post](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset/).
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Jan 16 19:08:15 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0              44W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 30.8/235.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 69.9MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 58.8MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 50.1ms
# Speed: 15.9ms preprocess, 50.1ms inference, 893.5ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 58.2ms
# Speed: 6.5ms preprocess, 58.2ms inference, 813.5ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.0000,  314.5054,  625.0387, 1278.1901],
#         [  55.3276,  250.0223,  648.1048, 1266.2391],
#         [ 633.2264,  719.5393,  701.0568,  786.0264]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.7269, 0.2905, 0.2843], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a [supported format](https://roboflow.com/formats), the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v8` dataset format. (Formerly, we used to use `Yolov5`, as the gif shows)
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# 🟢 Tip: The examples below work even if you use our non-custom model. However, you won't be able to deploy it to Roboflow. To do that, create a custom dataset as described below or fork (copy) one into your workspace from Universe.

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow==1.1.48 --quiet

import roboflow

roboflow.login()

rf = roboflow.Roboflow()

project = rf.workspace("final-ai-solution").project("weapon-detection-dinou-qdunh-ihnjy")
dataset = project.version(1).download("yolov8")
# Out:
# /content/datasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.4 MB/s eta 0:00:00
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Weapon-Detection-1 to yolov8:: 100%|██████████| 515562/515562 [00:06<00:00, 77935.73it/s]
# Extracting Dataset Version Zip to Weapon-Detection-1 in yolov8:: 100%|██████████| 21490/21490 [00:02<00:00, 7344.47it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 143MB/s]
# New https://pypi.org/project/ultralytics/8.3.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/Weapon-Detection-1/data.yaml, epochs=25, time=None, patience=100, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 13.8MB/s]
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2118370  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# Model summary: 225 layers, 11,137,922 parameters, 11,137,906 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/datasets/Weapon-Detection-1/train/labels... 9891 images, 0 backgrounds, 0 corrupt: 100% 9891/9891 [00:06<00:00, 1430.52it/s]
# train: New cache created: /content/datasets/Weapon-Detection-1/train/labels.cache
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.0 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Weapon-Detection-1/valid/labels... 582 images, 0 backgrounds, 0 corrupt: 100% 582/582 [00:00<00:00, 1187.45it/s]
# val: New cache created: /content/datasets/Weapon-Detection-1/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      6.16G       1.45      2.288      1.637         12        800: 100% 619/619 [01:18<00:00,  7.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:04<00:00,  4.41it/s]
#                    all        582       1302      0.603      0.522      0.571      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      5.88G      1.417      1.699      1.621         31        800: 100% 619/619 [01:13<00:00,  8.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.42it/s]
#                    all        582       1302      0.653      0.568      0.639      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      5.86G      1.404      1.651      1.626         16        800: 100% 619/619 [01:11<00:00,  8.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.49it/s]
#                    all        582       1302      0.681      0.606      0.679      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25       5.8G      1.348      1.518      1.568         10        800: 100% 619/619 [01:11<00:00,  8.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.45it/s]
#                    all        582       1302      0.764      0.654      0.745      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      5.84G      1.297      1.386      1.523         11        800: 100% 619/619 [01:12<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.47it/s]
#                    all        582       1302      0.769      0.644      0.743        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      5.89G      1.248      1.273      1.486         12        800: 100% 619/619 [01:11<00:00,  8.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.51it/s]
#                    all        582       1302      0.798      0.729      0.821      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      6.05G      1.204       1.19      1.452         15        800: 100% 619/619 [01:11<00:00,  8.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.37it/s]
#                    all        582       1302      0.875      0.762      0.875      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25       5.9G      1.178      1.124      1.429         10        800: 100% 619/619 [01:11<00:00,  8.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.48it/s]
#                    all        582       1302      0.875      0.786      0.884      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      5.74G      1.154       1.06      1.403         10        800: 100% 619/619 [01:11<00:00,  8.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.41it/s]
#                    all        582       1302      0.872      0.819       0.91      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      5.88G      1.117     0.9993      1.378         15        800: 100% 619/619 [01:11<00:00,  8.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.53it/s]
#                    all        582       1302      0.876      0.866      0.919       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      5.84G       1.09     0.9509      1.358         19        800: 100% 619/619 [01:11<00:00,  8.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.65it/s]
#                    all        582       1302      0.888      0.867      0.927      0.693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      5.84G      1.067     0.9147      1.339         10        800: 100% 619/619 [01:11<00:00,  8.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.38it/s]
#                    all        582       1302      0.879      0.883      0.934      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      5.85G      1.045     0.8781      1.325         14        800: 100% 619/619 [01:11<00:00,  8.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.71it/s]
#                    all        582       1302      0.885      0.897      0.946      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25       5.9G      1.024     0.8441      1.305         13        800: 100% 619/619 [01:12<00:00,  8.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.59it/s]
#                    all        582       1302      0.953      0.896      0.956      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      5.84G     0.9977     0.8059      1.286         13        800: 100% 619/619 [01:11<00:00,  8.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.41it/s]
#                    all        582       1302      0.948      0.884      0.956      0.746
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25       5.8G     0.9795     0.6054      1.294          3        800: 100% 619/619 [01:12<00:00,  8.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.64it/s]
#                    all        582       1302      0.949      0.922      0.967      0.773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      5.78G     0.9399     0.5561      1.264          9        800: 100% 619/619 [01:10<00:00,  8.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.63it/s]
#                    all        582       1302      0.928      0.915      0.969      0.768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25       5.8G     0.9148     0.5305      1.244          9        800: 100% 619/619 [01:10<00:00,  8.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.49it/s]
#                    all        582       1302      0.946      0.929      0.973      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      6.02G     0.8898     0.5025      1.229         13        800: 100% 619/619 [01:11<00:00,  8.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.49it/s]
#                    all        582       1302      0.953      0.935      0.972      0.803
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      5.83G     0.8581     0.4768        1.2          7        800: 100% 619/619 [01:11<00:00,  8.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.50it/s]
#                    all        582       1302       0.96      0.932      0.978       0.81
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      5.78G     0.8283     0.4552       1.18          3        800: 100% 619/619 [01:10<00:00,  8.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.46it/s]
#                    all        582       1302      0.967      0.934      0.978      0.823
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      5.83G     0.8029     0.4344       1.16          8        800: 100% 619/619 [01:10<00:00,  8.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.54it/s]
#                    all        582       1302      0.951      0.956      0.981      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25       5.8G     0.7729     0.4158      1.139          3        800: 100% 619/619 [01:11<00:00,  8.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.65it/s]
#                    all        582       1302      0.971      0.959      0.983      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      5.83G     0.7497     0.3983      1.119          3        800: 100% 619/619 [01:11<00:00,  8.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.58it/s]
#                    all        582       1302      0.975      0.958      0.984      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      5.78G     0.7268     0.3826      1.105         12        800: 100% 619/619 [01:11<00:00,  8.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.56it/s]
#                    all        582       1302      0.975      0.967      0.984       0.85
#
# 25 epochs completed in 0.524 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:03<00:00,  5.39it/s]
#                    all        582       1302      0.975      0.967      0.984       0.85
#                Grenade        190        289      0.985      0.928      0.975      0.832
#                    Gun        150        229      0.971      0.969      0.986       0.86
#                Handgun         70         72      0.971          1      0.991      0.844
#                  Knife        206        284      0.966      0.951      0.981      0.827
#                 Pistol        185        230      0.999      0.996      0.995      0.911
#                  Rifle        162        198       0.96      0.961      0.978      0.828
# Speed: 0.2ms preprocess, 1.0ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Weapon-Detection-1/valid/labels.cache... 582 images, 0 backgrounds, 0 corrupt: 100% 582/582 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 37/37 [00:04<00:00,  7.88it/s]
#                    all        582       1302      0.973      0.968      0.984      0.851
#                Grenade        190        289      0.982      0.929      0.975      0.831
#                    Gun        150        229       0.97      0.972      0.986      0.861
#                Handgun         70         72       0.97          1      0.991      0.843
#                  Knife        206        284       0.96      0.951      0.981       0.83
#                 Pistol        185        230      0.998      0.996      0.995      0.911
#                  Rifle        162        198       0.96      0.962      0.978      0.827
# Speed: 0.4ms preprocess, 2.0ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/266 /content/datasets/Weapon-Detection-1/test/images/05c1802eb11a54118e4cbc09a9f98530_jpg.rf.87cd18510671d82a9636fa1253e088cc.jpg: 800x800 2 Grenades, 1 Gun, 1 Pistol, 7.3ms
# image 2/266 /content/datasets/Weapon-Detection-1/test/images/06eba601-e1140_jpg.rf.75a7088a203da83d682907047752c7e2.jpg: 544x800 1 Grenade, 50.0ms
# image 3/266 /content/datasets/Weapon-Detection-1/test/images/0b891eae-ep261_jpg.rf.5b41e4fd32cfbe768755944a654deadf.jpg: 544x800 1 Grenade, 7.0ms
# image 4/266 /content/datasets/Weapon-Detection-1/test/images/1-105-_jpg.rf.c84da5f3b7238c190b0424e814f05301.jpg: 800x576 1 Handgun, 55.2ms
# image 5/266 /content/datasets/Weapon-Detection-1/test/images/1-118-_jpg.rf.19a1d2b0015e0906419442ca859c2757.jpg: 800x576 1 Handgun, 7.0ms
# image 6/266 /content/datasets/Weapon-Detection-1/test/images/1-122-_jpg.rf.3beff1419a66b60a04f8a0222010aa5d.jpg: 800x576 1 Handgun, 6.9ms
# image 7/266 /content/datasets/Weapon-Detection-1/test/images/1-125-_jpg.rf.a78b0b24e0f2f45a80043495fc7bc96e.jpg: 800x576 1 Handgun, 6.9ms
# image 8/266 /content/datasets/Weapon-Detection-1/test/images/1-133-_jpg.rf.c7ac96d6bb67c565ae4e68edb223e905.jpg: 800x576 1 Handgun, 6.7ms
# image 9/266 /content/datasets/Weapon-Detection-1/test/images/1-134-_jpg.rf.954ca10a1e19db2faaf7f6cc08ca8e61.jpg: 800x576 1 Handgun, 1 Pistol, 6.7ms
# image 10/266 /content/datasets/Weapon-Detection-1/test/images/1-134-_jpg.rf.dacb4111ed0fb4a7816f827bce100261.jpg: 800x576 1 Handgun, 1 Pistol, 6.7ms
# image 11/266 /content/datasets/Weapon-Detection-1/test/images/1-143-_jpg.rf.ff1af343635a9224df06cb8b5c73bb30.jpg: 800x576 1 Handgun, 6.7ms
# image 12/266 /content/datasets/Weapon-Detection-1/test/images/1-151-_jpg.rf.b0655ccda7f0b2b8d2fbc66b6ffa4207.jpg: 800x576 1 Handgun, 6.7ms
# image 13/266 /content/datasets/Weapon-Detection-1/test/images/1-170-_jpg.rf.049ed4361698b71bdb81850cd6c997fe.jpg: 800x576 1 Handgun, 6.7ms
# image 14/266 /content/datasets/Weapon-Detection-1/test/images/1-171-_jpg.rf.dcc5a454e54a4e982d4c5a608babe01d.jpg: 800x576 1 Handgun, 6.7ms
# image 15/266 /content/datasets/Weapon-Detection-1/test/images/1-179-_jpg.rf.66078d3c3c013b79f015d04f72af1e1b.jpg: 800x576 1 Handgun, 7.1ms
# image 16/266 /content/datasets/Weapon-Detection-1/test/images/1-182-_jpg.rf.50d93f2ad7c65b53025539d38dc2e89e.jpg: 800x576 1 Handgun, 6.6ms
# image 17/266 /content/datasets/Weapon-Detection-1/test/images/1-183-_jpg.rf.fc24a5692d973d8e689cd5ba1324eff3.jpg: 800x576 1 Handgun, 6.7ms
# image 18/266 /content/datasets/Weapon-Detection-1/test/images/1-189-_jpg.rf.76807eab03744c2ea373d5f6138f7eb5.jpg: 800x576 1 Handgun, 6.8ms
# image 19/266 /content/datasets/Weapon-Detection-1/test/images/1-190-_jpg.rf.8ee86a57c3eeddaa02df2fb69edc1509.jpg: 800x576 1 Handgun, 6.8ms
# image 20/266 /content/datasets/Weapon-Detection-1/test/images/1-191-_jpg.rf.d050f74708a6c82a4dad6d2e0f209b6c.jpg: 800x576 1 Handgun, 7.2ms
# image 21/266 /content/datasets/Weapon-Detection-1/test/images/1-192-_jpg.rf.f92c1d23ca7b5a51dc5691b666bf3028.jpg: 800x576 1 Handgun, 6.8ms
# image 22/266 /content/datasets/Weapon-Detection-1/test/images/1-196-_jpg.rf.307741e887c2283c641a7e256f52485d.jpg: 800x576 1 Handgun, 6.8ms
# image 23/266 /content/datasets/Weapon-Detection-1/test/images/1-196-_jpg.rf.bc6b4edb30bf9aae5e25ba6b5add5851.jpg: 800x576 1 Handgun, 6.7ms
# image 24/266 /content/datasets/Weapon-Detection-1/test/images/1-29-_jpg.rf.c65f6d0986e9b5ca2c95f825594c215c.jpg: 800x576 1 Handgun, 8.5ms
# image 25/266 /content/datasets/Weapon-Detection-1/test/images/1-3-t_jpg.rf.b47bebc50315fafe116a3d7df088a07d.jpg: 800x576 1 Handgun, 9.0ms
# image 26/266 /content/datasets/Weapon-Detection-1/test/images/1-33-_jpg.rf.9622a6721b454ba8008d44da31d16ba8.jpg: 800x576 1 Handgun, 8.4ms
# image 27/266 /content/datasets/Weapon-Detection-1/test/images/1-34-_jpg.rf.87fa0095219529222e8279fb81d322f7.jpg: 800x576 1 Handgun, 8.4ms
# image 28/266 /content/datasets/Weapon-Detection-1/test/images/1-40-_jpg.rf.fb049affcac527b0092b6b2bd0474bdb.jpg: 800x576 1 Handgun, 6.8ms
# image 29/266 /content/datasets/Weapon-Detection-1/test/images/1-41-_jpg.rf.91fcf2052ca6203233dca8b2fd573ee1.jpg: 800x576 1 Handgun, 6.7ms
# image 30/266 /content/datasets/Weapon-Detection-1/test/images/1-42-_jpg.rf.84fbd9e4d88d1f09be812ce48037bb25.jpg: 800x576 1 Handgun, 7.1ms
# image 31/266 /content/datasets/Weapon-Detection-1/test/images/1-49-_jpg.rf.de02bf3e8e82d6bb5077300f76856372.jpg: 800x576 1 Handgun, 7.0ms
# image 32/266 /content/datasets/Weapon-Detection-1/test/images/1-5-t_jpg.rf.480e03ab9ba17742cff59d7dc2219179.jpg: 800x576 1 Handgun, 6.9ms
# image 33/266 /content/datasets/Weapon-Detection-1/test/images/1-53-_jpg.rf.1f91cd5d4b66d24511591099416969f0.jpg: 800x576 2 Handguns, 6.9ms
# image 34/266 /content/datasets/Weapon-Detection-1/test/images/1-57-_jpg.rf.eaea3a3c68e3d7a89ea309dd433e8fe6.jpg: 800x576 1 Handgun, 6.8ms
# image 35/266 /content/datasets/Weapon-Detection-1/test/images/1-65-_jpg.rf.6f3e1acdc45b8cdddf8586c4304a1e61.jpg: 800x576 1 Handgun, 6.7ms
# image 36/266 /content/datasets/Weapon-Detection-1/test/images/1-76-_jpg.rf.f279e63f887ee5302f1c73c89399d04d.jpg: 800x576 1 Handgun, 6.7ms
# image 37/266 /content/datasets/Weapon-Detection-1/test/images/1-85-_jpg.rf.fe273dfbe50eefcd70b8723df0e34648.jpg: 800x576 2 Handguns, 7.0ms
# image 38/266 /content/datasets/Weapon-Detection-1/test/images/1-89-_jpg.rf.1b68f993539dcac0c9f05bf221ac9f03.jpg: 800x576 1 Handgun, 6.6ms
# image 39/266 /content/datasets/Weapon-Detection-1/test/images/1-89-_jpg.rf.674022fff2465df7c66323b5e7129f5c.jpg: 800x576 1 Handgun, 6.6ms
# image 40/266 /content/datasets/Weapon-Detection-1/test/images/10b3d37db7f8cc2d2879746b7be14a53_jpg.rf.d096a98ec36424417891cc7bfe7a7554.jpg: 800x800 2 Guns, 2 Knifes, 2 Pistols, 7.2ms
# image 41/266 /content/datasets/Weapon-Detection-1/test/images/151_jpeg_jpg.rf.72f3a162d899d3e8a28b747a809443f0.jpg: 800x576 1 Gun, 7.2ms
# image 42/266 /content/datasets/Weapon-Detection-1/test/images/15d17e8ac1a50904fea2dd1836eed323_jpg.rf.0924c2011c9c2dd795bed9ed4920377d.jpg: 800x800 2 Grenades, 1 Gun, 2 Knifes, 7.1ms
# image 43/266 /content/datasets/Weapon-Detection-1/test/images/2-10-t_jpg.rf.51281988847ac333961fcf8aeea512f2.jpg: 800x576 1 Handgun, 1 Rifle, 7.2ms
# image 44/266 /content/datasets/Weapon-Detection-1/test/images/2-102-_jpg.rf.6e4d234008243a880ddd6d572070d895.jpg: 800x576 1 Rifle, 6.8ms
# image 45/266 /content/datasets/Weapon-Detection-1/test/images/2-117-_jpg.rf.405bc0699f61d9891e92d4e954bc59f0.jpg: 800x576 1 Rifle, 6.7ms
# image 46/266 /content/datasets/Weapon-Detection-1/test/images/2-122-_jpg.rf.eab670c3d88e65f8591fa6217420d9c3.jpg: 800x576 1 Rifle, 6.7ms
# image 47/266 /content/datasets/Weapon-Detection-1/test/images/2-125-_jpg.rf.6fc6cd1d744b9493667d1a1603b0b0ed.jpg: 800x576 2 Rifles, 6.7ms
# image 48/266 /content/datasets/Weapon-Detection-1/test/images/2-128-_jpg.rf.670ac9b5981f2b629dffa3e6aa4423ae.jpg: 800x576 1 Rifle, 6.7ms
# image 49/266 /content/datasets/Weapon-Detection-1/test/images/2-132-_jpg.rf.a0c70a258a5bb9c1e34f4602ba9a6c60.jpg: 800x576 1 Rifle, 6.7ms
# image 50/266 /content/datasets/Weapon-Detection-1/test/images/2-150-_jpg.rf.6f095ca02fd52da5e2a92f76ef35a3d1.jpg: 800x576 1 Rifle, 7.0ms
# image 51/266 /content/datasets/Weapon-Detection-1/test/images/2-151-_jpg.rf.8fae2ecc69920257038efb81916b87ce.jpg: 800x576 1 Rifle, 6.9ms
# image 52/266 /content/datasets/Weapon-Detection-1/test/images/2-155-_jpg.rf.f5a8ac684e40388c4c4ff8d08a32f5a0.jpg: 800x576 1 Rifle, 6.8ms
# image 53/266 /content/datasets/Weapon-Detection-1/test/images/2-165-_jpg.rf.91d05e6f66850f3fb3aaf08251f1b286.jpg: 800x576 2 Rifles, 6.7ms
# image 54/266 /content/datasets/Weapon-Detection-1/test/images/2-184-_jpg.rf.2456eae83a55e2b8a33ccf5dc49197cc.jpg: 800x576 1 Rifle, 6.8ms
# image 55/266 /content/datasets/Weapon-Detection-1/test/images/2-185-_jpg.rf.873662ad17f14f326343a9df88bddde4.jpg: 800x576 1 Rifle, 7.2ms
# image 56/266 /content/datasets/Weapon-Detection-1/test/images/2-189-_jpg.rf.8d47c6e4dd620b40de307845684001f6.jpg: 800x576 1 Rifle, 7.9ms
# image 57/266 /content/datasets/Weapon-Detection-1/test/images/2-19-_jpg.rf.e381c514bf4deb2d0640ab5acbfd0e59.jpg: 800x576 2 Rifles, 8.3ms
# image 58/266 /content/datasets/Weapon-Detection-1/test/images/2-193-_jpg.rf.d1580b3706e78c4c7853abad08aef755.jpg: 800x576 2 Rifles, 6.7ms
# image 59/266 /content/datasets/Weapon-Detection-1/test/images/2-205-_jpg.rf.f1c7aeba1597629fc209056e9c89d6c4.jpg: 800x576 1 Rifle, 6.9ms
# image 60/266 /content/datasets/Weapon-Detection-1/test/images/2-206-_jpg.rf.41503a76873e53751842dc8326fe3756.jpg: 800x576 1 Rifle, 6.7ms
# image 61/266 /content/datasets/Weapon-Detection-1/test/images/2-207-_jpg.rf.04f4b50fdb22f9909e71c5c70cf438ab.jpg: 800x576 1 Rifle, 6.7ms
# image 62/266 /content/datasets/Weapon-Detection-1/test/images/2-208-_jpg.rf.f09fac9e15a06484f2458bb00cbc46fb.jpg: 800x576 3 Rifles, 6.6ms
# image 63/266 /content/datasets/Weapon-Detection-1/test/images/2-211-_jpg.rf.7586afe9508a0aab9047ba24b1414061.jpg: 800x576 1 Rifle, 6.7ms
# image 64/266 /content/datasets/Weapon-Detection-1/test/images/2-212-_jpg.rf.63e6adf75bf97ec104021dc5b38d8efe.jpg: 800x576 16 Rifles, 6.6ms
# image 65/266 /content/datasets/Weapon-Detection-1/test/images/2-215-_jpg.rf.317bd2d1cef3374856d2d30b04a0d4c6.jpg: 800x576 2 Rifles, 6.6ms
# image 66/266 /content/datasets/Weapon-Detection-1/test/images/2-223-_jpg.rf.c5157af7ec1afe29932ad362e28ba52e.jpg: 800x576 1 Rifle, 6.8ms
# image 67/266 /content/datasets/Weapon-Detection-1/test/images/2-226-_jpg.rf.9d8fc2561aad1244b7d53916089477a8.jpg: 800x576 1 Rifle, 6.6ms
# image 68/266 /content/datasets/Weapon-Detection-1/test/images/2-233-_jpg.rf.99b77e855513c122996cec0e9d094762.jpg: 800x576 1 Rifle, 6.7ms
# image 69/266 /content/datasets/Weapon-Detection-1/test/images/2-234-_jpg.rf.325010f76b19405918e73d6eab8cb1db.jpg: 800x576 1 Rifle, 6.6ms
# image 70/266 /content/datasets/Weapon-Detection-1/test/images/2-237-_jpg.rf.9d9cfc20664e4e11585618723d3693f1.jpg: 800x576 1 Rifle, 6.7ms
# image 71/266 /content/datasets/Weapon-Detection-1/test/images/2-241-_jpg.rf.7103c42b8ff3bff256fabc7a96c89925.jpg: 800x576 2 Rifles, 6.6ms
# image 72/266 /content/datasets/Weapon-Detection-1/test/images/2-250-_jpg.rf.34a499eae3e66eaf29d5a14ba43e6bd9.jpg: 800x576 1 Rifle, 6.7ms
# image 73/266 /content/datasets/Weapon-Detection-1/test/images/2-251-_jpg.rf.d6b4200ac984bab20bf2ed585b7210e6.jpg: 800x576 1 Rifle, 6.6ms
# image 74/266 /content/datasets/Weapon-Detection-1/test/images/2-261-_jpg.rf.1f440792c5d7792346a448916ed3b835.jpg: 800x576 1 Rifle, 6.7ms
# image 75/266 /content/datasets/Weapon-Detection-1/test/images/2-263-_jpg.rf.d9cde7834da0d1735902eeaa978ae06a.jpg: 800x576 1 Rifle, 6.7ms
# image 76/266 /content/datasets/Weapon-Detection-1/test/images/2-264-_jpg.rf.49b4c3f99ac59b60573a76e8930664f5.jpg: 800x576 2 Rifles, 6.7ms
# image 77/266 /content/datasets/Weapon-Detection-1/test/images/2-266-_jpg.rf.94d86c4b89c1c5c0fa0c57b2a0d57d60.jpg: 800x576 1 Rifle, 6.7ms
# image 78/266 /content/datasets/Weapon-Detection-1/test/images/2-267-_jpg.rf.1030aed455a574b0e3e7ba7824b3c38c.jpg: 800x576 1 Rifle, 6.7ms
# image 79/266 /content/datasets/Weapon-Detection-1/test/images/2-269-_jpg.rf.749f5a7fee642b110ee5e1404189cc22.jpg: 800x576 1 Rifle, 6.7ms
# image 80/266 /content/datasets/Weapon-Detection-1/test/images/2-276-_jpg.rf.069057829704e7196c2499a0f47fb840.jpg: 800x576 1 Rifle, 6.6ms
# image 81/266 /content/datasets/Weapon-Detection-1/test/images/2-279-_jpg.rf.7601d0b6577ebc50ba70115989399305.jpg: 800x576 1 Rifle, 6.6ms
# image 82/266 /content/datasets/Weapon-Detection-1/test/images/2-283-_jpg.rf.edc5c20a27365fe5a190034ddb7ca3f1.jpg: 800x576 1 Rifle, 6.7ms
# image 83/266 /content/datasets/Weapon-Detection-1/test/images/2-287-_jpg.rf.6874579e7b971f96fbc132d15bb31331.jpg: 800x576 1 Rifle, 6.7ms
# image 84/266 /content/datasets/Weapon-Detection-1/test/images/2-290-_jpg.rf.ae5cde7a8582448ef95b7a4a238f85dd.jpg: 800x576 1 Rifle, 6.6ms
# image 85/266 /content/datasets/Weapon-Detection-1/test/images/2-294-_jpg.rf.d807b0bbc27e9a29209a9191d4356922.jpg: 800x576 1 Rifle, 6.7ms
# image 86/266 /content/datasets/Weapon-Detection-1/test/images/2-298-_jpg.rf.f4d085cd09f16d7d9af3731d7c91d812.jpg: 800x576 1 Gun, 2 Rifles, 6.6ms
# image 87/266 /content/datasets/Weapon-Detection-1/test/images/2-3-t_jpg.rf.c8a98118cf694586f3950bc653687910.jpg: 800x576 1 Rifle, 6.6ms
# image 88/266 /content/datasets/Weapon-Detection-1/test/images/2-30-_jpg.rf.51c05983e9b1a85220d9aa9548bd228d.jpg: 800x576 1 Rifle, 6.6ms
# image 89/266 /content/datasets/Weapon-Detection-1/test/images/2-303-_jpg.rf.a044fa1ff9bee9d4cc639cad9c035534.jpg: 800x576 3 Rifles, 6.6ms
# image 90/266 /content/datasets/Weapon-Detection-1/test/images/2-305-_jpg.rf.9fbc3781778c35f6458c3b1d483effbe.jpg: 800x576 2 Rifles, 6.6ms
# image 91/266 /content/datasets/Weapon-Detection-1/test/images/2-308-_jpg.rf.280d732f63bda63316629011b2b483e3.jpg: 800x576 1 Rifle, 6.6ms
# image 92/266 /content/datasets/Weapon-Detection-1/test/images/2-313-_jpg.rf.84f75850b86ad9be463874019412e419.jpg: 800x576 1 Rifle, 6.6ms
# image 93/266 /content/datasets/Weapon-Detection-1/test/images/2-315-_jpg.rf.c069fb2626dfa7ea3b5c8c3813595e95.jpg: 800x576 1 Rifle, 6.7ms
# image 94/266 /content/datasets/Weapon-Detection-1/test/images/2-318-_jpg.rf.30f58237fd795692b196532451b78805.jpg: 800x576 1 Rifle, 6.7ms
# image 95/266 /content/datasets/Weapon-Detection-1/test/images/2-32-_jpg.rf.dedd6b89d06b04504467b6afff5d32d9.jpg: 800x576 1 Rifle, 6.8ms
# image 96/266 /content/datasets/Weapon-Detection-1/test/images/2-321-_jpg.rf.f3b82f664e188c426d8f56a1753aa121.jpg: 800x576 1 Rifle, 6.8ms
# image 97/266 /content/datasets/Weapon-Detection-1/test/images/2-324-_jpg.rf.c41b1b6238e4e8ca73c96e878ffc2571.jpg: 800x576 1 Rifle, 7.2ms
# image 98/266 /content/datasets/Weapon-Detection-1/test/images/2-340-_jpg.rf.4be53c658bd5fd8186d2eac91dc4dd0c.jpg: 800x576 1 Rifle, 6.8ms
# image 99/266 /content/datasets/Weapon-Detection-1/test/images/2-341-_jpg.rf.bf02363c8631f46d0f92ddca1a929a66.jpg: 800x576 1 Rifle, 6.9ms
# image 100/266 /content/datasets/Weapon-Detection-1/test/images/2-344-_jpg.rf.f57d97a01c7e34814d825f44a141653d.jpg: 800x576 1 Rifle, 6.8ms
# image 101/266 /content/datasets/Weapon-Detection-1/test/images/2-352-_jpg.rf.af046118074cc94dadd253b3fdf7ca16.jpg: 800x576 3 Rifles, 6.7ms
# image 102/266 /content/datasets/Weapon-Detection-1/test/images/2-360-_jpg.rf.6f339209fa9d7d53973609026bce286a.jpg: 800x576 1 Rifle, 6.6ms
# image 103/266 /content/datasets/Weapon-Detection-1/test/images/2-366-_jpg.rf.3d50a888abb44482701ebf3cad3305f3.jpg: 800x576 1 Rifle, 6.7ms
# image 104/266 /content/datasets/Weapon-Detection-1/test/images/2-374-_jpg.rf.0a1e2f74ec5eb0679feec8b702c525e0.jpg: 800x576 1 Rifle, 8.2ms
# image 105/266 /content/datasets/Weapon-Detection-1/test/images/2-375-_jpg.rf.c8891d55286f761d3c920639659fc3f1.jpg: 800x576 1 Rifle, 7.7ms
# image 106/266 /content/datasets/Weapon-Detection-1/test/images/2-381-_jpg.rf.647586ebf7a206ae92707d31c5252eab.jpg: 800x576 1 Rifle, 7.3ms
# image 107/266 /content/datasets/Weapon-Detection-1/test/images/2-387-_jpg.rf.1d080b48574ad7fa9b2dec69f69ae907.jpg: 800x576 1 Rifle, 6.7ms
# image 108/266 /content/datasets/Weapon-Detection-1/test/images/2-41-_jpg.rf.b1f2150b840fcdbc2627041d45b8337b.jpg: 800x576 1 Rifle, 6.7ms
# image 109/266 /content/datasets/Weapon-Detection-1/test/images/2-48-_jpg.rf.d185f51e01cd576a600acf69df0dd674.jpg: 800x576 1 Rifle, 6.6ms
# image 110/266 /content/datasets/Weapon-Detection-1/test/images/2-49-_jpg.rf.e1dbc498e0b16144ed1f1f798b02d00d.jpg: 800x576 2 Rifles, 6.6ms
# image 111/266 /content/datasets/Weapon-Detection-1/test/images/2-50-_jpg.rf.0ae281b51f73c584d2e099612c21be7f.jpg: 800x576 1 Rifle, 6.6ms
# image 112/266 /content/datasets/Weapon-Detection-1/test/images/2-51-_jpg.rf.33f79ca2e5e07dcc35265d46192f2d7d.jpg: 800x576 1 Rifle, 6.6ms
# image 113/266 /content/datasets/Weapon-Detection-1/test/images/2-6-t_jpg.rf.956ada52097322138ca650024f4337cd.jpg: 800x576 2 Rifles, 6.7ms
# image 114/266 /content/datasets/Weapon-Detection-1/test/images/2-63-_jpg.rf.c4e7fc8438182a08134b495dc07d4dea.jpg: 800x576 1 Rifle, 6.6ms
# image 115/266 /content/datasets/Weapon-Detection-1/test/images/2-64-_jpg.rf.127108dc3d8bd7a3c0fa3d7dc22f6c4c.jpg: 800x576 1 Rifle, 7.4ms
# image 116/266 /content/datasets/Weapon-Detection-1/test/images/2-79-_jpg.rf.17e12df042b38841c709b6eae327116a.jpg: 800x576 2 Rifles, 7.5ms
# image 117/266 /content/datasets/Weapon-Detection-1/test/images/2-80-_jpg.rf.96b6ad7413ec771bfb7a29d90e818da5.jpg: 800x576 2 Rifles, 7.3ms
# image 118/266 /content/datasets/Weapon-Detection-1/test/images/2-9-t_jpg.rf.f8f05a8c63c50864cae01c8b6b7aba51.jpg: 800x576 1 Handgun, 2 Rifles, 7.2ms
# image 119/266 /content/datasets/Weapon-Detection-1/test/images/204_jpeg_jpg.rf.eb7d6f709935ff242e8f47a7fadc9e3c.jpg: 544x800 2 Guns, 7.5ms
# image 120/266 /content/datasets/Weapon-Detection-1/test/images/246a1858-140_jpeg_jpg.rf.8e81b22c62d0630e253675a50e4e6360.jpg: 448x800 1 Pistol, 50.1ms
# image 121/266 /content/datasets/Weapon-Detection-1/test/images/24_jpg.rf.02e64c814bd64894a9eae0202fecf728.jpg: 480x800 1 Grenade, 4 Guns, 51.0ms
# image 122/266 /content/datasets/Weapon-Detection-1/test/images/25a3a5fd-4087-44c2-b7d3-b875a09ee5fa_1-b6d238a8b895193ecab4052db39eee54_jpg.rf.e9fbed02b59affbd59cfe4d53019dee1.jpg: 800x800 1 Grenade, 1 Knife, 1 Pistol, 7.9ms
# image 123/266 /content/datasets/Weapon-Detection-1/test/images/29_jpg.rf.fb9702087de40cf8c4c5d2787eb68622.jpg: 608x800 1 Grenade, 49.6ms
# image 124/266 /content/datasets/Weapon-Detection-1/test/images/2c417482-cedceb085c6ab7ca090683faf697ce04_jpg.rf.0ed25314d8b8b91f64f6bfe2682b23d8.jpg: 800x800 1 Knife, 1 Pistol, 7.6ms
# image 125/266 /content/datasets/Weapon-Detection-1/test/images/2ddb27a530a8d314bea057103fb81c1f_jpg.rf.f5bbf87a99d69d7b0eb917ee2ee0a3df.jpg: 800x800 5 Guns, 4 Knifes, 1 Pistol, 6.9ms
# image 126/266 /content/datasets/Weapon-Detection-1/test/images/2fafffe7abc4e1ba3d60e55d20a9a017_jpg.rf.9f401c713916402cc5de6196e698bc4e.jpg: 800x800 2 Guns, 2 Knifes, 5 Pistols, 7.0ms
# image 127/266 /content/datasets/Weapon-Detection-1/test/images/30_jpeg_jpg.rf.a4c994c27fefcf38d3c40e02de61a919.jpg: 800x704 2 Grenades, 1 Gun, 49.9ms
# image 128/266 /content/datasets/Weapon-Detection-1/test/images/34b4d8281bc90792792246438103a1bc_jpg.rf.bf227cd0927c55a03a29e23808ffb14e.jpg: 800x640 1 Grenade, 1 Pistol, 50.9ms
# image 129/266 /content/datasets/Weapon-Detection-1/test/images/35_jpg.rf.e8ce9235c9c00f65902e5e5efb55cce3.jpg: 544x800 2 Grenades, 7.9ms
# image 130/266 /content/datasets/Weapon-Detection-1/test/images/3ab5984a-e1199_jpg.rf.969ad271b175caa01e9d0cd372bda6ee.jpg: 800x768 1 Grenade, 50.0ms
# image 131/266 /content/datasets/Weapon-Detection-1/test/images/3c417a4cee5bb066c077f00dadfe69bf_jpg.rf.fcc14f68665f68f4425427820e6ca1ea.jpg: 736x800 1 Grenade, 1 Knife, 1 Pistol, 49.7ms
# image 132/266 /content/datasets/Weapon-Detection-1/test/images/3d_military_stuff_pilot_helmet_grenade_usmc_knife_by_cytherina_d8na6a2-pre_jpg.rf.d415b770d86a0451214c5aa421b5dc01.jpg: 576x800 1 Grenade, 1 Knife, 49.3ms
# image 133/266 /content/datasets/Weapon-Detection-1/test/images/3ddfd3323103f1b05b687e2423c3209e_jpg.rf.bd1738d650e8f483aa1bcfeffea99f23.jpg: 800x800 3 Guns, 2 Knifes, 1 Pistol, 7.9ms
# image 134/266 /content/datasets/Weapon-Detection-1/test/images/3fa29c5344299c1a_jpg.rf.472e18afff3723c257988708ab8862dd.jpg: 608x800 1 Gun, 7.8ms
# image 135/266 /content/datasets/Weapon-Detection-1/test/images/3fd4715c4f09f130af5a230a6a706764_jpg.rf.0a67773ce6b11225448d24b7655f7dab.jpg: 800x800 1 Grenade, 1 Gun, 1 Pistol, 7.8ms
# image 136/266 /content/datasets/Weapon-Detection-1/test/images/41c3589c5385a675_jpg.rf.e9a88ef39f3d5a04618dea1efd2b532c.jpg: 608x800 3 Guns, 7.5ms
# image 137/266 /content/datasets/Weapon-Detection-1/test/images/4272035582_c01fc60147_b_jpg.rf.055402afa0a89d6451ec1678b3c735d7.jpg: 608x800 3 Grenades, 1 Pistol, 7.0ms
# image 138/266 /content/datasets/Weapon-Detection-1/test/images/44_jpg.rf.376a7c1a1a55607635e6a61843060aa7.jpg: 800x544 1 Gun, 1 Knife, 50.7ms
# image 139/266 /content/datasets/Weapon-Detection-1/test/images/49e721b3-237_jpeg_jpg.rf.13e1c8bdf629de392bca371038832cb9.jpg: 352x800 1 Pistol, 49.5ms
# image 140/266 /content/datasets/Weapon-Detection-1/test/images/4a8a5f3e01e483bfa21eb699f9db6bcb_jpg.rf.c25fefd335296fe51efe313a0d0232ca.jpg: 800x800 4 Grenades, 2 Guns, 1 Knife, 1 Pistol, 7.6ms
# image 141/266 /content/datasets/Weapon-Detection-1/test/images/4d378873-e1279_jpg.rf.5ca3ac8e6b02c3ed3c759500df6bc862.jpg: 480x800 1 Grenade, 7.5ms
# image 142/266 /content/datasets/Weapon-Detection-1/test/images/4df2b1be-283_jpeg_jpg.rf.8c704debbabbe33e84182f5cc79539e9.jpg: 448x800 1 Pistol, 7.9ms
# image 143/266 /content/datasets/Weapon-Detection-1/test/images/4e32b902-e1216_jpg.rf.4224b540a7ba26d1cdedfb3456fb1c1b.jpg: 608x800 1 Grenade, 7.3ms
# image 144/266 /content/datasets/Weapon-Detection-1/test/images/500db0c3-201_jpeg_jpg.rf.a1e57fa3b2798bb116eef864b85d035d.jpg: 544x800 1 Pistol, 7.4ms
# image 145/266 /content/datasets/Weapon-Detection-1/test/images/50fbebc6-ep42_jpg.rf.c3ec48a64fbe02701bb5f007daf44359.jpg: 544x800 1 Grenade, 6.8ms
# image 146/266 /content/datasets/Weapon-Detection-1/test/images/51_jpeg_jpg.rf.0de77784e19bd6dcc04a3b8aac4baa61.jpg: 448x800 1 Gun, 7.3ms
# image 147/266 /content/datasets/Weapon-Detection-1/test/images/536cc816-e1130_jpg.rf.5cdf2d18e84f991939e1119a28f26973.jpg: 608x800 1 Grenade, 7.4ms
# image 148/266 /content/datasets/Weapon-Detection-1/test/images/53c4400f84904c855f000037_jpg.rf.bba83c0bebf3e9ed7b3e5da0ad6b5f78.jpg: 800x800 1 Grenade, 1 Gun, 1 Knife, 7.2ms
# image 149/266 /content/datasets/Weapon-Detection-1/test/images/53ff7b7eb833a044_jpg.rf.071ddfe95ca57085a7adf27ddbaa2fac.jpg: 672x800 1 Gun, 1 Knife, 50.0ms
# image 150/266 /content/datasets/Weapon-Detection-1/test/images/5d13f948e9edd9376a1695a541561ab5_jpg.rf.fcc90659f58d49861717f46e6f095401.jpg: 800x800 1 Gun, 2 Knifes, 1 Pistol, 7.5ms
# image 151/266 /content/datasets/Weapon-Detection-1/test/images/5e49be08f989a31d253b8a130fdba5f5_jpeg_jpg.rf.cc522318e8807f333ac59d5b7ddc545b.jpg: 800x800 2 Grenades, 1 Knife, 1 Pistol, 7.2ms
# image 152/266 /content/datasets/Weapon-Detection-1/test/images/641f684764d5a7e8_jpg.rf.adcaa9c93112e4330c6fe1a92ebc0fed.jpg: 512x800 1 Gun, 2 Pistols, 50.6ms
# image 153/266 /content/datasets/Weapon-Detection-1/test/images/66c31a88d85c363dabe8e421f05ad4ae_jpg.rf.73e2c1753959a20c21f27b4bda503b0d.jpg: 800x800 2 Guns, 4 Knifes, 2 Pistols, 8.5ms
# image 154/266 /content/datasets/Weapon-Detection-1/test/images/67fcce43-312_jpeg_jpg.rf.be94c0014e3e8d9667d5d8b2b5734759.jpg: 448x800 2 Pistols, 7.7ms
# image 155/266 /content/datasets/Weapon-Detection-1/test/images/6_jpeg_jpg.rf.0b59e039e8eee17fcdd2377cca1bf2a1.jpg: 544x800 1 Knife, 1 Pistol, 7.4ms
# image 156/266 /content/datasets/Weapon-Detection-1/test/images/759e2d02-234_jpeg_jpg.rf.7ada11a11ec9ea4ad25e05ba17967b11.jpg: 544x800 2 Pistols, 6.9ms
# image 157/266 /content/datasets/Weapon-Detection-1/test/images/7a40d2e5-e1415_jpg.rf.7c8bfc66e40f47e075c10676ec2a174f.jpg: 672x800 1 Grenade, 7.3ms
# image 158/266 /content/datasets/Weapon-Detection-1/test/images/7d49c786-282_jpeg_jpg.rf.61ea0e35af7bcfba5819f31a9d28be49.jpg: 480x800 1 Pistol, 7.4ms
# image 159/266 /content/datasets/Weapon-Detection-1/test/images/8130cc29a41fcb150c6cd1665efe88d1_jpeg_jpg.rf.844294aa456363da70a92e485d7a944e.jpg: 800x800 1 Grenade, 1 Knife, 1 Pistol, 7.4ms
# image 160/266 /content/datasets/Weapon-Detection-1/test/images/84d477ba-209_jpeg_jpg.rf.cd771ddcd11194221cad2c515bad19f3.jpg: 544x800 2 Pistols, 7.4ms
# image 161/266 /content/datasets/Weapon-Detection-1/test/images/87cdc28c-5715118276_3879f8e760_b_jpg.rf.596fc87adcd37c59c19222a48f331ccd.jpg: 544x800 1 Gun, 6.8ms
# image 162/266 /content/datasets/Weapon-Detection-1/test/images/892b72d4-184_jpeg_jpg.rf.ff067c1089e72d74f3d4d292ed21ac6d.jpg: 448x800 1 Pistol, 8.7ms
# image 163/266 /content/datasets/Weapon-Detection-1/test/images/8c8b6c267dd501c681b1bb23beef25b5_jpg.rf.f32d35211ccc3ed5d26511e66e373aa2.jpg: 800x800 1 Grenade, 1 Knife, 1 Pistol, 7.7ms
# image 164/266 /content/datasets/Weapon-Detection-1/test/images/965166ed6f924b9c_jpg.rf.f74b17dccb67d1cf963dbde473a10aff.jpg: 544x800 1 Grenade, 1 Gun, 7.3ms
# image 165/266 /content/datasets/Weapon-Detection-1/test/images/9913861094_s-l1600209_jpg.rf.7c0391e7085d142c50e15280b21dfa91.jpg: 800x800 3 Grenades, 2 Guns, 2 Knifes, 2 Pistols, 7.2ms
# image 166/266 /content/datasets/Weapon-Detection-1/test/images/ABbframe00319_jpg.rf.9411cf60abdf7b9c20aa204278fd54ef.jpg: 480x800 1 Knife, 7.3ms
# image 167/266 /content/datasets/Weapon-Detection-1/test/images/ABsframe00100_jpg.rf.6729642125d376edee21c27da7f0af8b.jpg: 480x800 1 Knife, 7.3ms
# image 168/266 /content/datasets/Weapon-Detection-1/test/images/ABsframe00241_jpg.rf.93affe56ea9c7ba9d534120607fdbc77.jpg: 480x800 1 Knife, 7.5ms
# image 169/266 /content/datasets/Weapon-Detection-1/test/images/BOCW-Ballistic-Knife-002_jpg.rf.56f6f3df283989354b3bcc74e3ccbb46.jpg: 800x800 5 Grenades, 3 Guns, 2 Knifes, 8.6ms
# image 170/266 /content/datasets/Weapon-Detection-1/test/images/C9xSlzDXsAEy2Sw_jpg.rf.f4ae77074cdf79490cadaeca5e3fbe56.jpg: 608x800 1 Grenade, 1 Knife, 8.2ms
# image 171/266 /content/datasets/Weapon-Detection-1/test/images/D51G65ZDG65Z1DSG5ZD1SG651SD65F1GSDFG1SD65F1image_jpg.rf.b305565540d636e21b8c97775c188079.jpg: 800x800 1 Grenade, 1 Gun, 1 Knife, 1 Pistol, 8.0ms
# image 172/266 /content/datasets/Weapon-Detection-1/test/images/DCjWRnT_jpg.rf.9ad9a8551f9f76820a87a52db021034d.jpg: 704x800 1 Grenade, 1 Knife, 1 Pistol, 49.6ms
# image 173/266 /content/datasets/Weapon-Detection-1/test/images/DSC_0012_jpg.rf.23e433b2d8c24475ba89d1b1512d9c84.jpg: 544x800 1 Knife, 7.9ms
# image 174/266 /content/datasets/Weapon-Detection-1/test/images/DSC_0030_jpg.rf.8f9cf752b3aae7fb9c6534f8bb6549a1.jpg: 544x800 1 Knife, 7.4ms
# image 175/266 /content/datasets/Weapon-Detection-1/test/images/DSC_0035_jpg.rf.0c5a156aba78ffaac1de26240862b8a8.jpg: 544x800 1 Knife, 7.5ms
# image 176/266 /content/datasets/Weapon-Detection-1/test/images/DefenseAndSurvive02_jpg.rf.402bb8a224c6919610193c6302000fa0.jpg: 480x800 1 Knife, 7.8ms
# image 177/266 /content/datasets/Weapon-Detection-1/test/images/DefenseKnifeAttack0187_jpg.rf.259a7dd83e20f179557e2f5f5b6a0e10.jpg: 480x800 1 Knife, 7.2ms
# image 178/266 /content/datasets/Weapon-Detection-1/test/images/DefenseKnifeAttack0842_jpg.rf.7ae391fa90a8a8cbfe218308f9d373f3.jpg: 480x800 1 Knife, 7.1ms
# image 179/266 /content/datasets/Weapon-Detection-1/test/images/DefenseKnifeAttack0942_jpg.rf.2e94f41ee1a927f0510cb960db8ff956.jpg: 480x800 1 Knife, 9.4ms
# image 180/266 /content/datasets/Weapon-Detection-1/test/images/FILE040_JPG_jpg.rf.0e6ab445ed5bf2911b5e65194ef3c279.jpg: 576x800 1 Gun, 1 Pistol, 7.9ms
# image 181/266 /content/datasets/Weapon-Detection-1/test/images/FILE058_JPG_jpg.rf.8c144f333436af35c7dc9d71e06e13a7.jpg: 512x800 1 Gun, 1 Knife, 7.6ms
# image 182/266 /content/datasets/Weapon-Detection-1/test/images/FILE109_JPG_jpg.rf.808423e16a1a4f3406d89fe24cb159e5.jpg: 512x800 1 Gun, 1 Knife, 6.9ms
# image 183/266 /content/datasets/Weapon-Detection-1/test/images/FILE11139_JPG_jpg.rf.7a9d5abfea1887b33e2808fc6d058437.jpg: 544x800 1 Knife, 1 Pistol, 7.3ms
# image 184/266 /content/datasets/Weapon-Detection-1/test/images/FILE11305_JPG_jpg.rf.3a7cb3b27819ae17f9b884b0d7fb9192.jpg: 672x800 1 Knife, 1 Pistol, 7.3ms
# image 185/266 /content/datasets/Weapon-Detection-1/test/images/FILE11307_JPG_jpg.rf.f929d41726770940d4266890724ebe52.jpg: 800x640 1 Knife, 1 Pistol, 7.4ms
# image 186/266 /content/datasets/Weapon-Detection-1/test/images/FILE20687_JPG_jpg.rf.0c5c7f79dce5239cf5dc5b6349be94bc.jpg: 416x800 1 Knife, 1 Pistol, 48.6ms
# image 187/266 /content/datasets/Weapon-Detection-1/test/images/FILE20691_JPG_jpg.rf.23ff27836531acdfd674d5b7d05effa9.jpg: 800x544 1 Knife, 1 Pistol, 7.3ms
# image 188/266 /content/datasets/Weapon-Detection-1/test/images/FILE20699_JPG_jpg.rf.0ddf39a26ff38f9bf93f9542e5024a6a.jpg: 576x800 3 Knifes, 1 Pistol, 7.3ms
# image 189/266 /content/datasets/Weapon-Detection-1/test/images/FILE20931_JPG_jpg.rf.b368e7aa7354c722fafb3488a7258012.jpg: 608x800 2 Knifes, 1 Pistol, 7.3ms
# image 190/266 /content/datasets/Weapon-Detection-1/test/images/FILE20969_JPG_jpg.rf.6946997b1955130575552c8d09631317.jpg: 512x800 1 Knife, 1 Pistol, 7.2ms
# image 191/266 /content/datasets/Weapon-Detection-1/test/images/FILE219_JPG_jpg.rf.90a9b191a520c3812ddafd4e6b744eb3.jpg: 576x800 1 Gun, 2 Pistols, 7.8ms
# image 192/266 /content/datasets/Weapon-Detection-1/test/images/FILE227_JPG_jpg.rf.4edef0db43408dbd0bd976e6cb7a446b.jpg: 448x800 1 Gun, 2 Pistols, 7.5ms
# image 193/266 /content/datasets/Weapon-Detection-1/test/images/FILE248_JPG_jpg.rf.05cd2dd99e6fae9e3969a5a963fdf655.jpg: 544x800 1 Gun, 1 Knife, 7.2ms
# image 194/266 /content/datasets/Weapon-Detection-1/test/images/FILE253_JPG_jpg.rf.4cdc4e021cbb65739422b8f65c39cde3.jpg: 608x800 2 Guns, 1 Knife, 7.2ms
# image 195/266 /content/datasets/Weapon-Detection-1/test/images/FILE254_JPG_jpg.rf.9f169847cae02dec5d8718de51793d03.jpg: 544x800 1 Gun, 1 Knife, 7.2ms
# image 196/266 /content/datasets/Weapon-Detection-1/test/images/FILE283_JPG_jpg.rf.ec9815de0fd1826d4c639ce90cefcad8.jpg: 608x800 1 Gun, 1 Knife, 7.2ms
# image 197/266 /content/datasets/Weapon-Detection-1/test/images/FILE306_JPG_jpg.rf.f413c2a09e5b8f712c8c5189ab123bb0.jpg: 544x800 1 Knife, 1 Pistol, 7.1ms
# image 198/266 /content/datasets/Weapon-Detection-1/test/images/FILE311_JPG_jpg.rf.b841fe13a8d20bd3e345148036fcc4b3.jpg: 448x800 1 Knife, 1 Pistol, 7.6ms
# image 199/266 /content/datasets/Weapon-Detection-1/test/images/FILE5354_JPG_jpg.rf.65587b4c365431d326ee9c059902e7c7.jpg: 800x800 1 Knife, 1 Pistol, 7.2ms
# image 200/266 /content/datasets/Weapon-Detection-1/test/images/FILE5390_JPG_jpg.rf.51f8c06de8074618580380b53e935c10.jpg: 800x800 1 Knife, 1 Pistol, 6.6ms
# image 201/266 /content/datasets/Weapon-Detection-1/test/images/FP-94WeaQAEuOjO_jpg.rf.481911edf30841fe63f607a39f8b2405.jpg: 544x800 3 Pistols, 7.2ms
# image 202/266 /content/datasets/Weapon-Detection-1/test/images/HD-wallpaper-molon-labe-ar15-bullets-dpms-guns-knives-murica-pistol-tactical-taurus-usa-thumbnail_jpg.rf.21542437d2a74cb5f25fa0554564dcd5.jpg: 800x800 1 Gun, 1 Knife, 1 Pistol, 7.1ms
# image 203/266 /content/datasets/Weapon-Detection-1/test/images/KODAK-EASYSHARE-C533-ZOOM-DIGITAL-CAMER249_JPG_jpg.rf.e078f7e29f82d6806520e0f2f4eb4a77.jpg: 800x800 1 Knife, 6.6ms
# image 204/266 /content/datasets/Weapon-Detection-1/test/images/KravMagaKnifeDefenseTechniques051_jpg.rf.3467e056d994b50f7ea69ae3c9fb2866.jpg: 480x800 1 Knife, 7.1ms
# image 205/266 /content/datasets/Weapon-Detection-1/test/images/KravMagaTraining20924_jpg.rf.241ec50fbc4e5d087f51a93dba68efd7.jpg: 480x800 1 Knife, 7.1ms
# image 206/266 /content/datasets/Weapon-Detection-1/test/images/KravMagaTraining500_jpg.rf.54cc7b92e657e0660bd8b50b51bf4b5b.jpg: 480x800 1 Knife, 7.1ms
# image 207/266 /content/datasets/Weapon-Detection-1/test/images/MW-S4-DFE-PT2-4_jpg.rf.cf1ea35283f638a54f7e1549850d8f26.jpg: 800x800 4 Guns, 1 Knife, 7.5ms
# image 208/266 /content/datasets/Weapon-Detection-1/test/images/PUBGGunsInRealLife-06721_jpg.rf.87a78bd9e045a23392071caead4e96d2.jpg: 480x800 1 Gun, 2 Pistols, 7.4ms
# image 209/266 /content/datasets/Weapon-Detection-1/test/images/Screen-Shot-2019-07-26-at-8-54-42-AM_png_jpg.rf.591caa704f91c0b6138f4dc4d1d7ecc0.jpg: 416x800 1 Grenade, 2 Knifes, 1 Pistol, 7.7ms
# image 210/266 /content/datasets/Weapon-Detection-1/test/images/Screenshot-from-2022-07-27-10-35-19_png_jpg.rf.65b3eaaaa6bdce0c91141ec8ce443376.jpg: 640x800 1 Grenade, 1 Knife, 2 Pistols, 48.7ms
# image 211/266 /content/datasets/Weapon-Detection-1/test/images/Screenshot-from-2022-07-27-10-45-16_png_jpg.rf.74b1c17cf5cfa89135898d6adaaf39e1.jpg: 544x800 1 Grenade, 1 Knife, 1 Pistol, 7.5ms
# image 212/266 /content/datasets/Weapon-Detection-1/test/images/Screenshot-from-2022-07-27-10-59-14_png_jpg.rf.da86ff097d70c67860f33d3da75473f3.jpg: 576x800 2 Grenades, 1 Knife, 1 Pistol, 7.5ms
# image 213/266 /content/datasets/Weapon-Detection-1/test/images/Screenshot-from-2022-07-27-11-21-35_jpg.rf.2f74008d0661cfeaa197441d22c98e4f.jpg: 800x800 1 Grenade, 1 Knife, 7.3ms
# image 214/266 /content/datasets/Weapon-Detection-1/test/images/Screenshot-from-2022-07-27-11-27-48_png_jpg.rf.ce84c387cdceee929e8fd578e94b6bca.jpg: 768x800 1 Grenade, 1 Knife, 48.4ms
# image 215/266 /content/datasets/Weapon-Detection-1/test/images/a33b8b45475347c65d51f59892bf3874_jpg.rf.f54339dae033c3137c15504b0d3c74d4.jpg: 800x800 2 Grenades, 1 Knife, 1 Pistol, 7.8ms
# image 216/266 /content/datasets/Weapon-Detection-1/test/images/a3bd4483-soldier-with-knife_jpg.rf.0f481a2ca7e4bf834b83a3c2350c8eb0.jpg: 800x800 1 Knife, 6.8ms
# image 217/266 /content/datasets/Weapon-Detection-1/test/images/a611d367076360361d0cbe2b9c1dc8f8_jpg.rf.ecad8ad8aca3b2eef1b60b851cf33c00.jpg: 800x640 1 Grenade, 1 Knife, 1 Pistol, 7.6ms
# image 218/266 /content/datasets/Weapon-Detection-1/test/images/acc2d679ee839f8d310b834196d2c55f_jpg.rf.daa849dc7d72ee53aaea185438d4a1a0.jpg: 800x800 3 Grenades, 2 Guns, 1 Knife, 2 Pistols, 7.3ms
# image 219/266 /content/datasets/Weapon-Detection-1/test/images/aebde69cff43bf49a12abad937ec7ba8_jpg.rf.b0510d0d7720adfaf682e3c6787e426e.jpg: 800x800 1 Gun, 1 Knife, 2 Pistols, 6.7ms
# image 220/266 /content/datasets/Weapon-Detection-1/test/images/b40571bd9c30e8d17c56ad842cf07e80_jpg.rf.179f6e20da7002ddcd8cf2331d097eb8.jpg: 800x800 1 Gun, 1 Knife, 6.8ms
# image 221/266 /content/datasets/Weapon-Detection-1/test/images/baseball_hand_grenade_by_wongkahei_dd37kiv-fullview_jpg.rf.67e0bd643be60d86bc07cf359badafae.jpg: 352x800 2 Grenades, 3 Knifes, 7.5ms
# image 222/266 /content/datasets/Weapon-Detection-1/test/images/be2f70f6a1c839626cba68ac18c73144_jpg.rf.fa064901e66be7db385cdcb3ecf5d95d.jpg: 800x800 2 Grenades, 1 Gun, 1 Pistol, 7.6ms
# image 223/266 /content/datasets/Weapon-Detection-1/test/images/bolt-action-rifle-grenades-gun-knife-wallpaper-thumb_jpg.rf.89caafb3ab7f8bde36641cdc6246f266.jpg: 800x800 1 Grenade, 1 Gun, 1 Knife, 6.8ms
# image 224/266 /content/datasets/Weapon-Detection-1/test/images/ca3345b72529699b11666d024f2bd915_jpg.rf.ae24a6b4eb16503d5097d74f983307ed.jpg: 800x800 6 Guns, 4 Knifes, 2 Pistols, 6.8ms
# image 225/266 /content/datasets/Weapon-Detection-1/test/images/cfd076a08c6ed11a1a66ac631ea58f35_jpg.rf.19c3ca0f4e07b112fc9b1c03c801c9bc.jpg: 800x800 6 Grenades, 1 Gun, 2 Knifes, 6.7ms
# image 226/266 /content/datasets/Weapon-Detection-1/test/images/dragunov-SVD_jpg.rf.bd4a895a59d2105b6a79d973909b2955.jpg: 512x800 1 Gun, 1 Knife, 9.5ms
# image 227/266 /content/datasets/Weapon-Detection-1/test/images/e6905c01d43ca6482338f3de37a554a3_jpg.rf.ff5d698bedafffb7cf768e7071006f74.jpg: 800x800 3 Grenades, 1 Gun, 1 Pistol, 7.7ms
# image 228/266 /content/datasets/Weapon-Detection-1/test/images/e7f0d0ae50effb67d2a9304c84c86b6d_jpg.rf.d0cf3864a842ffe3953b56a2e543f7fa.jpg: 800x800 2 Guns, 1 Knife, 1 Pistol, 6.8ms
# image 229/266 /content/datasets/Weapon-Detection-1/test/images/eed542dd033719aeb762b884a624b430_jpg.rf.e1ab97558d0c99af56e15c782fcb5b02.jpg: 800x800 1 Gun, 1 Knife, 1 Pistol, 6.6ms
# image 230/266 /content/datasets/Weapon-Detection-1/test/images/efddb53d5941eb313d3da2c8f92f6275_jpg.rf.bcafb70b199af01c4cfe70047441cd26.jpg: 800x800 1 Gun, 1 Knife, 2 Pistols, 6.6ms
# image 231/266 /content/datasets/Weapon-Detection-1/test/images/f6dc4ecf84af15c4b38de96f234572d4_jpg.rf.ee3a5860ab9f50684de1dd41d90d0951.jpg: 800x800 3 Guns, 2 Knifes, 1 Pistol, 6.5ms
# image 232/266 /content/datasets/Weapon-Detection-1/test/images/fghdfydrfhsdfg_jpg.rf.6894ebbeec8958f975aa547701492439.jpg: 448x800 1 Grenade, 1 Gun, 7.2ms
# image 233/266 /content/datasets/Weapon-Detection-1/test/images/flat-army-military-composition-with-automatic-machines-pistol-grenade-bullets-knife-binoculars-submarine-tank-helicopter_1284-35411_png_jpg.rf.20974a5d16af9dc3cd7a92fae9ef2b4b.jpg: 800x800 1 Grenade, 2 Guns, 1 Knife, 7.1ms
# image 234/266 /content/datasets/Weapon-Detection-1/test/images/frame-517_jpg.rf.845e821ec1c103dbf5c4b0e7b1cbae3f.jpg: 480x800 4 Grenades, 1 Gun, 5 Knifes, 2 Pistols, 7.7ms
# image 235/266 /content/datasets/Weapon-Detection-1/test/images/frame-id-123_jpg.rf.dc852801f554b211decd51c9bf0235b3.jpg: 608x800 1 Grenade, 2 Knifes, 7.3ms
# image 236/266 /content/datasets/Weapon-Detection-1/test/images/frame-id-144_jpg.rf.86d35035ef6e32519905ed5ec927e3e1.jpg: 608x800 1 Grenade, 2 Knifes, 6.8ms
# image 237/266 /content/datasets/Weapon-Detection-1/test/images/frame-id-149_jpg.rf.bd949991ef026918b19c524da4ef030d.jpg: 608x800 1 Grenade, 2 Knifes, 6.7ms
# image 238/266 /content/datasets/Weapon-Detection-1/test/images/frame-id-157_jpg.rf.35dbaa15618dce74a3a67da77861992c.jpg: 608x800 1 Grenade, 2 Knifes, 6.6ms
# image 239/266 /content/datasets/Weapon-Detection-1/test/images/frame-id-187_jpg.rf.f1d072389280f6e5c09a1fd57f08f595.jpg: 608x800 1 Grenade, 2 Knifes, 6.7ms
# image 240/266 /content/datasets/Weapon-Detection-1/test/images/frame13_jpg.rf.8881f2d8f79ade6f0ebb24badb88242b.jpg: 800x800 2 Grenades, 3 Guns, 7.2ms
# image 241/266 /content/datasets/Weapon-Detection-1/test/images/frame29_jpg.rf.809017ecaf12f699aabd4b4eeb84d50c.jpg: 480x800 1 Grenade, 6 Guns, 7.3ms
# image 242/266 /content/datasets/Weapon-Detection-1/test/images/ghujftgyuj54564654imagfghfdghdftghdfgh65dfg6hdf6g5hes_jpg.rf.bd89ca74a68e26bcbfd9fccdcc37c3dc.jpg: 544x800 1 Grenade, 1 Knife, 7.5ms
# image 243/266 /content/datasets/Weapon-Detection-1/test/images/gun-bomb-isolated-white-background-copy-space-gun-bomb-isolated-white-background-copy-space-tula-tt-symbol-sign-159331889_jpg.rf.42f8604975996c5e045f0815d421d4d2.jpg: 576x800 1 Grenade, 1 Pistol, 7.5ms
# image 244/266 /content/datasets/Weapon-Detection-1/test/images/ima5FG6H6FG541H65FG41H6F5G4H1F654H6FR5ge_jpg.rf.853969e7d20439b5a334d29d3ef06e73.jpg: 800x768 2 Grenades, 1 Gun, 1 Knife, 1 Pistol, 8.2ms
# image 245/266 /content/datasets/Weapon-Detection-1/test/images/imaDF6GH5FDGH1651GH6DF51H654FSD1Hge_jpg.rf.48abfadfceb47642f0aab377548ba7ac.jpg: 512x800 2 Grenades, 1 Gun, 1 Knife, 1 Pistol, 8.0ms
# image 246/266 /content/datasets/Weapon-Detection-1/test/images/image4ujg4fh65dyh65df4h65dfg65h4d_jpg.rf.6bc25e8ca4751e376c1059cac960d70b.jpg: 448x800 1 Grenade, 1 Knife, 7.7ms
# image 247/266 /content/datasets/Weapon-Detection-1/test/images/isxfgodpojgdpiosjfgidjpg654616516516dfmages_jpg.rf.0d644f77a089d5b126a809612aa0ac95.jpg: 800x448 2 Grenades, 1 Knife, 49.5ms
# image 248/266 /content/datasets/Weapon-Detection-1/test/images/lee-enfield-mk-1-ww1-rifle-GR09C9_jpg.rf.c106b81e587e8ef0fd529600d983cc7b.jpg: 608x800 4 Grenades, 1 Gun, 7.8ms
# image 249/266 /content/datasets/Weapon-Detection-1/test/images/machine-strap-ak-47-akm-wallpaper-preview_jpg.rf.35ff33e6e795ea4779cdc4491bc6b76b.jpg: 448x800 1 Gun, 1 Knife, 7.5ms
# image 250/266 /content/datasets/Weapon-Detection-1/test/images/main-qimg-28c8d6e339820cf8a1d5fa226ac98852-lq_jpg.rf.98b1c1b2b932364ca2399db30f18b0b5.jpg: 800x800 5 Grenades, 1 Gun, 7.7ms
# image 251/266 /content/datasets/Weapon-Detection-1/test/images/main-qimg-28c8d6e339820cf8a1d5fa226ac98852-lq_jpg.rf.da5deb65001a8572032483276880edf4.jpg: 800x800 5 Grenades, 1 Gun, 6.7ms
# image 252/266 /content/datasets/Weapon-Detection-1/test/images/matus-pavkeje-meleeassets_jpg.rf.9d3badb9fe6e1c20b176477123a9af5c.jpg: 800x800 1 Grenade, 1 Knife, 6.7ms
# image 253/266 /content/datasets/Weapon-Detection-1/test/images/matus-pavkeje-meleeassets_jpg.rf.d0ccca6806ba7691123e5ab73f4e82c2.jpg: 800x800 1 Grenade, 1 Knife, 6.6ms
# image 254/266 /content/datasets/Weapon-Detection-1/test/images/maxresdefault_jpg.rf.980a23c9eeba9d561ae6cf00804a24e6.jpg: 480x800 2 Guns, 2 Pistols, 7.3ms
# image 255/266 /content/datasets/Weapon-Detection-1/test/images/military-man-holding-automatic-rifle-hand-grenade-young-handsome-military-man-holding-automatic-rifle-hand-grenade-sky-129921936_jpg.rf.a2ae806bdc04d28dc4ac6c45630be6b6.jpg: 800x544 1 Grenade, 1 Gun, 7.1ms
# image 256/266 /content/datasets/Weapon-Detection-1/test/images/new1_png_jpg.rf.d91751f227e882cc654d2936a7ceb2d1.jpg: 800x800 1 Gun, 1 Pistol, 7.2ms
# image 257/266 /content/datasets/Weapon-Detection-1/test/images/new4_png_jpg.rf.728911e01d0c82fcca0b0101ccafc3b1.jpg: 544x800 1 Gun, 2 Knifes, 7.3ms
# image 258/266 /content/datasets/Weapon-Detection-1/test/images/new6_png_jpg.rf.bc87151857f90137f917f9252f34ce21.jpg: 800x576 1 Gun, 1 Pistol, 7.3ms
# image 259/266 /content/datasets/Weapon-Detection-1/test/images/retro-wwii-bunk-soldier-equipment-his-items-include-helmet-gun-rifle-carbine-grenade-mess-kit-army-boots-more-31651682_jpg.rf.834cfef44db1468363e460c778fad803.jpg: 800x800 1 Grenade, 1 Gun, 1 Knife, 7.2ms
# image 260/266 /content/datasets/Weapon-Detection-1/test/images/sddefault_jpg.rf.63be93688e572d12aa819e04117e21aa.jpg: 608x800 2 Grenades, 2 Pistols, 7.6ms
# image 261/266 /content/datasets/Weapon-Detection-1/test/images/sdfsdfdgf4dg4fdDFFG4744_png_jpg.rf.45a630788ac159ea7b7ffa6482b3e80f.jpg: 800x800 2 Grenades, 2 Knifes, 7.5ms
# image 262/266 /content/datasets/Weapon-Detection-1/test/images/stielhandgranate-german-stick-hand-grenade-was-german-hand-grenade-distinguished-its-wooden-handle-yorkshire-wartime-228364585_jpg.rf.96cb2b9615bf2996ca3eb6f9db989226.jpg: 800x800 6 Grenades, 2 Guns, 2 Pistols, 6.7ms
# image 263/266 /content/datasets/Weapon-Detection-1/test/images/test5_jpg.rf.086d1f3ada86ab0e9743ccf7b77b329d.jpg: 544x800 2 Grenades, 1 Pistol, 7.4ms
# image 264/266 /content/datasets/Weapon-Detection-1/test/images/tfuytfuy546646imayhfui54uj65u65jh4tf4yges_jpg.rf.9486113cc9277a238df8e8667c7027fd.jpg: 768x800 1 Grenade, 1 Knife, 7.2ms
# image 265/266 /content/datasets/Weapon-Detection-1/test/images/war-and-peace-revival-july-2013-folkestone-racecourse-kent-england-DDW0BX_jpg.rf.941cf1a2fc1a6a4cdf905b0b07a4a986.jpg: 608x800 7 Grenades, 1 Gun, 7.4ms
# image 266/266 /content/datasets/Weapon-Detection-1/test/images/ww2-german-army-soldiers-equipment-including-stick-grenade-knife-flare-BNFGAF_jpg.rf.ba29b37edd57e821ed0adbd653e6bccf.jpg: 800x512 2 Grenades, 2 Knifes, 2 Pistols, 48.5ms
# Speed: 3.0ms preprocess, 10.4ms inference, 3.4ms postprocess per image at shape (1, 3, 800, 512)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.103, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/final-ai-solution/weapon-detection-dinou-qdunh-ihnjy/1
# Share your model with the world at: https://universe.roboflow.com/final-ai-solution/weapon-detection-dinou-qdunh-ihnjy/model/1

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-afd7f5f31b70> in <cell line: 0>()
#       3 # Load model
#       4 model = project.version(dataset.version).model
# ----> 5 assert model, "Model deployment is still loading"
#       6
#       7 # Choose a random test image
#
# AssertionError: Model deployment is still loading

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.

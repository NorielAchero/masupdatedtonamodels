# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the accompanying [Blog Post](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset/).
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Jan 16 17:43:21 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0              42W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 30.8/235.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 74.8MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 92.2MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 51.0ms
# Speed: 15.7ms preprocess, 51.0ms inference, 765.3ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 51.4ms
# Speed: 6.3ms preprocess, 51.4ms inference, 556.1ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.0000,  314.5054,  625.0387, 1278.1901],
#         [  55.3276,  250.0223,  648.1048, 1266.2391],
#         [ 633.2264,  719.5393,  701.0568,  786.0264]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.7269, 0.2905, 0.2843], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a [supported format](https://roboflow.com/formats), the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v8` dataset format. (Formerly, we used to use `Yolov5`, as the gif shows)
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# 🟢 Tip: The examples below work even if you use our non-custom model. However, you won't be able to deploy it to Roboflow. To do that, create a custom dataset as described below or fork (copy) one into your workspace from Universe.

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow==1.1.48 --quiet

import roboflow

roboflow.login()

rf = roboflow.Roboflow()

project = rf.workspace("ai-solution-a0qsv").project("distracted-driving-fsygw")
dataset = project.version(3).download("yolov8")
# Out:
# /content/datasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# Downloading Dataset Version Zip in Distracted-Driving-3 to yolov8:: 100%|██████████| 864179/864179 [00:11<00:00, 78272.09it/s]
# Extracting Dataset Version Zip to Distracted-Driving-3 in yolov8:: 100%|██████████| 27674/27674 [00:04<00:00, 6441.49it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 140MB/s]
# New https://pypi.org/project/ultralytics/8.3.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/Distracted-Driving-3/data.yaml, epochs=25, time=None, patience=100, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 13.2MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# Model summary: 225 layers, 11,136,374 parameters, 11,136,358 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/datasets/Distracted-Driving-3/train/labels... 13098 images, 537 backgrounds, 0 corrupt: 100% 13098/13098 [00:08<00:00, 1509.72it/s]
# train: New cache created: /content/datasets/Distracted-Driving-3/train/labels.cache
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.0 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Distracted-Driving-3/valid/labels... 605 images, 13 backgrounds, 0 corrupt: 100% 605/605 [00:00<00:00, 1323.82it/s]
# val: New cache created: /content/datasets/Distracted-Driving-3/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      6.05G       1.59      1.614      1.554         15        800: 100% 819/819 [01:42<00:00,  7.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:04<00:00,  4.74it/s]
#                    all        605        599      0.682      0.551      0.632      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      5.79G      1.599      1.343       1.55         17        800: 100% 819/819 [01:37<00:00,  8.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.41it/s]
#                    all        605        599      0.715      0.634       0.68      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      5.76G      1.551      1.236      1.514         16        800: 100% 819/819 [01:34<00:00,  8.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.28it/s]
#                    all        605        599      0.812      0.771      0.832      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      5.78G      1.474      1.109      1.461         18        800: 100% 819/819 [01:33<00:00,  8.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.33it/s]
#                    all        605        599       0.75      0.781      0.819      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      5.78G      1.393     0.9863      1.396         13        800: 100% 819/819 [01:33<00:00,  8.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.33it/s]
#                    all        605        599      0.819      0.813      0.859      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      5.74G      1.346     0.8974      1.358         16        800: 100% 819/819 [01:33<00:00,  8.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.35it/s]
#                    all        605        599      0.851      0.831      0.892      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      5.79G      1.301     0.8318      1.328         25        800: 100% 819/819 [01:33<00:00,  8.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.37it/s]
#                    all        605        599      0.844      0.857      0.905      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      5.77G      1.252     0.7888      1.302         20        800: 100% 819/819 [01:33<00:00,  8.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.48it/s]
#                    all        605        599      0.867      0.835      0.905        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      5.81G      1.228     0.7512      1.282         16        800: 100% 819/819 [01:34<00:00,  8.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.46it/s]
#                    all        605        599      0.912      0.876      0.931      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      5.99G      1.196     0.7134      1.257         18        800: 100% 819/819 [01:33<00:00,  8.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.61it/s]
#                    all        605        599      0.926       0.88      0.935      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      5.76G      1.157     0.6737      1.231         12        800: 100% 819/819 [01:33<00:00,  8.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.74it/s]
#                    all        605        599      0.871      0.883      0.922      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      5.76G      1.135     0.6502      1.221         15        800: 100% 819/819 [01:33<00:00,  8.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.67it/s]
#                    all        605        599      0.927      0.892      0.946      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      5.79G      1.113     0.6311      1.202         19        800: 100% 819/819 [01:33<00:00,  8.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.76it/s]
#                    all        605        599      0.927      0.892      0.938      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      5.99G      1.095     0.6093      1.195         21        800: 100% 819/819 [01:33<00:00,  8.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.69it/s]
#                    all        605        599      0.923      0.882      0.937        0.7
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      5.77G      1.061     0.5814      1.174         18        800: 100% 819/819 [01:33<00:00,  8.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.67it/s]
#                    all        605        599      0.929      0.898      0.952      0.718
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      5.76G      1.021     0.4748      1.156          9        800: 100% 819/819 [01:33<00:00,  8.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.60it/s]
#                    all        605        599      0.921      0.903      0.952      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      5.79G     0.9853     0.4501       1.13         10        800: 100% 819/819 [01:33<00:00,  8.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.67it/s]
#                    all        605        599      0.926      0.902      0.955      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      5.99G     0.9615     0.4317      1.117         10        800: 100% 819/819 [01:33<00:00,  8.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.50it/s]
#                    all        605        599      0.916      0.916      0.958      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      5.77G     0.9236     0.4148      1.094         10        800: 100% 819/819 [01:32<00:00,  8.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.77it/s]
#                    all        605        599      0.953      0.912       0.96      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      5.78G     0.9019     0.3977      1.075         10        800: 100% 819/819 [01:33<00:00,  8.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.60it/s]
#                    all        605        599      0.945      0.912      0.961      0.742
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      5.79G     0.8713     0.3794      1.059         11        800: 100% 819/819 [01:33<00:00,  8.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.71it/s]
#                    all        605        599      0.935      0.907       0.96      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      5.99G     0.8486     0.3673      1.042          9        800: 100% 819/819 [01:33<00:00,  8.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.68it/s]
#                    all        605        599      0.944      0.934      0.969      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      5.77G     0.8236     0.3507      1.029         10        800: 100% 819/819 [01:33<00:00,  8.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.54it/s]
#                    all        605        599      0.959      0.903      0.964      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      5.76G     0.7919     0.3365      1.016         11        800: 100% 819/819 [01:33<00:00,  8.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.63it/s]
#                    all        605        599      0.931      0.933      0.971      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      5.79G     0.7714      0.326      1.004         10        800: 100% 819/819 [01:33<00:00,  8.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:02<00:00,  7.65it/s]
#                    all        605        599      0.957       0.91       0.97      0.764
#
# 25 epochs completed in 0.678 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 19/19 [00:03<00:00,  5.97it/s]
#                    all        605        599      0.957       0.91       0.97      0.764
#        Eating Drinking        299        301      0.931      0.884      0.953      0.771
#            Using Phone        293        298      0.982      0.936      0.986      0.757
# Speed: 0.2ms preprocess, 1.3ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Distracted-Driving-3/valid/labels.cache... 605 images, 13 backgrounds, 0 corrupt: 100% 605/605 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 38/38 [00:04<00:00,  8.53it/s]
#                    all        605        599      0.957       0.91       0.97      0.765
#        Eating Drinking        299        301      0.931      0.884      0.953      0.773
#            Using Phone        293        298      0.982      0.936      0.986      0.758
# Speed: 0.5ms preprocess, 1.8ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/128 /content/datasets/Distracted-Driving-3/test/images/-_20230508110703_jpg.rf.6a749bf9825123bf387b83b45b5f0796.jpg: 800x800 1 Using Phone, 7.3ms
# image 2/128 /content/datasets/Distracted-Driving-3/test/images/-_202305081107041_jpg.rf.d0a179de7f800290e06d0191ce21afc6.jpg: 800x800 1 Using Phone, 7.9ms
# image 3/128 /content/datasets/Distracted-Driving-3/test/images/-_202305081143472_jpg.rf.e73bbeabaa7922404136834d02004f28.jpg: 800x800 1 Using Phone, 7.2ms
# image 4/128 /content/datasets/Distracted-Driving-3/test/images/-_20230508114347_jpg.rf.e288a46b4137d4a1ed931c5a9493c72d.jpg: 800x800 1 Using Phone, 6.8ms
# image 5/128 /content/datasets/Distracted-Driving-3/test/images/-_202305081238372_jpg.rf.313d30440674b400d54ca115d56840c7.jpg: 800x800 1 Using Phone, 6.7ms
# image 6/128 /content/datasets/Distracted-Driving-3/test/images/1001-116-_jpg.rf.c0c567469abf19a9bd7bb407eca193f5.jpg: 800x800 1 Using Phone, 6.8ms
# image 7/128 /content/datasets/Distracted-Driving-3/test/images/1001-174-_jpg.rf.27618c3089e4b29fdaf72880e6d7042e.jpg: 800x800 1 Using Phone, 6.8ms
# image 8/128 /content/datasets/Distracted-Driving-3/test/images/1001-616-_jpg.rf.ced1cd14d200a7fa309b3b1ea2ba18a3.jpg: 800x800 1 Using Phone, 6.8ms
# image 9/128 /content/datasets/Distracted-Driving-3/test/images/104313frame0-00-08-03_jpg.rf.0547bf4253cd53c6fd2112a2afa1c054.jpg: 800x800 (no detections), 7.2ms
# image 10/128 /content/datasets/Distracted-Driving-3/test/images/104313frame0-00-48-55_jpg.rf.3de7ccbb8588f71fdb923a4fa6ca6626.jpg: 480x800 1 Eating Drinking, 49.6ms
# image 11/128 /content/datasets/Distracted-Driving-3/test/images/11314frame0-00-04-51_jpg.rf.34460ae9053b6656ce6f3f3c9e172209.jpg: 800x800 (no detections), 7.8ms
# image 12/128 /content/datasets/Distracted-Driving-3/test/images/13050frame0-07-17-50_jpg.rf.01de2db5a09a58afce9bb9738dc926e3.jpg: 800x800 (no detections), 6.6ms
# image 13/128 /content/datasets/Distracted-Driving-3/test/images/137e52fc11bca7a9_jpg.rf.70c2709a5cf54b2603723f01837ab528.jpg: 800x800 1 Using Phone, 6.8ms
# image 14/128 /content/datasets/Distracted-Driving-3/test/images/164049frame0-00-10-05_jpg.rf.8dfed1a88fc501feb3e4584d4dcc1fed.jpg: 800x800 (no detections), 6.7ms
# image 15/128 /content/datasets/Distracted-Driving-3/test/images/164053frame0-00-08-03_jpg.rf.4228fe2901fa92ef1f7f9661b5ca6eed.jpg: 800x800 (no detections), 6.7ms
# image 16/128 /content/datasets/Distracted-Driving-3/test/images/36_jpg.rf.d89212f6861bbebf3a35ffd697fa7fee.jpg: 800x800 3 Using Phones, 6.6ms
# image 17/128 /content/datasets/Distracted-Driving-3/test/images/4f9c586140035d9a_jpg.rf.2728ac6d21ab109d9700e5fd2dc1e5e8.jpg: 800x800 1 Using Phone, 6.6ms
# image 18/128 /content/datasets/Distracted-Driving-3/test/images/IMG-20230224-WA0107_jpg.rf.8aff70dfae9b0abf5b4a40e199ef1978.jpg: 800x800 1 Using Phone, 6.6ms
# image 19/128 /content/datasets/Distracted-Driving-3/test/images/Untitled-video-Made-with-Clipchamp_mp4-0471_jpg.rf.7797f69e1c1f24034478df072deea007.jpg: 800x800 1 Using Phone, 6.6ms
# image 20/128 /content/datasets/Distracted-Driving-3/test/images/Untitled-video-Made-with-Clipchamp_mp4-0507_jpg.rf.0f61be2ba436a948f8384ba118d15a7a.jpg: 800x800 1 Using Phone, 6.6ms
# image 21/128 /content/datasets/Distracted-Driving-3/test/images/Untitled-video-Made-with-Clipchamp_mp4-0599_jpg.rf.a34aebfee02d2ee8001530139b72be93.jpg: 800x800 1 Using Phone, 6.6ms
# image 22/128 /content/datasets/Distracted-Driving-3/test/images/Untitled-video-Made-with-Clipchamp_mp4-0627_jpg.rf.d41f0cf93a702a376fe7e0bc170e7f94.jpg: 800x800 1 Using Phone, 6.6ms
# image 23/128 /content/datasets/Distracted-Driving-3/test/images/VID_20221206_140620_020_png.rf.28e0ea10bdef5e018b4b9386bb57faf7.jpg: 800x480 1 Eating Drinking, 54.5ms
# image 24/128 /content/datasets/Distracted-Driving-3/test/images/VID_20221206_141209_230_png.rf.08d0b8d0bdc15444f990f12fa21ea501.jpg: 800x480 1 Eating Drinking, 7.4ms
# image 25/128 /content/datasets/Distracted-Driving-3/test/images/Video2_8_258_jpg.rf.a5308d10c7d055bfe4670b5b1b012067.jpg: 800x800 1 Using Phone, 7.5ms
# image 26/128 /content/datasets/Distracted-Driving-3/test/images/WIN_20220705_14_15_04_Pro-2-_jpg.rf.a96b338db472c9a803dbf9ef6f229253.jpg: 800x800 1 Using Phone, 7.2ms
# image 27/128 /content/datasets/Distracted-Driving-3/test/images/WIN_20220705_14_15_12_Pro_jpg.rf.7b3109e4eef76371118362f6920e1885.jpg: 800x800 2 Using Phones, 6.7ms
# image 28/128 /content/datasets/Distracted-Driving-3/test/images/WIN_20220722_12_32_06_Pro_jpg.rf.5ab6283878b36b79feda7a937a913fff.jpg: 800x800 1 Using Phone, 6.7ms
# image 29/128 /content/datasets/Distracted-Driving-3/test/images/WIN_20220722_14_03_03_Pro_jpg.rf.d275111a8c930534617bd3c0ad340e1b.jpg: 800x800 1 Using Phone, 6.6ms
# image 30/128 /content/datasets/Distracted-Driving-3/test/images/WIN_20220722_17_49_01_Pro-3-_jpg.rf.af857fe240a027cf8b61d8d201352e05.jpg: 800x800 1 Using Phone, 6.6ms
# image 31/128 /content/datasets/Distracted-Driving-3/test/images/WIN_20220728_14_32_17_Pro_jpg.rf.603bbc1672de15f8c97cda86a284342f.jpg: 800x800 1 Using Phone, 6.6ms
# image 32/128 /content/datasets/Distracted-Driving-3/test/images/WIN_20220728_14_33_11_Pro_jpg.rf.f155ba1b2b5051cda7396b707838cf86.jpg: 800x800 1 Using Phone, 6.6ms
# image 33/128 /content/datasets/Distracted-Driving-3/test/images/WhatsApp-Image-2022-02-22-at-11-58-56-PM_jpeg.rf.5eaa64ee99b9d2b83daaa5e71e1b1a41.jpg: 800x800 1 Using Phone, 6.6ms
# image 34/128 /content/datasets/Distracted-Driving-3/test/images/_-12-_mp4-75_jpg.rf.e57c55d556b3747aa324a3abcb262951.jpg: 800x800 1 Using Phone, 6.6ms
# image 35/128 /content/datasets/Distracted-Driving-3/test/images/_-12-_mp4-80_jpg.rf.b900d7e63a2fdd3497bc3f6dfbfec3c3.jpg: 800x800 1 Using Phone, 6.9ms
# image 36/128 /content/datasets/Distracted-Driving-3/test/images/_-2-_mp4-29_jpg.rf.26247f8cde3888eba700738215135cb5.jpg: 800x800 1 Using Phone, 6.6ms
# image 37/128 /content/datasets/Distracted-Driving-3/test/images/_-2-_mp4-37_jpg.rf.3763110a4ccc557fd37ca592bdbeddd3.jpg: 800x800 1 Using Phone, 6.6ms
# image 38/128 /content/datasets/Distracted-Driving-3/test/images/_-2-_mp4-65_jpg.rf.4f77d659c1fbdb177d53b2c877cbe98f.jpg: 800x800 1 Using Phone, 6.6ms
# image 39/128 /content/datasets/Distracted-Driving-3/test/images/_-3-_mp4-79_jpg.rf.fdca6da42bf8b5643d7d63b944e9f5b6.jpg: 800x800 1 Using Phone, 6.6ms
# image 40/128 /content/datasets/Distracted-Driving-3/test/images/_-43-_mp4-16_jpg.rf.9d1d612c53f5b2e3bf0a5641593d4d01.jpg: 800x800 1 Using Phone, 6.6ms
# image 41/128 /content/datasets/Distracted-Driving-3/test/images/_-43-_mp4-42_jpg.rf.9b362e0104a29ce62c63034b384f43e9.jpg: 800x800 1 Using Phone, 6.6ms
# image 42/128 /content/datasets/Distracted-Driving-3/test/images/_-44-_mp4-27_jpg.rf.1b04021d3fa90281326af9b1f8565666.jpg: 800x800 1 Using Phone, 7.0ms
# image 43/128 /content/datasets/Distracted-Driving-3/test/images/_-45-_mp4-32_jpg.rf.962196a72a7e262983febacb6ba7580e.jpg: 800x800 1 Using Phone, 6.6ms
# image 44/128 /content/datasets/Distracted-Driving-3/test/images/_-45-_mp4-5_jpg.rf.6cf3f6bd7a4af809617c8507d070e8a5.jpg: 800x800 1 Using Phone, 6.6ms
# image 45/128 /content/datasets/Distracted-Driving-3/test/images/_-46-_mp4-31_jpg.rf.f9a1b3f501ab42684da031c09f8b7b02.jpg: 800x800 1 Using Phone, 7.0ms
# image 46/128 /content/datasets/Distracted-Driving-3/test/images/_-53-_mp4-82_jpg.rf.9a6eaf708fa8397332138476efdd10b7.jpg: 800x800 1 Using Phone, 6.7ms
# image 47/128 /content/datasets/Distracted-Driving-3/test/images/_-54-_mp4-18_jpg.rf.3098397ed79eda025516653bab9f1eed.jpg: 800x800 1 Using Phone, 7.0ms
# image 48/128 /content/datasets/Distracted-Driving-3/test/images/_-54-_mp4-56_jpg.rf.aa11eb76bcd544cac1e2099aadc36709.jpg: 800x800 1 Using Phone, 6.8ms
# image 49/128 /content/datasets/Distracted-Driving-3/test/images/_-59-_mp4-30_jpg.rf.ea4f2642e2991d9b83fcfe7c1331c4f7.jpg: 800x800 1 Using Phone, 6.6ms
# image 50/128 /content/datasets/Distracted-Driving-3/test/images/_-59-_mp4-83_jpg.rf.c5f7ff69d6b2720058b34041096990c7.jpg: 800x800 1 Using Phone, 6.6ms
# image 51/128 /content/datasets/Distracted-Driving-3/test/images/cell05_0093_jpg.rf.1f6ddf8921690626a262671e445e5a69.jpg: 800x800 1 Using Phone, 6.6ms
# image 52/128 /content/datasets/Distracted-Driving-3/test/images/elite-daily-Studio-Firma-phone_jpg.rf.c78156932c8f5c574a050ecbd2b2625c.jpg: 800x800 1 Using Phone, 6.6ms
# image 53/128 /content/datasets/Distracted-Driving-3/test/images/goruntu_1689755960_jpg.rf.4cf119d708984835cc52b40b92ee42a6.jpg: 800x800 1 Using Phone, 6.6ms
# image 54/128 /content/datasets/Distracted-Driving-3/test/images/image2442_png.rf.8563ac22c4ff59fddc337a0cc91841f3.jpg: 800x800 1 Eating Drinking, 6.6ms
# image 55/128 /content/datasets/Distracted-Driving-3/test/images/img_11358_jpg.rf.28bdcae21594f26b4db9a4741fe28786.jpg: 608x800 1 Eating Drinking, 50.0ms
# image 56/128 /content/datasets/Distracted-Driving-3/test/images/img_11621_jpg.rf.e5763aa321aae255f9932cf222e22529.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 57/128 /content/datasets/Distracted-Driving-3/test/images/img_12066_jpg.rf.d9837360e9cbce878b4388f1cbb08008.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 58/128 /content/datasets/Distracted-Driving-3/test/images/img_12892_jpg.rf.bddeb3f407c9690b871ea8e83e17f724.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 59/128 /content/datasets/Distracted-Driving-3/test/images/img_13194_jpg.rf.80afa7b3c3cea7eb9f55908811316e9e.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 60/128 /content/datasets/Distracted-Driving-3/test/images/img_13516_jpg.rf.9f72a7bafc034874a8f3e78f18bd6dc3.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 61/128 /content/datasets/Distracted-Driving-3/test/images/img_13900_jpg.rf.a24ddfc3bc329287abc564bc8f25d51e.jpg: 608x800 1 Eating Drinking, 6.9ms
# image 62/128 /content/datasets/Distracted-Driving-3/test/images/img_14108_jpg.rf.6adc7461e61347fd30093a23c341b0bc.jpg: 608x800 1 Eating Drinking, 7.0ms
# image 63/128 /content/datasets/Distracted-Driving-3/test/images/img_14240_jpg.rf.f35b6c23e29fdb251f347d22ce9cc2f2.jpg: 608x800 1 Eating Drinking, 6.9ms
# image 64/128 /content/datasets/Distracted-Driving-3/test/images/img_14351_jpg.rf.77e8e03f72153e6954b030c6ad7be49b.jpg: 608x800 2 Eating Drinkings, 6.7ms
# image 65/128 /content/datasets/Distracted-Driving-3/test/images/img_14664_jpg.rf.daf7f02c08fc4e3a200504906b3047ce.jpg: 608x800 1 Eating Drinking, 7.1ms
# image 66/128 /content/datasets/Distracted-Driving-3/test/images/img_15223_jpg.rf.d0756095066704757c003d765350d2d4.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 67/128 /content/datasets/Distracted-Driving-3/test/images/img_15592_jpg.rf.b8a111add686541537990e3e79955e17.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 68/128 /content/datasets/Distracted-Driving-3/test/images/img_16148_jpg.rf.1080e79e1dc684d17934f2ed891a37f6.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 69/128 /content/datasets/Distracted-Driving-3/test/images/img_16171_jpg.rf.edf4cab941248459de0bc26e172c94a3.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 70/128 /content/datasets/Distracted-Driving-3/test/images/img_16374_jpg.rf.5ae3f8477f775f9eaf6ce56f640fc2b2.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 71/128 /content/datasets/Distracted-Driving-3/test/images/img_16458_jpg.rf.2d20bea1e874eef368f0ab3377f6ec5c.jpg: 608x800 2 Eating Drinkings, 6.6ms
# image 72/128 /content/datasets/Distracted-Driving-3/test/images/img_16526_jpg.rf.deed3575fe791c9a5fbbfe7845df1004.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 73/128 /content/datasets/Distracted-Driving-3/test/images/img_16735_jpg.rf.aee46bbd9048a448fd84388723240430.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 74/128 /content/datasets/Distracted-Driving-3/test/images/img_18016_jpg.rf.a4650b3ebbd4342163eb33ccf2e51981.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 75/128 /content/datasets/Distracted-Driving-3/test/images/img_18178_jpg.rf.7d82e68e92f06da64d11b178a9e8d8c2.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 76/128 /content/datasets/Distracted-Driving-3/test/images/img_18234_jpg.rf.32c5c8f3b7aa4987af7098f89723c056.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 77/128 /content/datasets/Distracted-Driving-3/test/images/img_18548_jpg.rf.724446a7f180cdc3417ec39c7b661bf3.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 78/128 /content/datasets/Distracted-Driving-3/test/images/img_18707_jpg.rf.678624ac4b8b940661247f7ef54e85bf.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 79/128 /content/datasets/Distracted-Driving-3/test/images/img_18807_jpg.rf.70ec8292906c3579261b0c4c803c4c05.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 80/128 /content/datasets/Distracted-Driving-3/test/images/img_18944_jpg.rf.2caed7b3cda8b6d60b198cc1f7c882e5.jpg: 608x800 1 Eating Drinking, 7.5ms
# image 81/128 /content/datasets/Distracted-Driving-3/test/images/img_19410_jpg.rf.fae620e5be2e36e5e10933550e2816a0.jpg: 608x800 1 Eating Drinking, 7.0ms
# image 82/128 /content/datasets/Distracted-Driving-3/test/images/img_19655_jpg.rf.a884362ccf4f3230ba62f82c3ea736fa.jpg: 608x800 1 Eating Drinking, 7.1ms
# image 83/128 /content/datasets/Distracted-Driving-3/test/images/img_19675_jpg.rf.69bda7169db24712b706b0ca1ec9c8a1.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 84/128 /content/datasets/Distracted-Driving-3/test/images/img_20218_jpg.rf.4e6e1589f6107548e6bbe371c2075862.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 85/128 /content/datasets/Distracted-Driving-3/test/images/img_20333_jpg.rf.7e62987c6a09d012b700453b3d6fff07.jpg: 608x800 1 Eating Drinking, 7.0ms
# image 86/128 /content/datasets/Distracted-Driving-3/test/images/img_20620_jpg.rf.ac7756b88d6dbb6b04bb9c65578e8b4f.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 87/128 /content/datasets/Distracted-Driving-3/test/images/img_20716_jpg.rf.62c57183acce947ae1a3a3a74b2fe751.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 88/128 /content/datasets/Distracted-Driving-3/test/images/img_21058_jpg.rf.a7c0c442d0d01e6cd50b831664597885.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 89/128 /content/datasets/Distracted-Driving-3/test/images/img_21068_jpg.rf.bd8f9152bd4f916a1d068a87f4694d5b.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 90/128 /content/datasets/Distracted-Driving-3/test/images/img_21565_jpg.rf.a06b402b4fc9d26f947befda55283595.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 91/128 /content/datasets/Distracted-Driving-3/test/images/img_21581_jpg.rf.510ec8678a019e6b031b16b8ecb38021.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 92/128 /content/datasets/Distracted-Driving-3/test/images/img_22101_jpg.rf.3258ca29aef06bf99abcdc10439ba1fd.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 93/128 /content/datasets/Distracted-Driving-3/test/images/img_22237_jpg.rf.0bb3ae8e04ba7844267b33d203ab0720.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 94/128 /content/datasets/Distracted-Driving-3/test/images/img_23396_jpg.rf.74782ee105ac4b125899297004b2ea21.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 95/128 /content/datasets/Distracted-Driving-3/test/images/img_23850_jpg.rf.12a52b9937e9e3dbc70424d56396d2cf.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 96/128 /content/datasets/Distracted-Driving-3/test/images/img_24003_jpg.rf.95b363826e9dbcede692e887e1f9dae5.jpg: 608x800 2 Eating Drinkings, 6.8ms
# image 97/128 /content/datasets/Distracted-Driving-3/test/images/img_24276_jpg.rf.558cb2d8866dee126b45bdab56486424.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 98/128 /content/datasets/Distracted-Driving-3/test/images/img_24905_jpg.rf.2f80753408bfd517c7286f9daa9e5224.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 99/128 /content/datasets/Distracted-Driving-3/test/images/img_24925_jpg.rf.24f0468bbb908784bfe89dc0ac1ccbef.jpg: 608x800 1 Eating Drinking, 7.3ms
# image 100/128 /content/datasets/Distracted-Driving-3/test/images/img_25153_jpg.rf.054137e47486c16ec17809ee9f28c6b6.jpg: 608x800 1 Eating Drinking, 7.0ms
# image 101/128 /content/datasets/Distracted-Driving-3/test/images/img_25404_jpg.rf.ee7c48da3b6829c9883d7780117bfe90.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 102/128 /content/datasets/Distracted-Driving-3/test/images/img_25489_jpg.rf.7d523d704cb90ef9446fb4555edc2dc7.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 103/128 /content/datasets/Distracted-Driving-3/test/images/img_25763_jpg.rf.afd9f9ae01c453ab1a9deca0b9b10f26.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 104/128 /content/datasets/Distracted-Driving-3/test/images/img_26104_jpg.rf.76ec5365c7c5fd624ad65167437652d2.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 105/128 /content/datasets/Distracted-Driving-3/test/images/img_26202_jpg.rf.2523d9512145bca07e94307161c8f74f.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 106/128 /content/datasets/Distracted-Driving-3/test/images/img_26549_jpg.rf.1126d4058099dc02c3223235e88dfe69.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 107/128 /content/datasets/Distracted-Driving-3/test/images/img_26875_jpg.rf.d1dfa4a162d9bf54290e9ee28798f69e.jpg: 608x800 1 Eating Drinking, 6.7ms
# image 108/128 /content/datasets/Distracted-Driving-3/test/images/img_26918_jpg.rf.174a906cecda34623716784d64d85634.jpg: 608x800 1 Eating Drinking, 6.8ms
# image 109/128 /content/datasets/Distracted-Driving-3/test/images/img_27207_jpg.rf.f3f75a07cd22fb7d404e4c5e2e66a756.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 110/128 /content/datasets/Distracted-Driving-3/test/images/img_27522_jpg.rf.37b1d79bb25cf4b82b89111720733b2a.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 111/128 /content/datasets/Distracted-Driving-3/test/images/img_27903_jpg.rf.c7dae5151f87b0ac60e18cd81ed761d6.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 112/128 /content/datasets/Distracted-Driving-3/test/images/img_27972_jpg.rf.214678372f7bad3a0ed5219aca49d082.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 113/128 /content/datasets/Distracted-Driving-3/test/images/img_28125_jpg.rf.62ad13a96c98066da29ea4b993ec07d0.jpg: 608x800 1 Eating Drinking, 6.5ms
# image 114/128 /content/datasets/Distracted-Driving-3/test/images/img_28781_jpg.rf.32831443338f028a9c498e40905cbe40.jpg: 608x800 2 Eating Drinkings, 6.6ms
# image 115/128 /content/datasets/Distracted-Driving-3/test/images/img_28791_jpg.rf.3ccd9f75c0001d491eaa7b1bc53e0527.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 116/128 /content/datasets/Distracted-Driving-3/test/images/img_29549_jpg.rf.5863db51cead22883e4a032427e61fe1.jpg: 608x800 1 Eating Drinking, 6.6ms
# image 117/128 /content/datasets/Distracted-Driving-3/test/images/img_32055_jpg.rf.72166100d8e0a24a12ed5e4393604528.jpg: 608x800 1 Eating Drinking, 6.5ms
# image 118/128 /content/datasets/Distracted-Driving-3/test/images/img_4_0_jpg.rf.b4a5c5d5ced83158c6a6af59edc711be.jpg: 800x800 1 Using Phone, 7.1ms
# image 119/128 /content/datasets/Distracted-Driving-3/test/images/man-shirt-phone-to-your-ear-29592975_jpg.rf.192b2634a4ea0fdfcee45110c9e8b114.jpg: 800x800 1 Using Phone, 7.5ms
# image 120/128 /content/datasets/Distracted-Driving-3/test/images/phone_call166_0_flip_jpg.rf.c14d987bbc04b1faf55998a82f63efd0.jpg: 800x800 1 Using Phone, 7.0ms
# image 121/128 /content/datasets/Distracted-Driving-3/test/images/smartphone_0805_JPG_jpg.rf.07e966c2460ecf49635769c469200d5e.jpg: 800x800 (no detections), 7.2ms
# image 122/128 /content/datasets/Distracted-Driving-3/test/images/smartphone_1005_jpg.rf.7a5b00972a4ed308d1d6144b07441ed0.jpg: 800x800 1 Using Phone, 6.7ms
# image 123/128 /content/datasets/Distracted-Driving-3/test/images/smartphone_1042_jpg.rf.eee7f5c0ce142336bfbb24ed0591c1b3.jpg: 800x800 1 Using Phone, 6.7ms
# image 124/128 /content/datasets/Distracted-Driving-3/test/images/xyzabc-208-_jpeg.rf.f58187cae9afde4a33675e9780fe7a2b.jpg: 800x800 1 Using Phone, 6.7ms
# image 125/128 /content/datasets/Distracted-Driving-3/test/images/xyzabc-247-_jpeg.rf.fcd13141799490f9fcbbeeeb78274e1d.jpg: 800x800 1 Using Phone, 6.7ms
# image 126/128 /content/datasets/Distracted-Driving-3/test/images/xyzzzzzz-151-_jpg.rf.cb84188e2dfab5ef5e23de4230508367.jpg: 800x800 1 Using Phone, 6.7ms
# image 127/128 /content/datasets/Distracted-Driving-3/test/images/xyzzzzzz-3-_jpg.rf.6d71a88cbca4eb9429a309b240497502.jpg: 800x800 2 Using Phones, 6.7ms
# image 128/128 /content/datasets/Distracted-Driving-3/test/images/xyzzzzzz-57-_jpg.rf.a80d5070c37ded3a531533951659461a.jpg: 800x800 1 Using Phone, 6.9ms
# Speed: 3.5ms preprocess, 7.8ms inference, 7.2ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.103, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/ai-solution-a0qsv/distracted-driving-fsygw/3
# Share your model with the world at: https://universe.roboflow.com/ai-solution-a0qsv/distracted-driving-fsygw/model/3

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-afd7f5f31b70> in <cell line: 0>()
#       3 # Load model
#       4 model = project.version(dataset.version).model
# ----> 5 assert model, "Model deployment is still loading"
#       6
#       7 # Choose a random test image
#
# AssertionError: Model deployment is still loading

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/runs
# Out:
# /content/runs

# %%
# !zip -r distracted.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train/R_curve.png (deflated 13%)
#   adding: content/runs/detect/train/train_batch12287.jpg (deflated 10%)
#   adding: content/runs/detect/train/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 33%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 13%)
#   adding: content/runs/detect/train/results.csv (deflated 84%)
#   adding: content/runs/detect/train/train_batch12285.jpg (deflated 10%)
#   adding: content/runs/detect/train/train_batch12286.jpg (deflated 10%)
#   adding: content/runs/detect/train/roboflow_deploy.zip (stored 0%)
#   adding: content/runs/detect/train/events.out.tfevents.1737049500.760d12a2e7a6.2367.0 (deflated 91%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/results.png (deflated 8%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 30%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 19%)
#   adding: content/runs/detect/train/state_dict.pt (deflated 8%)
#   adding: content/runs/detect/train/P_curve.png (deflated 18%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 31%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 5%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train/model_artifacts.json (deflated 64%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/ (stored 0%)
#   adding: content/runs/detect/predict2/img_13900_jpg.rf.a24ddfc3bc329287abc564bc8f25d51e.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_16735_jpg.rf.aee46bbd9048a448fd84388723240430.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_27903_jpg.rf.c7dae5151f87b0ac60e18cd81ed761d6.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/xyzzzzzz-57-_jpg.rf.a80d5070c37ded3a531533951659461a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_24925_jpg.rf.24f0468bbb908784bfe89dc0ac1ccbef.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_24905_jpg.rf.2f80753408bfd517c7286f9daa9e5224.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/WhatsApp-Image-2022-02-22-at-11-58-56-PM_jpeg.rf.5eaa64ee99b9d2b83daaa5e71e1b1a41.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/img_27207_jpg.rf.f3f75a07cd22fb7d404e4c5e2e66a756.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_12066_jpg.rf.d9837360e9cbce878b4388f1cbb08008.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Video2_8_258_jpg.rf.a5308d10c7d055bfe4670b5b1b012067.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/img_21581_jpg.rf.510ec8678a019e6b031b16b8ecb38021.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/VID_20221206_141209_230_png.rf.08d0b8d0bdc15444f990f12fa21ea501.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/img_15223_jpg.rf.d0756095066704757c003d765350d2d4.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/img_18944_jpg.rf.2caed7b3cda8b6d60b198cc1f7c882e5.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/_-59-_mp4-30_jpg.rf.ea4f2642e2991d9b83fcfe7c1331c4f7.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/smartphone_1042_jpg.rf.eee7f5c0ce142336bfbb24ed0591c1b3.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/-_202305081238372_jpg.rf.313d30440674b400d54ca115d56840c7.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/img_19675_jpg.rf.69bda7169db24712b706b0ca1ec9c8a1.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Untitled-video-Made-with-Clipchamp_mp4-0471_jpg.rf.7797f69e1c1f24034478df072deea007.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_18016_jpg.rf.a4650b3ebbd4342163eb33ccf2e51981.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1001-174-_jpg.rf.27618c3089e4b29fdaf72880e6d7042e.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/_-44-_mp4-27_jpg.rf.1b04021d3fa90281326af9b1f8565666.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/1001-116-_jpg.rf.c0c567469abf19a9bd7bb407eca193f5.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/_-43-_mp4-42_jpg.rf.9b362e0104a29ce62c63034b384f43e9.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/-_20230508110703_jpg.rf.6a749bf9825123bf387b83b45b5f0796.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/img_16526_jpg.rf.deed3575fe791c9a5fbbfe7845df1004.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/_-45-_mp4-32_jpg.rf.962196a72a7e262983febacb6ba7580e.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/_-2-_mp4-65_jpg.rf.4f77d659c1fbdb177d53b2c877cbe98f.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/img_18548_jpg.rf.724446a7f180cdc3417ec39c7b661bf3.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/164053frame0-00-08-03_jpg.rf.4228fe2901fa92ef1f7f9661b5ca6eed.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/image2442_png.rf.8563ac22c4ff59fddc337a0cc91841f3.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_18178_jpg.rf.7d82e68e92f06da64d11b178a9e8d8c2.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_14664_jpg.rf.daf7f02c08fc4e3a200504906b3047ce.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-54-_mp4-18_jpg.rf.3098397ed79eda025516653bab9f1eed.jpg (deflated 9%)
#   adding: content/runs/detect/predict2/img_29549_jpg.rf.5863db51cead22883e4a032427e61fe1.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-12-_mp4-80_jpg.rf.b900d7e63a2fdd3497bc3f6dfbfec3c3.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/-_202305081107041_jpg.rf.d0a179de7f800290e06d0191ce21afc6.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/104313frame0-00-48-55_jpg.rf.3de7ccbb8588f71fdb923a4fa6ca6626.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/img_20716_jpg.rf.62c57183acce947ae1a3a3a74b2fe751.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-12-_mp4-75_jpg.rf.e57c55d556b3747aa324a3abcb262951.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/img_21565_jpg.rf.a06b402b4fc9d26f947befda55283595.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-59-_mp4-83_jpg.rf.c5f7ff69d6b2720058b34041096990c7.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/img_32055_jpg.rf.72166100d8e0a24a12ed5e4393604528.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/img_14351_jpg.rf.77e8e03f72153e6954b030c6ad7be49b.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/img_16171_jpg.rf.edf4cab941248459de0bc26e172c94a3.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/goruntu_1689755960_jpg.rf.4cf119d708984835cc52b40b92ee42a6.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_11358_jpg.rf.28bdcae21594f26b4db9a4741fe28786.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/smartphone_0805_JPG_jpg.rf.07e966c2460ecf49635769c469200d5e.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/11314frame0-00-04-51_jpg.rf.34460ae9053b6656ce6f3f3c9e172209.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/img_26202_jpg.rf.2523d9512145bca07e94307161c8f74f.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/13050frame0-07-17-50_jpg.rf.01de2db5a09a58afce9bb9738dc926e3.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/WIN_20220722_17_49_01_Pro-3-_jpg.rf.af857fe240a027cf8b61d8d201352e05.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_18707_jpg.rf.678624ac4b8b940661247f7ef54e85bf.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/WIN_20220705_14_15_12_Pro_jpg.rf.7b3109e4eef76371118362f6920e1885.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/img_25489_jpg.rf.7d523d704cb90ef9446fb4555edc2dc7.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/xyzabc-208-_jpeg.rf.f58187cae9afde4a33675e9780fe7a2b.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/img_26918_jpg.rf.174a906cecda34623716784d64d85634.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_26549_jpg.rf.1126d4058099dc02c3223235e88dfe69.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_11621_jpg.rf.e5763aa321aae255f9932cf222e22529.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/WIN_20220722_14_03_03_Pro_jpg.rf.d275111a8c930534617bd3c0ad340e1b.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-3-_mp4-79_jpg.rf.fdca6da42bf8b5643d7d63b944e9f5b6.jpg (deflated 11%)
#   adding: content/runs/detect/predict2/img_21058_jpg.rf.a7c0c442d0d01e6cd50b831664597885.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/man-shirt-phone-to-your-ear-29592975_jpg.rf.192b2634a4ea0fdfcee45110c9e8b114.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/img_26875_jpg.rf.d1dfa4a162d9bf54290e9ee28798f69e.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/164049frame0-00-10-05_jpg.rf.8dfed1a88fc501feb3e4584d4dcc1fed.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/img_28125_jpg.rf.62ad13a96c98066da29ea4b993ec07d0.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_23850_jpg.rf.12a52b9937e9e3dbc70424d56396d2cf.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_20218_jpg.rf.4e6e1589f6107548e6bbe371c2075862.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_16374_jpg.rf.5ae3f8477f775f9eaf6ce56f640fc2b2.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_15592_jpg.rf.b8a111add686541537990e3e79955e17.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/VID_20221206_140620_020_png.rf.28e0ea10bdef5e018b4b9386bb57faf7.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/Untitled-video-Made-with-Clipchamp_mp4-0599_jpg.rf.a34aebfee02d2ee8001530139b72be93.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_4_0_jpg.rf.b4a5c5d5ced83158c6a6af59edc711be.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_24276_jpg.rf.558cb2d8866dee126b45bdab56486424.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_25763_jpg.rf.afd9f9ae01c453ab1a9deca0b9b10f26.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-54-_mp4-56_jpg.rf.aa11eb76bcd544cac1e2099aadc36709.jpg (deflated 9%)
#   adding: content/runs/detect/predict2/img_27972_jpg.rf.214678372f7bad3a0ed5219aca49d082.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/phone_call166_0_flip_jpg.rf.c14d987bbc04b1faf55998a82f63efd0.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/img_16148_jpg.rf.1080e79e1dc684d17934f2ed891a37f6.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/137e52fc11bca7a9_jpg.rf.70c2709a5cf54b2603723f01837ab528.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/WIN_20220728_14_33_11_Pro_jpg.rf.f155ba1b2b5051cda7396b707838cf86.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/WIN_20220722_12_32_06_Pro_jpg.rf.5ab6283878b36b79feda7a937a913fff.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_19655_jpg.rf.a884362ccf4f3230ba62f82c3ea736fa.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-43-_mp4-16_jpg.rf.9d1d612c53f5b2e3bf0a5641593d4d01.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/104313frame0-00-08-03_jpg.rf.0547bf4253cd53c6fd2112a2afa1c054.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/img_13516_jpg.rf.9f72a7bafc034874a8f3e78f18bd6dc3.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/xyzzzzzz-151-_jpg.rf.cb84188e2dfab5ef5e23de4230508367.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_16458_jpg.rf.2d20bea1e874eef368f0ab3377f6ec5c.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/img_21068_jpg.rf.bd8f9152bd4f916a1d068a87f4694d5b.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/img_24003_jpg.rf.95b363826e9dbcede692e887e1f9dae5.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_28781_jpg.rf.32831443338f028a9c498e40905cbe40.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/elite-daily-Studio-Firma-phone_jpg.rf.c78156932c8f5c574a050ecbd2b2625c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_25153_jpg.rf.054137e47486c16ec17809ee9f28c6b6.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Untitled-video-Made-with-Clipchamp_mp4-0507_jpg.rf.0f61be2ba436a948f8384ba118d15a7a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/4f9c586140035d9a_jpg.rf.2728ac6d21ab109d9700e5fd2dc1e5e8.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_19410_jpg.rf.fae620e5be2e36e5e10933550e2816a0.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-2-_mp4-29_jpg.rf.26247f8cde3888eba700738215135cb5.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/img_26104_jpg.rf.76ec5365c7c5fd624ad65167437652d2.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/1001-616-_jpg.rf.ced1cd14d200a7fa309b3b1ea2ba18a3.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/_-45-_mp4-5_jpg.rf.6cf3f6bd7a4af809617c8507d070e8a5.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/img_18234_jpg.rf.32c5c8f3b7aa4987af7098f89723c056.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/img_13194_jpg.rf.80afa7b3c3cea7eb9f55908811316e9e.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_14240_jpg.rf.f35b6c23e29fdb251f347d22ce9cc2f2.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/36_jpg.rf.d89212f6861bbebf3a35ffd697fa7fee.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/IMG-20230224-WA0107_jpg.rf.8aff70dfae9b0abf5b4a40e199ef1978.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/-_20230508114347_jpg.rf.e288a46b4137d4a1ed931c5a9493c72d.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_14108_jpg.rf.6adc7461e61347fd30093a23c341b0bc.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_27522_jpg.rf.37b1d79bb25cf4b82b89111720733b2a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_22101_jpg.rf.3258ca29aef06bf99abcdc10439ba1fd.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/-_202305081143472_jpg.rf.e73bbeabaa7922404136834d02004f28.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_18807_jpg.rf.70ec8292906c3579261b0c4c803c4c05.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/smartphone_1005_jpg.rf.7a5b00972a4ed308d1d6144b07441ed0.jpg (deflated 12%)
#   adding: content/runs/detect/predict2/_-46-_mp4-31_jpg.rf.f9a1b3f501ab42684da031c09f8b7b02.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/WIN_20220728_14_32_17_Pro_jpg.rf.603bbc1672de15f8c97cda86a284342f.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/img_23396_jpg.rf.74782ee105ac4b125899297004b2ea21.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/Untitled-video-Made-with-Clipchamp_mp4-0627_jpg.rf.d41f0cf93a702a376fe7e0bc170e7f94.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_25404_jpg.rf.ee7c48da3b6829c9883d7780117bfe90.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/img_22237_jpg.rf.0bb3ae8e04ba7844267b33d203ab0720.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/xyzzzzzz-3-_jpg.rf.6d71a88cbca4eb9429a309b240497502.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_20333_jpg.rf.7e62987c6a09d012b700453b3d6fff07.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/xyzabc-247-_jpeg.rf.fcd13141799490f9fcbbeeeb78274e1d.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/cell05_0093_jpg.rf.1f6ddf8921690626a262671e445e5a69.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/img_28791_jpg.rf.3ccd9f75c0001d491eaa7b1bc53e0527.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/_-2-_mp4-37_jpg.rf.3763110a4ccc557fd37ca592bdbeddd3.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/_-53-_mp4-82_jpg.rf.9a6eaf708fa8397332138476efdd10b7.jpg (deflated 9%)
#   adding: content/runs/detect/predict2/img_20620_jpg.rf.ac7756b88d6dbb6b04bb9c65578e8b4f.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/img_12892_jpg.rf.bddeb3f407c9690b871ea8e83e17f724.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/WIN_20220705_14_15_04_Pro-2-_jpg.rf.a96b338db472c9a803dbf9ef6f229253.jpg (deflated 7%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/dog.jpeg (deflated 6%)
#   adding: content/runs/detect/val/ (stored 0%)
#   adding: content/runs/detect/val/val_batch0_labels.jpg (deflated 8%)
#   adding: content/runs/detect/val/val_batch2_pred.jpg (deflated 8%)
#   adding: content/runs/detect/val/R_curve.png (deflated 13%)
#   adding: content/runs/detect/val/confusion_matrix.png (deflated 33%)
#   adding: content/runs/detect/val/F1_curve.png (deflated 13%)
#   adding: content/runs/detect/val/val_batch0_pred.jpg (deflated 8%)
#   adding: content/runs/detect/val/val_batch2_labels.jpg (deflated 8%)
#   adding: content/runs/detect/val/val_batch1_pred.jpg (deflated 8%)
#   adding: content/runs/detect/val/PR_curve.png (deflated 19%)
#   adding: content/runs/detect/val/P_curve.png (deflated 18%)
#   adding: content/runs/detect/val/confusion_matrix_normalized.png (deflated 30%)
#   adding: content/runs/detect/val/val_batch1_labels.jpg (deflated 8%)

# %%
from google.colab import files
files.download('distracted.zip')

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.

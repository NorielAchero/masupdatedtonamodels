# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the accompanying [Blog Post](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset/).
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Jan 16 19:24:06 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   66C    P8              15W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 30.8/235.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 342MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 88.2MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 61.9ms
# Speed: 11.9ms preprocess, 61.9ms inference, 789.6ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 65.0ms
# Speed: 5.2ms preprocess, 65.0ms inference, 590.5ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.0000,  314.4659,  625.1384, 1278.2329],
#         [  55.3155,  250.0996,  648.0573, 1266.2471],
#         [ 633.2308,  719.5389,  701.0688,  786.0390]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.7272, 0.2903, 0.2839], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a [supported format](https://roboflow.com/formats), the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v8` dataset format. (Formerly, we used to use `Yolov5`, as the gif shows)
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# 🟢 Tip: The examples below work even if you use our non-custom model. However, you won't be able to deploy it to Roboflow. To do that, create a custom dataset as described below or fork (copy) one into your workspace from Universe.

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow==1.1.48 --quiet

import roboflow

roboflow.login()

rf = roboflow.Roboflow()

project = rf.workspace("asdasdas-v3czz").project("fire-detection-yolov8-ylrh2-t9njv")
dataset = project.version(2).download("yolov8")
# Out:
# /content/datasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.7 MB/s eta 0:00:00
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
#
# Version export complete for yolov8 format
# Downloading Dataset Version Zip in Fire-Detection-YOLOv8-2 to yolov8:: 100%|██████████| 89803/89803 [00:06<00:00, 13179.17it/s]
# Extracting Dataset Version Zip to Fire-Detection-YOLOv8-2 in yolov8:: 100%|██████████| 4340/4340 [00:00<00:00, 7784.47it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:01<00:00, 13.3MB/s]
# New https://pypi.org/project/ultralytics/8.3.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/Fire-Detection-YOLOv8-2/data.yaml, epochs=25, time=None, patience=100, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 120MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/datasets/Fire-Detection-YOLOv8-2/train/labels... 1953 images, 0 backgrounds, 0 corrupt: 100% 1953/1953 [00:01<00:00, 1513.70it/s]
# train: New cache created: /content/datasets/Fire-Detection-YOLOv8-2/train/labels.cache
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.0 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Fire-Detection-YOLOv8-2/valid/labels... 105 images, 0 backgrounds, 0 corrupt: 100% 105/105 [00:00<00:00, 1328.38it/s]
# val: New cache created: /content/datasets/Fire-Detection-YOLOv8-2/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25       5.6G      1.722      2.682      1.699          4        800: 100% 123/123 [00:33<00:00,  3.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:02<00:00,  1.91it/s]
#                    all        105        137      0.424      0.241      0.294      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      5.59G      1.755      1.548      1.701          1        800: 100% 123/123 [00:30<00:00,  4.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.00it/s]
#                    all        105        137      0.351      0.307      0.269      0.093
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      5.57G      1.725      1.507      1.637          1        800: 100% 123/123 [00:30<00:00,  4.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.98it/s]
#                    all        105        137      0.278      0.314      0.204     0.0758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      5.56G      1.705      1.421      1.629          2        800: 100% 123/123 [00:30<00:00,  4.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.92it/s]
#                    all        105        137      0.782      0.761      0.812      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      5.58G      1.623      1.259      1.562          0        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.07it/s]
#                    all        105        137      0.503      0.406      0.393      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      5.55G      1.565      1.158      1.521          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.00it/s]
#                    all        105        137      0.742      0.819      0.832      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      5.57G      1.515      1.088      1.482          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.06it/s]
#                    all        105        137      0.871      0.781       0.87      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      5.56G      1.483      1.032      1.463          1        800: 100% 123/123 [00:30<00:00,  4.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.98it/s]
#                    all        105        137      0.871      0.887      0.914      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      5.59G      1.448      0.984       1.44          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.06it/s]
#                    all        105        137       0.92      0.883      0.951      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25       5.8G       1.39      0.933      1.401          2        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.96it/s]
#                    all        105        137        0.9      0.869      0.935      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      5.57G      1.353     0.8752      1.374          1        800: 100% 123/123 [00:30<00:00,  4.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.84it/s]
#                    all        105        137      0.938      0.861       0.94      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      5.56G       1.34     0.8532      1.362          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.06it/s]
#                    all        105        137      0.884      0.832      0.919      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      5.58G      1.295     0.8199      1.343          2        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.12it/s]
#                    all        105        137      0.942      0.891      0.942      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      5.79G       1.28     0.8083      1.322          0        800: 100% 123/123 [00:30<00:00,  4.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.15it/s]
#                    all        105        137      0.912      0.908      0.953      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      5.58G      1.258     0.7758      1.314          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.12it/s]
#                    all        105        137      0.954      0.942      0.966      0.613
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      5.56G      1.214     0.6602      1.318          1        800: 100% 123/123 [00:31<00:00,  3.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.03it/s]
#                    all        105        137       0.94      0.911      0.962       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      5.58G      1.168     0.6424      1.296          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.05it/s]
#                    all        105        137      0.929       0.92      0.947      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25       5.8G      1.148     0.6104      1.278          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.07it/s]
#                    all        105        137      0.961      0.905      0.952      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      5.57G      1.101     0.5809      1.252          2        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.07it/s]
#                    all        105        137      0.939      0.949      0.961      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      5.56G      1.082     0.5676      1.231          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.10it/s]
#                    all        105        137      0.951       0.92      0.983      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      5.58G      1.057     0.5587      1.211          2        800: 100% 123/123 [00:30<00:00,  4.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.11it/s]
#                    all        105        137      0.958      0.934      0.971      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      5.55G      1.013     0.5142      1.186          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.12it/s]
#                    all        105        137      0.928      0.945      0.981      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      5.57G     0.9694     0.4869       1.16          1        800: 100% 123/123 [00:30<00:00,  4.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.12it/s]
#                    all        105        137      0.933      0.971      0.982      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      5.55G     0.9528     0.4904      1.145          2        800: 100% 123/123 [00:30<00:00,  4.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.14it/s]
#                    all        105        137       0.97      0.933       0.97      0.693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      5.58G     0.9261     0.4632      1.131          1        800: 100% 123/123 [00:30<00:00,  4.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.03it/s]
#                    all        105        137      0.957      0.949      0.983      0.686
#
# 25 epochs completed in 0.225 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.86it/s]
#                    all        105        137       0.97      0.933       0.97      0.692
# Speed: 0.3ms preprocess, 3.9ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Fire-Detection-YOLOv8-2/valid/labels.cache... 105 images, 0 backgrounds, 0 corrupt: 100% 105/105 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  2.19it/s]
#                    all        105        137      0.963      0.927      0.969      0.691
# Speed: 3.2ms preprocess, 7.0ms inference, 0.0ms loss, 11.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0009_jpg.rf.93242149eac7da9bcb265fe766da07a5.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 7.8ms
# image 2/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0023_jpg.rf.03c39e9eb0148028dc84f5f8e9ed8ac7.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 7.2ms
# image 3/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0030_jpg.rf.7062f04ce351044cdd2f5af7973764d4.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.6ms
# image 4/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0032_jpg.rf.a723ee77828cef706987a7ffa6b54382.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.6ms
# image 5/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0034_jpg.rf.16b8b647d2fc993660c14a48c026b086.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.6ms
# image 6/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0101_jpg.rf.05bea8d1eedd853a6c15c192bb1715d0.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.5ms
# image 7/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0103_jpg.rf.72f2ddfb39f906aad2fd9ff2845f7ce0.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 8/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0105_jpg.rf.c6f8daf44c722aeacd2c06124a526cb8.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 9/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0130_jpg.rf.2e0b292bc3ac58e5e7517607a4eb7c82.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 10/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0134_jpg.rf.6edb6980c91c27ba0f7119b25ebccdf6.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 11/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0137_jpg.rf.4c04bbc71c66498e5621af873c7e11ca.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 12/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0145_jpg.rf.30007bab714a06a2191f982cbfe2bbe5.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 13/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0155_jpg.rf.32b86f1a3cf5766201b8fd161b85775a.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 14/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0161_jpg.rf.5c7729d7436de4b6ce742b2d11c2d0fe.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.7ms
# image 15/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0168_jpg.rf.1e7217f906acbf2c67bfe28c5e727d1a.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.5ms
# image 16/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0175_jpg.rf.a79d44d129cee108335c2aa4d25a7b86.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.6ms
# image 17/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0177_jpg.rf.d6e0b050ed0dfcff898ddb29cf2c889d.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.5ms
# image 18/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0220_jpg.rf.cf7a67de79f9a90bb827794e4f749d3c.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 19/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0234_jpg.rf.64fae8be9f7df1ef224d71226e0dfa47.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 20/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0235_jpg.rf.330a22f9d0c4eda582bc890f6865ab3f.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 21/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0238_jpg.rf.00ad7ac571b66c2b123c03dd5e745a2d.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.5ms
# image 22/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0258_jpg.rf.58b78b528e6a58456296d1888013d30d.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 23/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0316_jpg.rf.17b99cc86135fdaca681c84b70c2f626.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 24/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0318_jpg.rf.d3788357cebc7a6aa516d7f2575e1b59.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 25/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0320_jpg.rf.2683f63b0019e6b9e4c0b97fcf8950cf.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 26/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0321_jpg.rf.8c5e52e64fa55dd389c6a8750cf400b5.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 27/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0330_jpg.rf.a88ef1769281fbbec465fc8442adc3d0.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 28/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0345_jpg.rf.4e7c325c2da782b0825078c150b3df43.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 29/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0358_jpg.rf.8ed0a100a117aa7fe43be28cc83a6e46.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 30/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0383_jpg.rf.af039c2331edd733ed3d123f32d046bb.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.4ms
# image 31/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0388_jpg.rf.9985b7b45f62618e1a76760d67a8ee76.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 32/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0392_jpg.rf.ac227dd32950c6cbdb19e5a84d16d95f.jpg: 800x800 4 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 33/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0397_jpg.rf.7431c1395463ba540bb0409095152f7c.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 34/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0402_jpg.rf.1003e71032e92d64bec229eb5c354f0e.jpg: 800x800 4 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 35/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0412_jpg.rf.8a94cdaf541adb110621d800a5ea0338.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 36/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0415_jpg.rf.23c584e952307e9fbcd930795779d75f.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.5ms
# image 37/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0439_jpg.rf.4906e44171a77fda0d2e9be62cb7f846.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 38/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0446_jpg.rf.20df2d293c0db3303f274732cf3e547f.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 39/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0463_jpg.rf.e14070ec13e7cfcb12cf2fd386829081.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 40/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0500_jpg.rf.91c65951428902e2390618bac708f7e9.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 41/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0512_jpg.rf.113836b038709008a3e16a63fe797582.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 42/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0533_jpg.rf.da0fb83c01deb792c4437e3a3e810930.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 43/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0548_jpg.rf.ce8d5ddc72f1ef7fc481ae5888db290b.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 44/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0561_jpg.rf.ea44a463176da566448fd3b45eb7ea71.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 45/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0573_jpg.rf.2e8e7d1ced93ff7bfd8167764c514cbb.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 46/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0581_jpg.rf.7e8e64bec5e9dcc6d401e1300304c955.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 47/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0601_jpg.rf.8278cb2414f8971bf2d70456a77c1866.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 48/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0619_jpg.rf.8a1a166a000c629c7fcef51c797fe4e3.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.6ms
# image 49/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0626_jpg.rf.4e71aeebc2c919de58a1dd5246d1e0de.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 50/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0635_jpg.rf.4c75eeb3701cdf067d4befe6365064b0.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.2ms
# image 51/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0640_jpg.rf.c187ca54bfd2f3d245aa18a7222dd58a.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.4ms
# image 52/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0646_jpg.rf.221e65f12d4fac2fdd7d2d564c7aa170.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.2ms
# image 53/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0650_jpg.rf.b44d16225a05217d9c5bc665521acbd8.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 54/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0655_jpg.rf.f4a5918148debab8c46ba72c09c13210.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 55/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0661_jpg.rf.3af5431143a203085785a21423d00252.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 56/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0676_jpg.rf.c1f556300cd47ce74afee3207795cad0.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.2ms
# image 57/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0677_jpg.rf.4c5c92e5c293828c3d062dab9e088408.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 58/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0689_jpg.rf.24fa9961ef303633ec41671608c78dfc.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 7.7ms
# image 59/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0694_jpg.rf.e2868d5ce5ed3168a88d0a39eb88ae69.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.7ms
# image 60/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0697_jpg.rf.91fe3c9b7118d3eef692ae9c8cce3d08.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 61/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0716_jpg.rf.64512efaa95a2bcc32b4ed66a6a3ab92.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 62/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0773_jpg.rf.a6c49278cdd8abc606547646537dbb1d.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 63/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0779_jpg.rf.9093a312027562c8dbcb597d1bfc2754.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 64/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0806_jpg.rf.22568e12982aad200ab18a21921f3315.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 65/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0814_jpg.rf.e2eb7f058d4cc58f7c53539a79077025.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 66/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0822_jpg.rf.3297f02e7f7267927ba6579ead7235c9.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.2ms
# image 67/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0834_jpg.rf.4695d1f3c8d30a7b688f6881afd9b9c1.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 68/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0855_jpg.rf.fddf26c570701096bfaed5d06d33ff7a.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 69/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0871_jpg.rf.d423281e89c994648d14707251fda26e.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 70/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0880_jpg.rf.5a84ce1b4ab48c90c2fca757fb6f39ea.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 71/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0883_jpg.rf.ab8abd67ed653f6dfa690e19360d0d4f.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 72/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0906_jpg.rf.2e7cdf1f8eac117e6e289b9d7a5b7230.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 73/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0908_jpg.rf.d5f55265eba893e4638eb6cc36172db2.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.6ms
# image 74/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0909_jpg.rf.f9b90a039c44c1f8aa39565406b9e40f.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 75/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0919_jpg.rf.fd19b02dba98bb7146a3962dd4b6a840.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 7.4ms
# image 76/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0931_jpg.rf.a7c6a083a6369712e9708879906ed927.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 77/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0944_jpg.rf.5b71d3760028c511cfc53940dce0d57f.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 78/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0954_jpg.rf.b6bc961d568c031b85fadb2130465580.jpg: 800x800 6 fire-detection - v1 2024-12-03 4-19pms, 6.4ms
# image 79/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0963_jpg.rf.3da6205257bd6ad316d32dcaa92a1cd5.jpg: 800x800 4 fire-detection - v1 2024-12-03 4-19pms, 6.3ms
# image 80/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0985_jpg.rf.006c40705d6a433ddc272ff63e19e173.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 81/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0989_jpg.rf.a5f2d8b5800a9f11e652a5afd9a639d3.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 82/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0995_jpg.rf.87ab2d2c2bd0a35b3f812657a4bac13c.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.8ms
# image 83/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-0998_jpg.rf.f814a46211160f0ab2c58856ca122b0e.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 84/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1012_jpg.rf.4ffea418a15490ce30a3dee9374c97b5.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 85/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1030_jpg.rf.0d375a278dccd20026b80de40a5570ba.jpg: 800x800 2 fire-detection - v1 2024-12-03 4-19pms, 6.2ms
# image 86/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1033_jpg.rf.b2816be3dc10766023ad98ad67de5f8a.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.4ms
# image 87/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1040_jpg.rf.e22f304bc3666e739066fa6075def4e5.jpg: 800x800 3 fire-detection - v1 2024-12-03 4-19pms, 6.2ms
# image 88/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1043_jpg.rf.67de039957e753e07ccef461e1c885b8.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 89/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1051_jpg.rf.21759bbbc54d45f212c857f15c665398.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 90/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1058_jpg.rf.78bfb76cdba1250422c899a0fae6b38a.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 91/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1068_jpg.rf.227e71e1e278b7086eb763c69e54c21c.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 92/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1073_jpg.rf.fa7ac213f28131f42102ee3f02d9a62c.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.8ms
# image 93/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1074_jpg.rf.f1cc937fb2c81736e6f717de97c9d552.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 94/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1079_jpg.rf.b3d17bd9dbfb8311736aa42295b58d25.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 95/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1084_jpg.rf.18981689eff4b042ceae70f55225bb06.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 96/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1091_jpg.rf.3f0e135172b1432f80cdcd849b6777af.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 97/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1094_jpg.rf.54d8b4e5bfe8b6b400032a826210d9bf.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.4ms
# image 98/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1095_jpg.rf.8e72d6a205598ed4751167032779aab7.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 99/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1096_jpg.rf.c9ec4e695fbe72c669bbe50331df0d51.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# image 100/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1111_jpg.rf.3f0951813d10dc8ae3a0f459019457db.jpg: 800x800 (no detections), 6.2ms
# image 101/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1113_jpg.rf.5c929bdd7cfc9049a291a7d83d312b1a.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 102/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1116_jpg.rf.3d51ddfa5219c882ecf3146a5cdbceed.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 103/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1117_jpg.rf.656ec28ba48a1bf84faa6813209045a6.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 104/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1122_jpg.rf.8a14e359ee4098738eaf9eaf3fb5b48a.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.5ms
# image 105/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1133_jpg.rf.3894bec98000feb375b51e7f619281b5.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.2ms
# image 106/106 /content/datasets/Fire-Detection-YOLOv8-2/test/images/CarFiresVed_mp4-1134_jpg.rf.d1c40bf3e62450f2970bcff2e7f2c64c.jpg: 800x800 1 fire-detection - v1 2024-12-03 4-19pm, 6.3ms
# Speed: 3.9ms preprocess, 6.4ms inference, 8.3ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.103, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/asdasdas-v3czz/fire-detection-yolov8-ylrh2-t9njv/2
# Share your model with the world at: https://universe.roboflow.com/asdasdas-v3czz/fire-detection-yolov8-ylrh2-t9njv/model/2

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-afd7f5f31b70> in <cell line: 0>()
#       3 # Load model
#       4 model = project.version(dataset.version).model
# ----> 5 assert model, "Model deployment is still loading"
#       6
#       7 # Choose a random test image
#
# AssertionError: Model deployment is still loading

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/runs
# Out:
# /content/runs

# %%
# !zip -r fire.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/dog.jpeg (deflated 6%)
#   adding: content/runs/detect/predict2/ (stored 0%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1073_jpg.rf.fa7ac213f28131f42102ee3f02d9a62c.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0234_jpg.rf.64fae8be9f7df1ef224d71226e0dfa47.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0676_jpg.rf.c1f556300cd47ce74afee3207795cad0.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0258_jpg.rf.58b78b528e6a58456296d1888013d30d.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1040_jpg.rf.e22f304bc3666e739066fa6075def4e5.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0533_jpg.rf.da0fb83c01deb792c4437e3a3e810930.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0415_jpg.rf.23c584e952307e9fbcd930795779d75f.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0954_jpg.rf.b6bc961d568c031b85fadb2130465580.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0330_jpg.rf.a88ef1769281fbbec465fc8442adc3d0.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0931_jpg.rf.a7c6a083a6369712e9708879906ed927.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0581_jpg.rf.7e8e64bec5e9dcc6d401e1300304c955.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0908_jpg.rf.d5f55265eba893e4638eb6cc36172db2.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1111_jpg.rf.3f0951813d10dc8ae3a0f459019457db.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0145_jpg.rf.30007bab714a06a2191f982cbfe2bbe5.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1095_jpg.rf.8e72d6a205598ed4751167032779aab7.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0130_jpg.rf.2e0b292bc3ac58e5e7517607a4eb7c82.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1084_jpg.rf.18981689eff4b042ceae70f55225bb06.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0985_jpg.rf.006c40705d6a433ddc272ff63e19e173.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1051_jpg.rf.21759bbbc54d45f212c857f15c665398.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0573_jpg.rf.2e8e7d1ced93ff7bfd8167764c514cbb.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0032_jpg.rf.a723ee77828cef706987a7ffa6b54382.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0906_jpg.rf.2e7cdf1f8eac117e6e289b9d7a5b7230.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1113_jpg.rf.5c929bdd7cfc9049a291a7d83d312b1a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1133_jpg.rf.3894bec98000feb375b51e7f619281b5.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0989_jpg.rf.a5f2d8b5800a9f11e652a5afd9a639d3.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0880_jpg.rf.5a84ce1b4ab48c90c2fca757fb6f39ea.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0155_jpg.rf.32b86f1a3cf5766201b8fd161b85775a.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0716_jpg.rf.64512efaa95a2bcc32b4ed66a6a3ab92.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0397_jpg.rf.7431c1395463ba540bb0409095152f7c.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0814_jpg.rf.e2eb7f058d4cc58f7c53539a79077025.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1058_jpg.rf.78bfb76cdba1250422c899a0fae6b38a.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0677_jpg.rf.4c5c92e5c293828c3d062dab9e088408.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1122_jpg.rf.8a14e359ee4098738eaf9eaf3fb5b48a.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0321_jpg.rf.8c5e52e64fa55dd389c6a8750cf400b5.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0548_jpg.rf.ce8d5ddc72f1ef7fc481ae5888db290b.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0822_jpg.rf.3297f02e7f7267927ba6579ead7235c9.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0626_jpg.rf.4e71aeebc2c919de58a1dd5246d1e0de.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0646_jpg.rf.221e65f12d4fac2fdd7d2d564c7aa170.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0694_jpg.rf.e2868d5ce5ed3168a88d0a39eb88ae69.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0402_jpg.rf.1003e71032e92d64bec229eb5c354f0e.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0834_jpg.rf.4695d1f3c8d30a7b688f6881afd9b9c1.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0661_jpg.rf.3af5431143a203085785a21423d00252.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1091_jpg.rf.3f0e135172b1432f80cdcd849b6777af.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0944_jpg.rf.5b71d3760028c511cfc53940dce0d57f.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0689_jpg.rf.24fa9961ef303633ec41671608c78dfc.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0320_jpg.rf.2683f63b0019e6b9e4c0b97fcf8950cf.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0161_jpg.rf.5c7729d7436de4b6ce742b2d11c2d0fe.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0640_jpg.rf.c187ca54bfd2f3d245aa18a7222dd58a.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1068_jpg.rf.227e71e1e278b7086eb763c69e54c21c.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1094_jpg.rf.54d8b4e5bfe8b6b400032a826210d9bf.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0318_jpg.rf.d3788357cebc7a6aa516d7f2575e1b59.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0105_jpg.rf.c6f8daf44c722aeacd2c06124a526cb8.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0383_jpg.rf.af039c2331edd733ed3d123f32d046bb.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0919_jpg.rf.fd19b02dba98bb7146a3962dd4b6a840.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0561_jpg.rf.ea44a463176da566448fd3b45eb7ea71.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0137_jpg.rf.4c04bbc71c66498e5621af873c7e11ca.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0883_jpg.rf.ab8abd67ed653f6dfa690e19360d0d4f.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0345_jpg.rf.4e7c325c2da782b0825078c150b3df43.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0238_jpg.rf.00ad7ac571b66c2b123c03dd5e745a2d.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1033_jpg.rf.b2816be3dc10766023ad98ad67de5f8a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0998_jpg.rf.f814a46211160f0ab2c58856ca122b0e.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0512_jpg.rf.113836b038709008a3e16a63fe797582.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0177_jpg.rf.d6e0b050ed0dfcff898ddb29cf2c889d.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1012_jpg.rf.4ffea418a15490ce30a3dee9374c97b5.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1079_jpg.rf.b3d17bd9dbfb8311736aa42295b58d25.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0650_jpg.rf.b44d16225a05217d9c5bc665521acbd8.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0697_jpg.rf.91fe3c9b7118d3eef692ae9c8cce3d08.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0316_jpg.rf.17b99cc86135fdaca681c84b70c2f626.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0779_jpg.rf.9093a312027562c8dbcb597d1bfc2754.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1116_jpg.rf.3d51ddfa5219c882ecf3146a5cdbceed.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0023_jpg.rf.03c39e9eb0148028dc84f5f8e9ed8ac7.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0220_jpg.rf.cf7a67de79f9a90bb827794e4f749d3c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1030_jpg.rf.0d375a278dccd20026b80de40a5570ba.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0412_jpg.rf.8a94cdaf541adb110621d800a5ea0338.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0619_jpg.rf.8a1a166a000c629c7fcef51c797fe4e3.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0009_jpg.rf.93242149eac7da9bcb265fe766da07a5.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0034_jpg.rf.16b8b647d2fc993660c14a48c026b086.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0358_jpg.rf.8ed0a100a117aa7fe43be28cc83a6e46.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0500_jpg.rf.91c65951428902e2390618bac708f7e9.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0963_jpg.rf.3da6205257bd6ad316d32dcaa92a1cd5.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0392_jpg.rf.ac227dd32950c6cbdb19e5a84d16d95f.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1096_jpg.rf.c9ec4e695fbe72c669bbe50331df0d51.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0601_jpg.rf.8278cb2414f8971bf2d70456a77c1866.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1043_jpg.rf.67de039957e753e07ccef461e1c885b8.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0235_jpg.rf.330a22f9d0c4eda582bc890f6865ab3f.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0773_jpg.rf.a6c49278cdd8abc606547646537dbb1d.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0463_jpg.rf.e14070ec13e7cfcb12cf2fd386829081.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0175_jpg.rf.a79d44d129cee108335c2aa4d25a7b86.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0446_jpg.rf.20df2d293c0db3303f274732cf3e547f.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0168_jpg.rf.1e7217f906acbf2c67bfe28c5e727d1a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0388_jpg.rf.9985b7b45f62618e1a76760d67a8ee76.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0909_jpg.rf.f9b90a039c44c1f8aa39565406b9e40f.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0635_jpg.rf.4c75eeb3701cdf067d4befe6365064b0.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1134_jpg.rf.d1c40bf3e62450f2970bcff2e7f2c64c.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0103_jpg.rf.72f2ddfb39f906aad2fd9ff2845f7ce0.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0030_jpg.rf.7062f04ce351044cdd2f5af7973764d4.jpg (deflated 3%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0855_jpg.rf.fddf26c570701096bfaed5d06d33ff7a.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0806_jpg.rf.22568e12982aad200ab18a21921f3315.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0134_jpg.rf.6edb6980c91c27ba0f7119b25ebccdf6.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1117_jpg.rf.656ec28ba48a1bf84faa6813209045a6.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0871_jpg.rf.d423281e89c994648d14707251fda26e.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0995_jpg.rf.87ab2d2c2bd0a35b3f812657a4bac13c.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0439_jpg.rf.4906e44171a77fda0d2e9be62cb7f846.jpg (deflated 8%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0655_jpg.rf.f4a5918148debab8c46ba72c09c13210.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-1074_jpg.rf.f1cc937fb2c81736e6f717de97c9d552.jpg (deflated 5%)
#   adding: content/runs/detect/predict2/CarFiresVed_mp4-0101_jpg.rf.05bea8d1eedd853a6c15c192bb1715d0.jpg (deflated 4%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train/events.out.tfevents.1737055528.1ddb5d332ea9.1185.0 (deflated 91%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 31%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 9%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train/roboflow_deploy.zip (stored 0%)
#   adding: content/runs/detect/train/R_curve.png (deflated 18%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 2%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 34%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 2%)
#   adding: content/runs/detect/train/results.png (deflated 7%)
#   adding: content/runs/detect/train/P_curve.png (deflated 19%)
#   adding: content/runs/detect/train/labels.jpg (deflated 34%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 18%)
#   adding: content/runs/detect/train/model_artifacts.json (deflated 64%)
#   adding: content/runs/detect/train/train_batch1846.jpg (deflated 9%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 2%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 33%)
#   adding: content/runs/detect/train/results.csv (deflated 84%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/state_dict.pt (deflated 8%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 25%)
#   adding: content/runs/detect/train/train_batch1847.jpg (deflated 6%)
#   adding: content/runs/detect/train/train_batch1845.jpg (deflated 5%)
#   adding: content/runs/detect/val/ (stored 0%)
#   adding: content/runs/detect/val/val_batch0_labels.jpg (deflated 7%)
#   adding: content/runs/detect/val/confusion_matrix_normalized.png (deflated 31%)
#   adding: content/runs/detect/val/val_batch2_labels.jpg (deflated 8%)
#   adding: content/runs/detect/val/val_batch2_pred.jpg (deflated 8%)
#   adding: content/runs/detect/val/val_batch1_labels.jpg (deflated 7%)
#   adding: content/runs/detect/val/R_curve.png (deflated 18%)
#   adding: content/runs/detect/val/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/val/P_curve.png (deflated 20%)
#   adding: content/runs/detect/val/F1_curve.png (deflated 18%)
#   adding: content/runs/detect/val/confusion_matrix.png (deflated 32%)
#   adding: content/runs/detect/val/val_batch0_pred.jpg (deflated 7%)
#   adding: content/runs/detect/val/PR_curve.png (deflated 24%)

# %%
from google.colab import files
files.download('distracted.zip')

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
